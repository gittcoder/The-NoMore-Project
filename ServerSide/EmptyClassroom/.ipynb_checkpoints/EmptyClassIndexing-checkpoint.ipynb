# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(pd.read_excel("AllocationList.xlsx"))

# %%
df
# Out:
#      COURSE CODE                           COURSE TITLE COURSE TY  \
# 0        MGT1022               Lean Start-up Management       ETH
# 1        MGT1022               Lean Start-up Management       EPJ
# 2        MGT1022               Lean Start-up Management       ETH
# 3        MGT1022               Lean Start-up Management       EPJ
# 4        MGT1022               Lean Start-up Management       ETH
# ...          ...                                    ...       ...
# 2966     LFS4021  Life Skills for Biotechnologists - IV        TH
# 2967     LFS4021  Life Skills for Biotechnologists - IV        TH
# 2968     TAM1003                                  Tamil        TH
# 2969     TAM1003                                  Tamil        TH
# 2970     TAM1003                                  Tamil        TH
#
#              CLASS ID ROOM NUMBE    SLOT ERP ID     EMPLOYEE NAME
# 0     VL2021220502852     SJT302     TC1  12438   UMA PRICILDA J.
# 1     VL2021220502853        NIL     NIL  12438   UMA PRICILDA J.
# 2     VL2021220502855      TT331     TE1  12438   UMA PRICILDA J.
# 3     VL2021220502856        NIL     NIL  12438   UMA PRICILDA J.
# 4     VL2021220503418      MB218     TE1  10531       SUBASHINI R
# ...               ...        ...     ...    ...               ...
# 2966  VL2021220501484     SMV209      G1  17057          VARSHA K
# 2967  VL2021220501485     SMV218      G2  17056   SUSHANT KISHORE
# 2968  VL2021220501162      TT206  F1+TF1  14555  MARIA SEBASTIN A
# 2969  VL2021220501164     SJT118  D1+TD1  14555  MARIA SEBASTIN A
# 2970  VL2021220501166      TT206  G1+TG1  14555  MARIA SEBASTIN A
#
# [2971 rows x 8 columns]

# %%
df.drop(['COURSE CODE'], axis=1,inplace=True)
df.drop(['COURSE TITLE'], axis=1,inplace=True)
df.drop(['COURSE TY'], axis=1,inplace=True)
df.drop(['CLASS ID'], axis=1,inplace=True)
df.drop(['ERP ID'], axis=1,inplace=True)
df.drop(['EMPLOYEE NAME'], axis=1,inplace=True)

# %%
df
# Out:
#      ROOM NUMBE    SLOT
# 0        SJT302     TC1
# 1           NIL     NIL
# 2         TT331     TE1
# 3           NIL     NIL
# 4         MB218     TE1
# ...         ...     ...
# 2966     SMV209      G1
# 2967     SMV218      G2
# 2968      TT206  F1+TF1
# 2969     SJT118  D1+TD1
# 2970      TT206  G1+TG1
#
# [2971 rows x 2 columns]

# %%
df = df[df['ROOM NUMBE'] != 'NIL']
df = df[df['SLOT'] != 'NIL']

# %%
df
# Out:
#      ROOM NUMBE    SLOT
# 0        SJT302     TC1
# 2         TT331     TE1
# 4         MB218     TE1
# 6         MB218     TE2
# 8         MB219     TE1
# ...         ...     ...
# 2966     SMV209      G1
# 2967     SMV218      G2
# 2968      TT206  F1+TF1
# 2969     SJT118  D1+TD1
# 2970      TT206  G1+TG1
#
# [2405 rows x 2 columns]

# %%
slots=['A1','TA1','A2','TA2','B1','TB1','B2','TB2','C1','TC1','C2','TC2','D1','TD1','D2','TD2','E1','TE1','E2','TE2','F1','TF1','F2','TF2','G1','TG1','G2','TG2']
classes=[]
len(slots)
for i in range(28):
    classes.append([str(i)])

# %%
co=0
for i in df.iterrows():
    s=i[1]['SLOT']
    c=i[1]['ROOM NUMBE']
    c=str(c)
    if(s[0]!='L'):
        if(s[0]=='T'):
            if(s[2]=='1'):
                classes[((ord(s[1])-65))*4+1].append(c)
            else:
                classes[((ord(s[1])-64))*4-1].append(c)
        elif(len(s)>3 and s[2]=='+'):
            if(s[1]=='1'):
                classes[((ord(s[0])-65))*4].append(c)
                classes[((ord(s[0])-65))*4+1].append(c)
            else:
                classes[((ord(s[0])-65))*4+2].append(c)
                classes[((ord(s[0]))-64)*4-1].append(c)
        elif(len(s)==2):
            if(s[1]=='1'):
                classes[((ord(s[0])-65))*4].append(c)
            else:
                classes[((ord(s[0])-65))*4+2].append(c)
        co+=1
    
print(co)
# Out:
# 1550

# %%
classes
# Out:
# [['0',
#   'SJT415',
#   'SJT617',
#   'MB214',
#   'SJT508',
#   'SJT513',
#   'SJT521',
#   'SJT315',
#   'SJT112',
#   'SJT113',
#   'SJT401',
#   'SJT404',
#   'SJT405',
#   'MB218',
#   'MB224',
#   'MB225',
#   'SMVG10',
#   'SMV116',
#   'SMV217',
#   'SMV218',
#   'SMV219',
#   'SMV128',
#   'SMV209',
#   'SMV234',
#   'SMV109',
#   'CDMM105',
#   'CDMM302',
#   'SMV101',
#   'SMV102',
#   'SJT505',
#   'SJT324',
#   'SJT402',
#   'SJT403',
#   'SJT422',
#   'SJT423',
#   'SJT302',
#   'SJT322',
#   'SJT501',
#   'MGB105',
#   'TT630',
#   'MGB201',
#   'MGB110',
#   'MGB305',
#   'MB226',
#   'SJT601',
#   'SJT323',
#   'SJT421',
#   'SJT522',
#   'SJT303',
#   'SJT308',
#   'SJT311A',
#   'MGB 303',
#   'SJT305',
#   'SJT409',
#   'SJT424',
#   'SJT514',
#   'MGB304',
#   'SJT602',
#   'TT434A',
#   'TT424',
#   'TT423',
#   'TT434',
#   'SMV220',
#   'TT335',
#   'TT531A',
#   'TT631',
#   'CBMR101',
#   'CBMR402',
#   'TT619',
#   'CBMR403',
#   'TT504',
#   'TT523',
#   'SJT201',
#   'SJT205',
#   'SJT207',
#   'SJT207A',
#   'SJT208',
#   'SJT211',
#   'SJT211A',
#   'SJT215',
#   'SJT221',
#   'SJT222',
#   'SJT224',
#   'SJT807',
#   'CDMM303',
#   'MB305A',
#   'PLB519',
#   'MB219',
#   'GDN128',
#   'MB227',
#   'PLB509',
#   'GDN129',
#   'PLB504',
#   'PLB522',
#   'MB312',
#   'PLB622',
#   'MB311',
#   'MB309A',
#   'SJT304',
#   'SJT127',
#   'TT524',
#   'SMV320',
#   'SJT311'],
#  ['1',
#   'SJT415',
#   'SJT617',
#   'MB214',
#   'SJT508',
#   'SJT513',
#   'SJT521',
#   'SJT315',
#   'SJT112',
#   'SJT113',
#   'SJT401',
#   'SJT404',
#   'SJT405',
#   'MB218',
#   'MB224',
#   'MB225',
#   'SJT323',
#   'SMVG10',
#   'SMV116',
#   'SMV217',
#   'SMV219',
#   'SMV128',
#   'SMV209',
#   'SMV234',
#   'SMV109',
#   'CDMM301',
#   'CDMM105',
#   'SMV101',
#   'SJT505',
#   'SJT402',
#   'SJT423',
#   'SJT302',
#   'SJT322',
#   'SJT501',
#   'MGB105',
#   'TT630',
#   'MGB201',
#   'MGB110',
#   'MGB305',
#   'MB226',
#   'SJT601',
#   'SJT421',
#   'SJT303',
#   'SJT308',
#   'SJT311A',
#   'MGB 303',
#   'SJT305',
#   'SJT409',
#   'SJT424',
#   'SJT514',
#   'MGB304',
#   'SJT602',
#   'TT434A',
#   'SMV220',
#   'TT530A',
#   'TT531A',
#   'TT631',
#   'CBMR101',
#   'CBMR402',
#   'TT619',
#   'CBMR403',
#   'TT504',
#   'TT523',
#   'SJT201',
#   'SJT205',
#   'SJT207',
#   'SJT207A',
#   'SJT208',
#   'SJT211',
#   'SJT211A',
#   'SJT221',
#   'SJT222',
#   'SJT807',
#   'MB309',
#   'CDMM303',
#   'MB305A',
#   'PLB519',
#   'MB219',
#   'GDN128',
#   'MB227',
#   'PLB509',
#   'GDN129',
#   'PLB504',
#   'PLB522',
#   'MB312',
#   'PLB622',
#   'MB309A'],
#  ['2',
#   'TT523',
#   'SJT415',
#   'SJT505',
#   'SJT508',
#   'SJT513',
#   'SJT514',
#   'SJT521',
#   'SJT401',
#   'SJT402',
#   'SJT403',
#   'SJT404',
#   'SJT112',
#   'SJT113',
#   'TT630',
#   'MB219',
#   'MB224',
#   'CDMM105',
#   'SJT617',
#   'CDMM302',
#   'SMV116',
#   'SMV219',
#   'SMV218',
#   'SMV217',
#   'SMV209',
#   'SMV234',
#   'SMV220',
#   'CDMM301',
#   'SMV112',
#   'SMV101',
#   'SMV128',
#   'SMV102',
#   'SJT303',
#   'SJT224',
#   'SJT315',
#   'SJT323',
#   'SJT305',
#   'SJT501',
#   'MGB109',
#   'MGB202',
#   'TT631',
#   'SJT522',
#   'SJT302',
#   'SJT311A',
#   'MGB110',
#   'SJT421',
#   'SJT807',
#   'SJT504',
#   'SJT322',
#   'SJT405',
#   'MGB207',
#   'SJT423',
#   'SJT409',
#   'SJT424',
#   'MGB106',
#   'SJT503',
#   'SJT601',
#   'TT112',
#   'SJT222',
#   'TT423',
#   'TT424',
#   'TT434A',
#   'TT434',
#   'TT504',
#   'TT531A',
#   'CBMR101',
#   'SJT205',
#   'CBMR301',
#   'CBMR403',
#   'SJT211A',
#   'CBMR402',
#   'SJT109',
#   'SJT114',
#   'SJT115',
#   'SJT118',
#   'SJT124',
#   'SJT125',
#   'SJT207',
#   'SJT126',
#   'SJT127',
#   'SJT201',
#   'SJT202',
#   'SJT203',
#   'SJT204',
#   'SJT207A',
#   'MB214',
#   'GDN107',
#   'MB309',
#   'MB225',
#   'PLB622',
#   'PLB509',
#   'SMV109',
#   'PLB504',
#   'PLB519',
#   'PLB522',
#   'MB227',
#   'MGB303',
#   'SJT308',
#   'SJT304',
#   'SJT208',
#   'SMVG10',
#   'SJT211',
#   'TT524',
#   'TT619',
#   'SJT221',
#   'SJT215',
#   'SJT324',
#   'SJT422',
#   'TT331',
#   'SJT311'],
#  ['3',
#   'TT523',
#   'SJT415',
#   'SJT505',
#   'SJT508',
#   'SJT513',
#   'SJT514',
#   'SJT521',
#   'SJT401',
#   'SJT402',
#   'SJT403',
#   'SJT404',
#   'SJT112',
#   'SJT113',
#   'TT630',
#   'MB219',
#   'MB224',
#   'CDMM105',
#   'SJT223',
#   'CDMM302',
#   'SMV116',
#   'SMV219',
#   'SMV218',
#   'SMV217',
#   'SMV209',
#   'SMV234',
#   'SMV220',
#   'CDMM301',
#   'SMV112',
#   'SMV101',
#   'SMV128',
#   'SJT315',
#   'SJT323',
#   'SJT305',
#   'SJT501',
#   'MGB109',
#   'MGB202',
#   'TT631',
#   'SJT522',
#   'SJT421',
#   'SJT807',
#   'SJT322',
#   'SJT405',
#   'MGB207',
#   'SJT423',
#   'SJT409',
#   'SJT424',
#   'MGB106',
#   'SJT503',
#   'SJT601',
#   'TT112',
#   'SJT222',
#   'TT434A',
#   'TT434',
#   'TT504',
#   'TT531A',
#   'CBMR101',
#   'SJT205',
#   'CBMR301',
#   'SJT211A',
#   'CBMR402',
#   'SJT109',
#   'SJT114',
#   'SJT115',
#   'SJT118',
#   'SJT124',
#   'SJT125',
#   'SJT207',
#   'SJT126',
#   'SJT202',
#   'SJT204',
#   'SJT207A',
#   'MB226',
#   'MB214',
#   'GDN107',
#   'MB309',
#   'MB225',
#   'PLB622',
#   'PLB509',
#   'SMV109',
#   'PLB504',
#   'PLB519',
#   'PLB522',
#   'MB227',
#   'MGB303',
#   'SJT308',
#   'TT331'],
#  ['4',
#   'SJT617',
#   'SMV116',
#   'SMV220',
#   'SMV219',
#   'SMV111',
#   'SMV214',
#   'SMV109',
#   'SMV128',
#   'SMV218',
#   'CDMM105',
#   'CDMM302',
#   'CDMM301',
#   'SMVG11',
#   'SMV101',
#   'SMV102',
#   'SMVG10',
#   'SJT514',
#   'SJT405',
#   'SJT423',
#   'SJT513',
#   'SJT522',
#   'SJT501',
#   'MGB 303',
#   'MGB106',
#   'MGB201',
#   'MGB304',
#   'SJT601',
#   'MB218',
#   'SJT311A',
#   'SJT424',
#   'MGB110',
#   'SJT521',
#   'SJT323',
#   'MGB305',
#   'SJT404',
#   'SJT508',
#   'MB219',
#   'SJT322',
#   'MGB202',
#   'SJT401',
#   'SJT409',
#   'MGB105',
#   'SJT421',
#   'MGB108',
#   'MB214',
#   'SJT402',
#   'SJT422',
#   'TT112',
#   'TT423',
#   'TT414',
#   'CBMR403',
#   'MGB111',
#   'TT630',
#   'TT631',
#   'CBMR101',
#   'CBMR402',
#   'CBMR301',
#   'MGB208',
#   'TT413',
#   'TT424',
#   'TT415',
#   'TT434A',
#   'TT504',
#   'TT619',
#   'TT523',
#   'TT524',
#   'SJT109',
#   'SJT113',
#   'SJT114',
#   'SJT126',
#   'SJT127',
#   'SJT807',
#   'SJT201',
#   'SJT205',
#   'SJT207',
#   'SJT207A',
#   'SJT208',
#   'SJT211',
#   'SJT211A',
#   'SJT215',
#   'SJT221',
#   'SJT222',
#   'SJT224',
#   'GDN128',
#   'CDMM303',
#   'MB225',
#   'MB226',
#   'MB227',
#   'MB305A',
#   'MB309',
#   'SMV234',
#   'GDN129',
#   'SJT308',
#   'SJT315',
#   'TT531A',
#   'SJT403',
#   'SJT505',
#   'SJT415',
#   'SMV217',
#   'SJT324',
#   'SJT602',
#   'SJT311'],
#  ['5',
#   'SJT617',
#   'SMV116',
#   'SMV220',
#   'SMV219',
#   'SMV111',
#   'SMV109',
#   'SMV128',
#   'CDMM105',
#   'CDMM302',
#   'SMVG11',
#   'SJT514',
#   'SJT405',
#   'SJT423',
#   'SJT513',
#   'SJT522',
#   'SJT501',
#   'MGB 303',
#   'MGB106',
#   'MGB201',
#   'MGB304',
#   'SJT601',
#   'MB218',
#   'SJT521',
#   'SJT323',
#   'MGB305',
#   'SJT404',
#   'SJT508',
#   'MB219',
#   'SJT322',
#   'MGB202',
#   'SJT401',
#   'SJT409',
#   'MGB105',
#   'TT423',
#   'TT414',
#   'CBMR403',
#   'TT304',
#   'TT630',
#   'TT631',
#   'CBMR101',
#   'CBMR402',
#   'CBMR301',
#   'TT504',
#   'TT523',
#   'TT524',
#   'SJT109',
#   'SJT113',
#   'SJT114',
#   'SJT126',
#   'SJT127',
#   'SJT807',
#   'SJT201',
#   'SJT205',
#   'SJT207',
#   'SJT207A',
#   'SJT208',
#   'SJT211',
#   'SJT211A',
#   'SJT215',
#   'SJT221',
#   'SJT222',
#   'SJT224',
#   'GDN128',
#   'CDMM303',
#   'MB225',
#   'MB226',
#   'MB227',
#   'MB305A',
#   'MB309',
#   'SMV234',
#   'GDN129',
#   'SJT308',
#   'SJT403',
#   'SJT505',
#   'SJT415',
#   'SMV217',
#   'SJT324',
#   'SJT602'],
#  ['6',
#   'SJT415',
#   'SJT401',
#   'SJT807',
#   'SMV112',
#   'SMV116',
#   'SMV111',
#   'SMV218',
#   'SMV214',
#   'SMV217',
#   'CDMM105',
#   'CDMM302',
#   'CDMM303',
#   'SMV128',
#   'CDMM301',
#   'SMV101',
#   'SMV102',
#   'SJT305',
#   'SJT403',
#   'SJT404',
#   'SJT421',
#   'SJT423',
#   'SJT508',
#   'SJT513',
#   'SJT409',
#   'SJT324',
#   'SJT224',
#   'SJT424',
#   'SJT504',
#   'SJT311A',
#   'SJT501',
#   'SJT505',
#   'SJT521',
#   'SJT405',
#   'SJT402',
#   'SJT503',
#   'SJT514',
#   'SJT322',
#   'SJT422',
#   'TT424',
#   'TT434',
#   'TT434A',
#   'TT523',
#   'TT531A',
#   'TT630',
#   'CBMR101',
#   'CBMR301',
#   'CBMR402',
#   'TT631',
#   'TT415',
#   'TT423',
#   'TT414',
#   'CBMR403',
#   'TT504',
#   'SJT208',
#   'SJT109',
#   'SJT113',
#   'SJT114',
#   'SJT115',
#   'SJT118',
#   'SJT124',
#   'SJT125',
#   'SJT127',
#   'SJT201',
#   'SJT112',
#   'SJT202',
#   'SJT203',
#   'SJT204',
#   'SJT205',
#   'SJT207',
#   'SJT207A',
#   'SJT211',
#   'MB305A',
#   'MB214',
#   'MB309',
#   'MB218',
#   'MB219',
#   'MB224',
#   'MB225',
#   'MB226',
#   'SJT222',
#   'MGB 303',
#   'MB312',
#   'MB227',
#   'MB311',
#   'MB309A',
#   'PLB504',
#   'SJT315',
#   'SJT221',
#   'SMVG10',
#   'SMV109',
#   'SJT211A',
#   'SMVG11',
#   'TT619',
#   'SJT126',
#   'SJT323',
#   'SJT303',
#   'SJT215',
#   'SJT311'],
#  ['7',
#   'SJT415',
#   'SJT401',
#   'SJT807',
#   'SMV112',
#   'SMV116',
#   'SMV111',
#   'SMV218',
#   'SMV217',
#   'CDMM105',
#   'CDMM302',
#   'CDMM303',
#   'SMV128',
#   'SMV102',
#   'SJT305',
#   'SJT403',
#   'SJT404',
#   'SJT421',
#   'SJT423',
#   'SJT508',
#   'SJT513',
#   'SJT409',
#   'SJT424',
#   'SJT504',
#   'SJT311A',
#   'SJT501',
#   'SJT505',
#   'SJT521',
#   'SJT405',
#   'TT424',
#   'TT434',
#   'TT434A',
#   'TT523',
#   'TT304',
#   'TT531A',
#   'TT630',
#   'CBMR101',
#   'CBMR301',
#   'CBMR402',
#   'TT631',
#   'CBMR403',
#   'TT504',
#   'SJT208',
#   'SJT113',
#   'SJT114',
#   'SJT115',
#   'SJT118',
#   'SJT124',
#   'SJT125',
#   'SJT127',
#   'SJT112',
#   'SJT202',
#   'SJT203',
#   'SJT204',
#   'SJT205',
#   'SJT207',
#   'SJT207A',
#   'SJT211',
#   'MB305A',
#   'MB214',
#   'MB309',
#   'MB218',
#   'MB219',
#   'MB224',
#   'MB225',
#   'MB226',
#   'SJT222',
#   'MGB 303',
#   'MB312',
#   'MB227',
#   'MB311',
#   'MB309A',
#   'PLB504',
#   'SJT602',
#   'SJT323',
#   'SJT303'],
#  ['8',
#   'SJT617',
#   'MB214',
#   'SJT508',
#   'SJT513',
#   'SJT514',
#   'SJT521',
#   'SJT522',
#   'SJT401',
#   'SJT402',
#   'SJT403',
#   'SJT404',
#   'SJT112',
#   'SJT113',
#   'SJT405',
#   'SJT409',
#   'SJT315',
#   'SJT415',
#   'MB218',
#   'MB219',
#   'MB224',
#   'SMV217',
#   'SMV109',
#   'SMV116',
#   'SMV128',
#   'SMV209',
#   'SMV219',
#   'SMV220',
#   'SMV234',
#   'SMV218',
#   'SMV320',
#   'CDMM105',
#   'CDMM303',
#   'CDMM301',
#   'CDMM302',
#   'SMV102',
#   'SMV101',
#   'SJT421',
#   'MGB304',
#   'MGB106',
#   'SJT323',
#   'SJT311',
#   'MGB305',
#   'SJT311A',
#   'SJT505',
#   'MGB 303',
#   'SJT601',
#   'MGB303',
#   'TT206',
#   'TT504',
#   'TT619',
#   'MB309',
#   'SJT807',
#   'SJT324',
#   'SJT501',
#   'SJT423',
#   'MGB202',
#   'SJT308',
#   'MB311',
#   'SJT422',
#   'SJT424',
#   'MB227',
#   'MB305A',
#   'MGB207',
#   'SJT322',
#   '519',
#   'MGB201',
#   'MGB110',
#   'MB225',
#   'TT424',
#   'TT423',
#   'TT434A',
#   'MB226',
#   'TT434',
#   'TT531A',
#   'TT630',
#   'TT301',
#   'TT302',
#   'TT621A',
#   'TT631',
#   'TT207',
#   'TT303',
#   'CBMR403',
#   'CBMR101',
#   'CBMR301',
#   'CBMR402',
#   'SJT109',
#   'SJT114',
#   'SJT126',
#   'SJT201',
#   'SJT204',
#   'SJT205',
#   'SJT224',
#   'SJT207A',
#   'SJT208',
#   'SJT222',
#   'SJT211A',
#   'SJT215',
#   'SJT221',
#   'SJT207',
#   'GDN129',
#   'PLB519',
#   'GDN107',
#   'GDN128',
#   'MB312',
#   'CDMM304',
#   'PLB523',
#   'PLB504',
#   'PLB509',
#   'PLB522',
#   'PLB619',
#   'MB309A',
#   'TT524',
#   'TT523',
#   'SMVG11',
#   'SMVG10'],
#  ['9',
#   'SJT302',
#   'SJT617',
#   'MB214',
#   'SJT508',
#   'SJT513',
#   'SJT514',
#   'SJT521',
#   'SJT522',
#   'SJT401',
#   'SJT402',
#   'SJT403',
#   'SJT404',
#   'SJT112',
#   'SJT113',
#   'SJT405',
#   'SJT409',
#   'SJT315',
#   'SJT415',
#   'MB218',
#   'MB219',
#   'MB224',
#   'SJT215',
#   'TT630',
#   'TT301',
#   'SJT224',
#   'SMV217',
#   'SMV109',
#   'SMV116',
#   'SMV128',
#   'SMV209',
#   'SMV320',
#   'CDMM105',
#   'CDMM303',
#   'CDMM301',
#   'CDMM302',
#   'SMV102',
#   'SMV101',
#   'SJT421',
#   'MGB304',
#   'MGB106',
#   'SJT323',
#   'MGB305',
#   'SJT311A',
#   'SJT505',
#   'MGB 303',
#   'SJT601',
#   'MGB303',
#   'TT206',
#   'TT504',
#   'TT619',
#   'MB309',
#   'SJT807',
#   'SJT501',
#   'SJT423',
#   'SJT308',
#   'MB311',
#   'SJT303',
#   'SJT422',
#   'SJT424',
#   'MB227',
#   'MB305A',
#   'MGB207',
#   'SJT322',
#   '519',
#   'MGB201',
#   'TT424',
#   'TT423',
#   'MB226',
#   'TT434',
#   'TT302',
#   'TT207',
#   'TT303',
#   'CBMR101',
#   'CBMR301',
#   'CBMR402',
#   'SJT109',
#   'SJT114',
#   'SJT126',
#   'SJT201',
#   'SJT204',
#   'SJT205',
#   'SJT207A',
#   'SJT221',
#   'SJT207',
#   'GDN129',
#   'PLB519',
#   'GDN107',
#   'GDN128',
#   'MB312',
#   'CDMM304',
#   'PLB523',
#   'PLB504',
#   'PLB509',
#   'PLB522',
#   'PLB619'],
#  ['10',
#   'MB214',
#   'SJT421',
#   'SJT505',
#   'SJT508',
#   'SJT513',
#   'SJT514',
#   'SJT521',
#   'SJT522',
#   'SJT401',
#   'SJT402',
#   'SJT404',
#   'SJT403',
#   'SJT112',
#   'SJT405',
#   'MB218',
#   'MB224',
#   'MB225',
#   'SJT617',
#   'SMV217',
#   'SMV220',
#   'SMV112',
#   'SMV218',
#   'SMV219',
#   'SMV128',
#   'CDMM301',
#   'CDMM105',
#   'CDMM302',
#   'SJT224',
#   'SJT504',
#   'SJT423',
#   'SJT315',
#   'SJT422',
#   'SJT415',
#   'SJT202',
#   'SJT807',
#   'SJT203',
#   'SJT222',
#   'SJT308',
#   'SJT409',
#   'SJT501',
#   'SJT311',
#   'SJT303',
#   'SJT324',
#   'SJT322',
#   'SJT424',
#   'SJT113',
#   'SJT207',
#   'SJT221',
#   'SJT323',
#   'SJT311A',
#   'TT112',
#   'TT523',
#   'TT434',
#   'TT434A',
#   'TT424',
#   'TT208',
#   'CBMR101',
#   'TT301',
#   'TT302',
#   'TT531A',
#   'TT207',
#   'TT423',
#   'CBMR301',
#   'TT630',
#   'SJT109',
#   'SJT114',
#   'SJT115',
#   'SJT204',
#   'SJT118',
#   'SJT124',
#   'SJT127',
#   'SJT207A',
#   'SJT205',
#   'SJT125',
#   'SJT126',
#   'SJT211A',
#   'SJT208',
#   'MB312',
#   'MB219',
#   'MB305A',
#   'MB309',
#   'PLB519',
#   'CDMM303',
#   'MB311',
#   'PLB522',
#   'PLB523',
#   'MB226',
#   'MB227',
#   'SJT201',
#   'SJT305',
#   'SMV109',
#   'SJT211',
#   'SJT215',
#   'TT331',
#   'SMV234',
#   'TT504'],
#  ['11',
#   'MB214',
#   'SJT421',
#   'SJT505',
#   'SJT508',
#   'SJT513',
#   'SJT514',
#   'SJT521',
#   'SJT522',
#   'SJT401',
#   'SJT402',
#   'SJT404',
#   'SJT403',
#   'SJT112',
#   'SJT405',
#   'MB218',
#   'MB224',
#   'MB225',
#   'SJT617',
#   'TT423',
#   'SJT204',
#   'TT302',
#   'SMV116',
#   'SMV217',
#   'SMV220',
#   'SMV112',
#   'SMV218',
#   'CDMM301',
#   'CDMM105',
#   'SJT224',
#   'SJT504',
#   'SJT423',
#   'SJT315',
#   'SJT422',
#   'SJT415',
#   'SJT202',
#   'SJT807',
#   'SJT203',
#   'SJT222',
#   'SJT308',
#   'SJT501',
#   'SJT303',
#   'SJT324',
#   'SJT322',
#   'SJT424',
#   'SJT113',
#   'SJT207',
#   'SJT221',
#   'SJT323',
#   'TT112',
#   'TT523',
#   'TT434',
#   'TT434A',
#   'TT424',
#   'CBMR101',
#   'TT206',
#   'TT301',
#   'TT531A',
#   'TT207',
#   'CBMR301',
#   'TT630',
#   'SJT109',
#   'SJT114',
#   'SJT115',
#   'SJT118',
#   'SJT126',
#   'SJT211A',
#   'SJT208',
#   'MB312',
#   'MB219',
#   'MB305A',
#   'MB309',
#   'PLB519',
#   'CDMM303',
#   'MB311',
#   'PLB522',
#   'PLB523',
#   'MB226',
#   'MB227',
#   'SJT201',
#   'SJT602',
#   'TT504'],
#  ['12',
#   'SJT322',
#   'SJT315',
#   'SJT208',
#   'SJT211A',
#   'SJT211',
#   'SJT215',
#   'SJT221',
#   'SJT222',
#   'SJT401',
#   'SJT402',
#   'SJT403',
#   'SJT404',
#   'SJT405',
#   'SJT308',
#   'SJT324',
#   'SJT311',
#   'SJT311A',
#   'SJT323',
#   'SMV109',
#   'CDMM105',
#   'SMV116',
#   'TT207',
#   'TT208',
#   'MB214',
#   'TT630',
#   'TT631',
#   'MB218',
#   'TT531A',
#   'MB219',
#   'MB224',
#   'MB225',
#   'SJT224',
#   'SJT127',
#   'SJT505',
#   'SJT514',
#   'SJT508',
#   'SJT521',
#   'SJT513',
#   'SJT522',
#   'MB226',
#   'SMV128',
#   'MB227',
#   'SMV217',
#   'TT424',
#   'TT423',
#   'TT434',
#   'TT303',
#   'SJT409',
#   'SJT415',
#   'SJT421',
#   'SMV220',
#   'SMV234',
#   'SMV209',
#   'SMV218',
#   'SMV219',
#   'CDMM301',
#   'SMV101',
#   'SMV102',
#   'SJT423',
#   'MGB304',
#   'MGB305',
#   'SJT601',
#   'SJT202',
#   'SJT207A',
#   'SJT422',
#   'MGB105',
#   'MGB202',
#   'SJT807',
#   'SJT501',
#   'MGB106',
#   'SJT424',
#   'MGB201',
#   'TT413',
#   'TT415',
#   'TT414',
#   'TT504',
#   'TT434A',
#   'TT301',
#   'TT302',
#   'CBMR101',
#   'CBMR301',
#   'CBMR402',
#   'CBMR403',
#   'SJT207',
#   'SJT109',
#   'SJT112',
#   'SJT114',
#   'SJT126',
#   'SJT201',
#   'SJT205',
#   'MB305A',
#   'GDN129',
#   'MB312',
#   'PLB522',
#   'MB309A',
#   'GDN128',
#   'MB309',
#   'MB311',
#   'PLB523',
#   'PLB509',
#   'MGB207',
#   'MGB 303',
#   'TT524',
#   'TT206',
#   'SMV313',
#   'SMVG10',
#   'SJT118'],
#  ['13',
#   'SJT322',
#   'SJT315',
#   'SJT208',
#   'SJT211A',
#   'SJT211',
#   'SJT215',
#   'SJT221',
#   'SJT222',
#   'SJT401',
#   'SJT402',
#   'SJT403',
#   'SJT404',
#   'SJT405',
#   'SJT308',
#   'SJT324',
#   'SJT311',
#   'SJT311A',
#   'SJT323',
#   'SMV109',
#   'CDMM105',
#   'SMV116',
#   'TT207',
#   'TT208',
#   'MB214',
#   'TT630',
#   'TT631',
#   'MB218',
#   'TT531A',
#   'MB219',
#   'MB224',
#   'MB225',
#   'SJT224',
#   'SJT127',
#   'SJT505',
#   'SJT514',
#   'SJT508',
#   'SJT521',
#   'SJT513',
#   'SJT522',
#   'MB226',
#   'SMV128',
#   'MB227',
#   'SMV217',
#   'TT424',
#   'TT423',
#   'TT434',
#   'TT303',
#   'SJT409',
#   'SJT415',
#   'SJT421',
#   'SJT202',
#   'SMV220',
#   'SMV234',
#   'SMV218',
#   'SMV219',
#   'SMV102',
#   'SJT423',
#   'MGB304',
#   'MGB305',
#   'SJT207A',
#   'SJT807',
#   'SJT501',
#   'MGB106',
#   'SJT424',
#   'MGB201',
#   'TT504',
#   'TT434A',
#   'TT206',
#   'TT301',
#   'TT302',
#   'CBMR101',
#   'CBMR301',
#   'CBMR402',
#   'CBMR403',
#   'SJT207',
#   'SJT109',
#   'SJT112',
#   'SJT114',
#   'SJT126',
#   'SJT201',
#   'SJT205',
#   'GDN129',
#   'MB312',
#   'PLB522',
#   'GDN128',
#   'MB309',
#   'PLB509',
#   'MGB207',
#   'SMVG10',
#   'SJT118'],
#  ['14',
#   'SJT322',
#   'SJT315',
#   'SJT208',
#   'SJT215',
#   'SJT211A',
#   'SJT211',
#   'SJT221',
#   'SJT222',
#   'SJT401',
#   'SJT402',
#   'SJT403',
#   'SJT404',
#   'SJT405',
#   'SJT308',
#   'SJT311',
#   'SJT324',
#   'SJT311A',
#   'SJT323',
#   'SMV109',
#   'CDMM105',
#   'SMV116',
#   'TT207',
#   'TT208',
#   'MB214',
#   'TT630',
#   'TT631',
#   'MB218',
#   'MB219',
#   'TT531A',
#   'MB224',
#   'MB225',
#   'SJT224',
#   'SJT127',
#   'SJT505',
#   'SJT514',
#   'SJT508',
#   'SJT521',
#   'SJT513',
#   'SJT522',
#   'SMV128',
#   'MB226',
#   'MB227',
#   'MB305A',
#   'TT424',
#   'TT423',
#   'TT434',
#   'TT303',
#   'SJT409',
#   'SJT415',
#   'SMV112',
#   'SMV220',
#   'SMV219',
#   'SMV218',
#   'SMV217',
#   'CDMM301',
#   'CDMM303',
#   'SMV102',
#   'SMV101',
#   'SJT807',
#   'SJT423',
#   'SJT504',
#   'SJT115',
#   'SJT125',
#   'SJT303',
#   'SJT202',
#   'SJT203',
#   'SJT501',
#   'SJT305',
#   'SJT421',
#   'SJT422',
#   'SJT503',
#   'TT414',
#   'TT112',
#   'TT413',
#   'TT434A',
#   'TT206',
#   'TT301',
#   'TT302',
#   'CBMR101',
#   'CBMR301',
#   'CBMR403',
#   'CBMR402',
#   'SJT124',
#   'SJT118',
#   'SJT109',
#   'SJT112',
#   'SJT113',
#   'SJT114',
#   'GDN107',
#   'MB309',
#   'CDMM302',
#   'GDN129',
#   'PLB519',
#   'MB312',
#   'MB311',
#   'MB309A',
#   'SMV234',
#   'GDN128',
#   'PLB522',
#   'SJT617',
#   'TT415'],
#  ['15',
#   'SJT322',
#   'SJT315',
#   'SJT208',
#   'SJT215',
#   'SJT211A',
#   'SJT211',
#   'SJT221',
#   'SJT222',
#   'SJT401',
#   'SJT402',
#   'SJT403',
#   'SJT404',
#   'SJT405',
#   'SJT308',
#   'SJT311',
#   'SJT324',
#   'SJT311A',
#   'SJT323',
#   'SMV109',
#   'CDMM105',
#   'SMV116',
#   'TT207',
#   'TT208',
#   'MB214',
#   'TT630',
#   'TT631',
#   'MB218',
#   'MB219',
#   'TT531A',
#   'MB224',
#   'MB225',
#   'SJT224',
#   'SJT127',
#   'SJT505',
#   'SJT514',
#   'SJT508',
#   'SJT521',
#   'SJT513',
#   'SJT522',
#   'SMV128',
#   'MB226',
#   'MB227',
#   'MB305A',
#   'TT424',
#   'TT423',
#   'TT434',
#   'TT303',
#   'SJT409',
#   'SJT415',
#   'SJT203',
#   'TT621',
#   'TT619',
#   'TT524',
#   'SMV112',
#   'SMV220',
#   'SMV219',
#   'SMV217',
#   'SMV102',
#   'SJT423',
#   'SJT115',
#   'SJT125',
#   'SJT303',
#   'SJT202',
#   'SJT305',
#   'SJT421',
#   'SJT422',
#   'SJT503',
#   'TT112',
#   'TT434A',
#   'TT206',
#   'TT301',
#   'TT302',
#   'CBMR101',
#   'CBMR301',
#   'CBMR402',
#   'SJT124',
#   'SJT112',
#   'SJT114',
#   'GDN107',
#   'MB309',
#   'GDN129',
#   'PLB519',
#   'MB312',
#   'MB311',
#   'MB309A',
#   'SMV234',
#   'GDN128',
#   'PLB522',
#   'SJT617'],
#  ['16',
#   'SJT201',
#   'SJT202',
#   'SJT505',
#   'SJT508',
#   'SJT513',
#   'SJT204',
#   'SJT207',
#   'SMV101',
#   'TT531A',
#   'SMV102',
#   'SJT203',
#   'SMV104',
#   'SJT205',
#   'MB110',
#   'SJT207A',
#   'TT423',
#   'SJT401',
#   'MB111',
#   'SJT402',
#   'MB124',
#   'SJT403',
#   'TT424',
#   'SJT404',
#   'MB211',
#   'TT621',
#   'MB212',
#   'SJT405',
#   'TT630',
#   'MB213',
#   'SJT323',
#   'TT725',
#   'SJT409',
#   'TT631',
#   'SJT415',
#   'SJT421',
#   'SJT514',
#   'SJT422',
#   'SJT521',
#   'SJT423',
#   'SJT522',
#   'SJT424',
#   'SJT324',
#   'SMV219',
#   'SMV116',
#   'SMV128',
#   'SMV217',
#   'SMVG10',
#   'SMV214',
#   'SMV218',
#   'CDMM105',
#   'CDMM301',
#   'CDMM302',
#   'SMV234',
#   'SMV220',
#   'SMV111',
#   'MGB303',
#   'MB312',
#   'SJT311',
#   'SJT311A',
#   'MGB110',
#   'MGB304',
#   'MGB106',
#   'MB219',
#   'MGB202',
#   'SJT501',
#   'MGB105',
#   'MGB201',
#   'SJT601',
#   'MB218',
#   'SJT602',
#   'MGB 303',
#   'SJT322',
#   'TT434A',
#   'SJT315',
#   'MB214',
#   'MGB305',
#   'CBMR301',
#   'MGB111',
#   'CBMR402',
#   'CBMR403',
#   'TT504',
#   'TT523',
#   'TT524',
#   'TT619',
#   'CBMR101',
#   'SJT113',
#   'SJT126',
#   'SJT127',
#   'SJT208',
#   'SJT211',
#   'SJT211A',
#   'SJT215',
#   'SJT221',
#   'SJT222',
#   'SJT112',
#   'SJT224',
#   'PLB522',
#   'PLB504',
#   'PLB509',
#   'MB226',
#   'MB227',
#   'MB305A',
#   'MB309',
#   'MB311',
#   'MB225',
#   'MB309A',
#   'MB224',
#   'SJT308',
#   'TT434',
#   'SMV109',
#   'TT331'],
#  ['17',
#   'TT331',
#   'MB218',
#   'MB219',
#   'MB225',
#   'MB227',
#   'MB305A',
#   'SMV126',
#   'SMV130',
#   'SMV214',
#   'SMV218',
#   'SMV220',
#   'SMV235',
#   'SMV320',
#   'SJT201',
#   'SJT202',
#   'SJT505',
#   'SJT508',
#   'SJT513',
#   'SJT204',
#   'SJT207',
#   'SMV101',
#   'TT531A',
#   'SMV102',
#   'SJT203',
#   'SMV104',
#   'SJT205',
#   'MB110',
#   'SJT207A',
#   'TT423',
#   'SJT401',
#   'MB111',
#   'SJT402',
#   'MB124',
#   'SJT403',
#   'TT424',
#   'SJT404',
#   'MB211',
#   'TT621',
#   'MB212',
#   'SJT405',
#   'TT630',
#   'MB213',
#   'SJT323',
#   'TT725',
#   'SJT409',
#   'TT631',
#   'SJT415',
#   'SJT421',
#   'SJT514',
#   'SJT422',
#   'SJT521',
#   'SJT423',
#   'SJT522',
#   'SJT424',
#   'SJT324',
#   'SJT302',
#   'TT304',
#   'SMV219',
#   'SMV116',
#   'SMV128',
#   'SMV217',
#   'SMVG10',
#   'CDMM105',
#   'CDMM301',
#   'CDMM302',
#   'SMV234',
#   'SMV111',
#   'MB312',
#   'SJT304',
#   'MGB304',
#   'MGB106',
#   'MGB202',
#   'SJT602',
#   'MGB 303',
#   'SJT322',
#   'TT434',
#   'TT434A',
#   'SJT315',
#   'MGB305',
#   'CBMR301',
#   'CBMR402',
#   'CBMR403',
#   'TT504',
#   'TT523',
#   'TT524',
#   'TT619',
#   'CBMR101',
#   'SJT113',
#   'SJT222',
#   'SJT126',
#   'SJT127',
#   'SJT208',
#   'SJT211',
#   'SJT224',
#   'SJT211A',
#   'SJT215',
#   'PLB522',
#   'PLB504',
#   'MB214',
#   'MB226',
#   'MB309',
#   'MB311',
#   'MB309A',
#   'MB224',
#   'SJT308',
#   'SMV109'],
#  ['18',
#   'SJT201',
#   'SJT202',
#   'SJT505',
#   'SJT508',
#   'SJT513',
#   'SJT204',
#   'SJT207',
#   'SMV101',
#   'TT531A',
#   'SMV102',
#   'SJT203',
#   'SMV104',
#   'SJT205',
#   'MB110',
#   'SJT207A',
#   'SJT401',
#   'TT423',
#   'MB111',
#   'SJT402',
#   'MB124',
#   'SJT403',
#   'TT424',
#   'MB211',
#   'SJT404',
#   'TT621',
#   'MB212',
#   'SJT405',
#   'TT630',
#   'MB213',
#   'SJT323',
#   'TT725',
#   'SJT409',
#   'TT631',
#   'SJT415',
#   'SJT421',
#   'SJT514',
#   'SJT521',
#   'SJT422',
#   'SJT522',
#   'SJT423',
#   'SJT424',
#   'SJT324',
#   'SMV109',
#   'SMV112',
#   'SMV116',
#   'SMV218',
#   'SMV214',
#   'SMV128',
#   'CDMM105',
#   'CDMM303',
#   'SMV219',
#   'SMV220',
#   'SMVG10',
#   'SJT501',
#   'SJT322',
#   'SJT223',
#   'SJT308',
#   'SJT315',
#   'SJT504',
#   'SJT311',
#   'SJT311A',
#   'SJT502',
#   'SJT503',
#   'SJT224',
#   'SJT601',
#   'MB214',
#   'SJT222',
#   'TT434A',
#   'TT434',
#   'TT530',
#   'CBMR101',
#   'CBMR301',
#   'CBMR403',
#   'CBMR402',
#   'TT504',
#   'TT523',
#   'TT524',
#   'TT303',
#   'SJT109',
#   'SJT112',
#   'SJT114',
#   'SJT113',
#   'SJT115',
#   'SJT118',
#   'SJT124',
#   'SJT125',
#   'SJT126',
#   'SJT127',
#   'SJT208',
#   'SJT211',
#   'SJT211A',
#   'SJT215',
#   'MB311',
#   'MB312',
#   'MB219',
#   'MB224',
#   'GDN107',
#   'MB225',
#   'MB226',
#   'MB227',
#   'MB218',
#   'MB309',
#   'PLB509',
#   'TT619',
#   'SJT221'],
#  ['19',
#   'MB218',
#   'MB224',
#   'MB225',
#   'MB227',
#   'MB305A',
#   'SMV112',
#   'SMV128',
#   'SMV217',
#   'SMV234',
#   'SMV235',
#   'SMV126',
#   'SJT201',
#   'SJT202',
#   'SJT505',
#   'SJT508',
#   'SJT513',
#   'SJT204',
#   'SJT207',
#   'SMV101',
#   'TT531A',
#   'SMV102',
#   'SJT203',
#   'SMV104',
#   'SJT205',
#   'MB110',
#   'SJT207A',
#   'SJT401',
#   'TT423',
#   'MB111',
#   'SJT402',
#   'MB124',
#   'SJT403',
#   'TT424',
#   'MB211',
#   'SJT404',
#   'TT621',
#   'MB212',
#   'SJT405',
#   'TT630',
#   'MB213',
#   'SJT323',
#   'TT725',
#   'SJT409',
#   'TT631',
#   'SJT415',
#   'SJT421',
#   'SJT514',
#   'SJT521',
#   'SJT422',
#   'SJT522',
#   'SJT423',
#   'SJT424',
#   'SJT324',
#   'SJT303',
#   'TT304',
#   'SMV109',
#   'SMV116',
#   'SMV218',
#   'CDMM105',
#   'CDMM303',
#   'SMV219',
#   'SMV220',
#   'SMVG10',
#   'SJT322',
#   'SJT315',
#   'SJT601',
#   'MB214',
#   'SJT222',
#   'TT434A',
#   'CBMR101',
#   'TT530',
#   'CBMR301',
#   'CBMR403',
#   'CBMR402',
#   'TT504',
#   'TT523',
#   'TT524',
#   'TT303',
#   'SJT112',
#   'SJT114',
#   'SJT126',
#   'SJT113',
#   'SJT115',
#   'SJT118',
#   'SJT124',
#   'SJT211',
#   'SJT211A',
#   'SJT215',
#   'SJT109',
#   'SJT125',
#   'MB311',
#   'MB219',
#   'GDN107',
#   'MB226',
#   'MB309',
#   'PLB509',
#   'TT619',
#   'SJT221'],
#  ['20',
#   'SMV109',
#   'MB214',
#   'MB218',
#   'TT630',
#   'TT434',
#   'SJT109',
#   'SMV116',
#   'SMV111',
#   'SMV209',
#   'SMV217',
#   'SMV219',
#   'SMV220',
#   'SMV218',
#   'SMV234',
#   'SMV214',
#   'SMV128',
#   'CDMM301',
#   'CDMM303',
#   'CDMM302',
#   'SMV102',
#   'SMV101',
#   'SJT204',
#   'SJT617',
#   'SJT311A',
#   'SJT404',
#   'SJT501',
#   'SJT521',
#   'SJT208',
#   'SJT211',
#   'SJT211A',
#   'SJT215',
#   'SJT221',
#   'SJT222',
#   'SJT224',
#   'SJT402',
#   'SJT308',
#   'SJT323',
#   'SJT403',
#   'SJT401',
#   'SJT409',
#   'SJT422',
#   'SJT423',
#   'SJT504',
#   'SJT505',
#   'SJT508',
#   'SJT513',
#   'SJT807',
#   'SJT522',
#   'MGB201',
#   'MGB106',
#   'MGB 303',
#   'SJT415',
#   'SJT421',
#   'MGB110',
#   'SJT405',
#   'SJT424',
#   'TT413',
#   'TT424',
#   'TT434A',
#   'TT414',
#   'TT415',
#   'TT423',
#   'TT301',
#   'TT302',
#   'TT303',
#   'TT531A',
#   'TT631',
#   'CBMR101',
#   'CBMR301',
#   'CBMR402',
#   'CBMR403',
#   'TT334',
#   'SJT203',
#   'SJT207',
#   'SJT207A',
#   'SJT112',
#   'SJT113',
#   'SJT114',
#   'SJT126',
#   'SJT201',
#   'SJT205',
#   'SJT127',
#   'SMVG11',
#   'MB225',
#   'MB226',
#   'MB224',
#   'MB305A',
#   'PLB509',
#   'MB227',
#   'MB309A',
#   'GDN129',
#   'MB309',
#   'CDMM105',
#   'MB311',
#   'CDMM304',
#   'GDN128',
#   'MB219',
#   'MGB202',
#   'PLB622',
#   'MB312',
#   'PLB519',
#   'SJT322',
#   'SMVG10',
#   'TT523',
#   'SJT315',
#   'TT504',
#   'SJT324',
#   'TT524',
#   'SJT311',
#   'TT206'],
#  ['21',
#   'SMV109',
#   'MB214',
#   'MB218',
#   'TT630',
#   'TT434',
#   'SJT109',
#   'TT621',
#   'TT619',
#   'SMV111',
#   'SMV209',
#   'SMV217',
#   'SMV219',
#   'SMV220',
#   'SMV218',
#   'SMV234',
#   'CDMM303',
#   'SMV101',
#   'SMV102',
#   'MGB110',
#   'SJT405',
#   'SJT424',
#   'TT413',
#   'TT424',
#   'TT434A',
#   'TT423',
#   'TT414',
#   'TT301',
#   'TT302',
#   'TT303',
#   'TT531A',
#   'TT631',
#   'SJT207',
#   'SJT207A',
#   'SJT112',
#   'SJT126',
#   'SJT201',
#   'SJT205',
#   'SJT127',
#   'SMVG11',
#   'MB225',
#   'MB226',
#   'MB305A',
#   'PLB509',
#   'MB224',
#   'MB311',
#   'MB309A',
#   'CDMM105',
#   'SJT807',
#   'MB227',
#   'MB219',
#   'SMV112',
#   'SMV116',
#   'PLB519',
#   'SJT315',
#   'TT504',
#   'TT524',
#   'TT206'],
#  ['22',
#   'SMV109',
#   'MB214',
#   'TT630',
#   'TT434',
#   'SJT415',
#   'SJT522',
#   'SMV217',
#   'SMV111',
#   'SMV219',
#   'SMV218',
#   'SMV128',
#   'SMV214',
#   'SMV116',
#   'CDMM304',
#   'CDMM301',
#   'CDMM105',
#   'SMV102',
#   'SJT423',
#   'SJT223',
#   'SJT305',
#   'SJT401',
#   'SJT311A',
#   'SJT405',
#   'SJT501',
#   'SJT208',
#   'SJT211',
#   'SJT211A',
#   'SJT125',
#   'SJT126',
#   'SJT222',
#   'SJT308',
#   'SJT403',
#   'SJT402',
#   'SJT409',
#   'SJT323',
#   'SJT404',
#   'SJT201',
#   'SJT421',
#   'SJT221',
#   'SJT202',
#   'SJT504',
#   'SJT503',
#   'SJT505',
#   'SJT422',
#   'SJT508',
#   'SJT315',
#   'SJT322',
#   'SJT424',
#   'SJT324',
#   'TT434A',
#   'TT414',
#   'TT415',
#   'TT424',
#   'CBMR101',
#   'TT301',
#   'TT302',
#   'TT303',
#   'TT621',
#   'TT504',
#   'TT207',
#   'TT208',
#   'TT331',
#   'TT631',
#   'TT413',
#   'TT423',
#   'SJT112',
#   'SJT113',
#   'SJT114',
#   'SJT109',
#   'SJT115',
#   'SJT118',
#   'SJT124',
#   'MB225',
#   'MB226',
#   'MB227',
#   'MB218',
#   'MB305A',
#   'MB309',
#   'MB312',
#   'MB311',
#   'MB309A',
#   'MB224',
#   'MB219',
#   'GDN107',
#   'GDN129',
#   'GDN128',
#   'PLB523',
#   'MGB105',
#   'MGB106',
#   'CDMM303',
#   'TT524',
#   'SMVG11',
#   'SJT207A'],
#  ['23',
#   'SMV109',
#   'MB214',
#   'TT630',
#   'TT434',
#   'SJT415',
#   'TT619',
#   'SMV217',
#   'SMV111',
#   'SMV219',
#   'SMV218',
#   'SMV128',
#   'CDMM301',
#   'CDMM105',
#   'SMV102',
#   'SJT401',
#   'SJT501',
#   'SJT324',
#   'TT434A',
#   'TT424',
#   'TT206',
#   'TT301',
#   'TT302',
#   'TT303',
#   'TT621',
#   'TT504',
#   'SJT112',
#   'SJT114',
#   'SJT109',
#   'SJT115',
#   'SJT118',
#   'SJT124',
#   'MB225',
#   'MB226',
#   'MB227',
#   'MB305A',
#   'MB309',
#   'MB312',
#   'MB311',
#   'MB309A',
#   'MB218',
#   'MB219',
#   'MB224',
#   'SMV101',
#   'SMV116',
#   'SMVG11',
#   'SJT207A'],
#  ['24',
#   'SJT109',
#   'SJT112',
#   'SJT113',
#   'SJT114',
#   'SJT522',
#   'SJT401',
#   'SMV128',
#   'SMV220',
#   'SMV116',
#   'SMV217',
#   'SMV218',
#   'CDMM105',
#   'CDMM301',
#   'CDMM302',
#   'SMV102',
#   'SMV101',
#   'SMVG11',
#   'SMV219',
#   'SJT311A',
#   'SJT402',
#   'MGB304',
#   'SJT308',
#   'SJT508',
#   'SJT311',
#   'SJT315',
#   'SJT423',
#   'SJT405',
#   'SJT501',
#   'SJT513',
#   'SJT514',
#   'MB214',
#   'MGB303',
#   'SJT504',
#   'SJT323',
#   'SJT403',
#   'SJT324',
#   'SJT404',
#   'MGB 303',
#   'MGB110',
#   'SJT521',
#   'SJT424',
#   'SJT601',
#   'MGB209',
#   'MB219',
#   'MGB207',
#   'MB218',
#   'SJT415',
#   'TT619',
#   'SJT422',
#   'TT524',
#   'SJT409',
#   'SJT505',
#   'MGB208',
#   'TT415',
#   'TT423',
#   'TT434A',
#   'TT424',
#   'TT434',
#   'CBMR402',
#   'TT304',
#   'TT531A',
#   'TT630',
#   'TT631',
#   'CBMR101',
#   'TT301',
#   'TT208',
#   'TT303',
#   'TT530A',
#   'CBMR403',
#   'CBMR301',
#   'TT523',
#   'SJT127',
#   'SJT201',
#   'SJT205',
#   'SJT207',
#   'SJT207A',
#   'SJT208',
#   'SJT211',
#   'SJT211A',
#   'SJT126',
#   'SJT215',
#   'SJT221',
#   'SJT222',
#   'SJT224',
#   'SJT807',
#   'MB227',
#   'MB311',
#   'MB224',
#   'MB225',
#   'GDN128',
#   'MB226',
#   'MB309A',
#   'MB210',
#   'MB312',
#   'SJT322',
#   'SMVG10',
#   'SMV109',
#   'TT504',
#   'TT413',
#   'TT414',
#   'SJT421',
#   'SMV111',
#   'SMV234',
#   'SMV209',
#   'TT206'],
#  ['25',
#   'SJT109',
#   'SJT112',
#   'SJT113',
#   'SJT114',
#   'SJT522',
#   'SJT401',
#   'TT413',
#   'SMV128',
#   'SMV112',
#   'SMV220',
#   'SMV116',
#   'SMV217',
#   'SMV218',
#   'CDMM304',
#   'SMV102',
#   'SMV101',
#   'SMVG11',
#   'SMV219',
#   'SJT402',
#   'SJT505',
#   'MGB304',
#   'SJT308',
#   'SJT508',
#   'SJT311',
#   'SJT315',
#   'SJT423',
#   'SJT405',
#   'SJT501',
#   'SJT513',
#   'SJT514',
#   'MB214',
#   'MGB303',
#   'SJT504',
#   'SJT323',
#   'SJT403',
#   'SJT324',
#   'SJT404',
#   'MGB 303',
#   'MGB110',
#   'SJT521',
#   'SJT424',
#   'SJT601',
#   'MGB209',
#   'MB219',
#   'MGB207',
#   'MB218',
#   'SJT415',
#   'SJT422',
#   'TT524',
#   'SJT409',
#   'MGB208',
#   'TT415',
#   'TT423',
#   'TT424',
#   'TT434',
#   'TT304',
#   'TT531A',
#   'TT301',
#   'TT208',
#   'TT303',
#   'TT530A',
#   'CBMR301',
#   'TT523',
#   'CBMR101',
#   'SJT127',
#   'SJT201',
#   'SJT205',
#   'SJT207A',
#   'SJT208',
#   'SJT211',
#   'SJT211A',
#   'SJT126',
#   'SJT215',
#   'SJT807',
#   'MB311',
#   'MB224',
#   'GDN128',
#   'MB226',
#   'MB309A',
#   'MB210',
#   'MB312',
#   'SMV209',
#   'SJT602',
#   'TT206'],
#  ['26',
#   'SJT109',
#   'SJT112',
#   'SJT113',
#   'SJT324',
#   'SMV111',
#   'TT523',
#   'SMV116',
#   'SMV217',
#   'SMV214',
#   'SMV128',
#   'CDMM304',
#   'CDMM105',
#   'SMV109',
#   'SMV102',
#   'SMV101',
#   'SJT305',
#   'SJT403',
#   'SJT311',
#   'SJT401',
#   'SJT423',
#   'SJT402',
#   'SJT323',
#   'SJT405',
#   'SJT424',
#   'SJT501',
#   'SJT502',
#   'SJT508',
#   'SJT311A',
#   'SJT404',
#   'SJT315',
#   'SJT503',
#   'SJT505',
#   'SJT215',
#   'SJT224',
#   'SJT221',
#   'SJT422',
#   'MB214',
#   'SJT514',
#   'SJT222',
#   'SJT415',
#   'SJT409',
#   'SJT308',
#   'SJT504',
#   'SJT322',
#   'SJT421',
#   'SJT513',
#   'TT112',
#   'TT434A',
#   'TT415',
#   'TT413',
#   'TT414',
#   'TT434',
#   'TT423',
#   'TT424',
#   'TT531A',
#   'TT630',
#   'TT207',
#   'TT208',
#   'TT301',
#   'TT303',
#   'TT530',
#   'CBMR101',
#   'TT206',
#   'TT631',
#   'SJT211A',
#   'SJT114',
#   'SJT115',
#   'SJT118',
#   'SJT124',
#   'SJT807',
#   'SJT125',
#   'SJT127',
#   'SJT201',
#   'SJT202',
#   'SJT126',
#   'SJT203',
#   'SJT204',
#   'SJT205',
#   'SJT211',
#   'SJT208',
#   'SJT207',
#   'GDN107',
#   'MB309',
#   'MB219',
#   'MB224',
#   'MGB105',
#   'MB225',
#   'MB226',
#   'MB311',
#   'MB218',
#   'MB312',
#   'SMVG11',
#   'SMVG10',
#   'SJT207A',
#   'SMV219',
#   'SMV218'],
#  ['27',
#   'SJT109',
#   'SJT112',
#   'SJT113',
#   'SJT324',
#   'SMV116',
#   'SMV214',
#   'SMV128',
#   'CDMM304',
#   'SMV109',
#   'SMV102',
#   'SMV101',
#   'SJT305',
#   'SJT403',
#   'SJT311',
#   'SJT401',
#   'SJT423',
#   'SJT402',
#   'SJT323',
#   'SJT405',
#   'SJT424',
#   'SJT501',
#   'SJT502',
#   'SJT508',
#   'SJT311A',
#   'SJT404',
#   'SJT315',
#   'SJT505',
#   'SJT215',
#   'SJT224',
#   'SJT221',
#   'SJT422',
#   'MB214',
#   'SJT514',
#   'SJT222',
#   'SJT415',
#   'SJT409',
#   'SJT308',
#   'SJT504',
#   'SJT322',
#   'SJT513',
#   'TT434A',
#   'TT415',
#   'TT413',
#   'TT414',
#   'TT423',
#   'TT424',
#   'TT302',
#   'TT301',
#   'TT303',
#   'TT530',
#   'CBMR101',
#   'TT206',
#   'TT631',
#   'SJT211A',
#   'SJT114',
#   'SJT115',
#   'SJT118',
#   'SJT125',
#   'SJT127',
#   'SJT201',
#   'SJT202',
#   'SJT126',
#   'SJT203',
#   'SJT207',
#   'MB219',
#   'MGB105',
#   'MB225',
#   'MB218',
#   'MB312',
#   'SMVG11',
#   'SJT207A']]

# %%
allotment=[['A1','F1','D1','TB1','TG1','A2','F2','D2','TB2','TG2'],
          ['B1','G1','E1','TC1','TAA1','B2','G2','E2','TC2','TAA2'],
          ['C1','A1','F1','V1','V2','C2','A2','F2','TD2','TBB2'],
          ['D1','B1','G1','TE1','TCC1','D2','B2','G2','TE2','TCC2'],
          ['E1','C1','TA1','TF1','TD1','E2','C2','TA2','TF2','TDD2']]
daywise=[]
for i in range(len(allotment)):
    daywise.append([str(i)])

# %%
for i in range(len(allotment)):
    for j in range(len(allotment[i])):
        for k in range(len(slots)):
            if(allotment[i][j]==slots[k]):
                daywise[i].append(classes[k])

# %%
daywise
# Out:
# [['0',
#   ['0',
#    'SJT415',
#    'SJT617',
#    'MB214',
#    'SJT508',
#    'SJT513',
#    'SJT521',
#    'SJT315',
#    'SJT112',
#    'SJT113',
#    'SJT401',
#    'SJT404',
#    'SJT405',
#    'MB218',
#    'MB224',
#    'MB225',
#    'SMVG10',
#    'SMV116',
#    'SMV217',
#    'SMV218',
#    'SMV219',
#    'SMV128',
#    'SMV209',
#    'SMV234',
#    'SMV109',
#    'CDMM105',
#    'CDMM302',
#    'SMV101',
#    'SMV102',
#    'SJT505',
#    'SJT324',
#    'SJT402',
#    'SJT403',
#    'SJT422',
#    'SJT423',
#    'SJT302',
#    'SJT322',
#    'SJT501',
#    'MGB105',
#    'TT630',
#    'MGB201',
#    'MGB110',
#    'MGB305',
#    'MB226',
#    'SJT601',
#    'SJT323',
#    'SJT421',
#    'SJT522',
#    'SJT303',
#    'SJT308',
#    'SJT311A',
#    'MGB 303',
#    'SJT305',
#    'SJT409',
#    'SJT424',
#    'SJT514',
#    'MGB304',
#    'SJT602',
#    'TT434A',
#    'TT424',
#    'TT423',
#    'TT434',
#    'SMV220',
#    'TT335',
#    'TT531A',
#    'TT631',
#    'CBMR101',
#    'CBMR402',
#    'TT619',
#    'CBMR403',
#    'TT504',
#    'TT523',
#    'SJT201',
#    'SJT205',
#    'SJT207',
#    'SJT207A',
#    'SJT208',
#    'SJT211',
#    'SJT211A',
#    'SJT215',
#    'SJT221',
#    'SJT222',
#    'SJT224',
#    'SJT807',
#    'CDMM303',
#    'MB305A',
#    'PLB519',
#    'MB219',
#    'GDN128',
#    'MB227',
#    'PLB509',
#    'GDN129',
#    'PLB504',
#    'PLB522',
#    'MB312',
#    'PLB622',
#    'MB311',
#    'MB309A',
#    'SJT304',
#    'SJT127',
#    'TT524',
#    'SMV320',
#    'SJT311'],
#   ['20',
#    'SMV109',
#    'MB214',
#    'MB218',
#    'TT630',
#    'TT434',
#    'SJT109',
#    'SMV116',
#    'SMV111',
#    'SMV209',
#    'SMV217',
#    'SMV219',
#    'SMV220',
#    'SMV218',
#    'SMV234',
#    'SMV214',
#    'SMV128',
#    'CDMM301',
#    'CDMM303',
#    'CDMM302',
#    'SMV102',
#    'SMV101',
#    'SJT204',
#    'SJT617',
#    'SJT311A',
#    'SJT404',
#    'SJT501',
#    'SJT521',
#    'SJT208',
#    'SJT211',
#    'SJT211A',
#    'SJT215',
#    'SJT221',
#    'SJT222',
#    'SJT224',
#    'SJT402',
#    'SJT308',
#    'SJT323',
#    'SJT403',
#    'SJT401',
#    'SJT409',
#    'SJT422',
#    'SJT423',
#    'SJT504',
#    'SJT505',
#    'SJT508',
#    'SJT513',
#    'SJT807',
#    'SJT522',
#    'MGB201',
#    'MGB106',
#    'MGB 303',
#    'SJT415',
#    'SJT421',
#    'MGB110',
#    'SJT405',
#    'SJT424',
#    'TT413',
#    'TT424',
#    'TT434A',
#    'TT414',
#    'TT415',
#    'TT423',
#    'TT301',
#    'TT302',
#    'TT303',
#    'TT531A',
#    'TT631',
#    'CBMR101',
#    'CBMR301',
#    'CBMR402',
#    'CBMR403',
#    'TT334',
#    'SJT203',
#    'SJT207',
#    'SJT207A',
#    'SJT112',
#    'SJT113',
#    'SJT114',
#    'SJT126',
#    'SJT201',
#    'SJT205',
#    'SJT127',
#    'SMVG11',
#    'MB225',
#    'MB226',
#    'MB224',
#    'MB305A',
#    'PLB509',
#    'MB227',
#    'MB309A',
#    'GDN129',
#    'MB309',
#    'CDMM105',
#    'MB311',
#    'CDMM304',
#    'GDN128',
#    'MB219',
#    'MGB202',
#    'PLB622',
#    'MB312',
#    'PLB519',
#    'SJT322',
#    'SMVG10',
#    'TT523',
#    'SJT315',
#    'TT504',
#    'SJT324',
#    'TT524',
#    'SJT311',
#    'TT206'],
#   ['12',
#    'SJT322',
#    'SJT315',
#    'SJT208',
#    'SJT211A',
#    'SJT211',
#    'SJT215',
#    'SJT221',
#    'SJT222',
#    'SJT401',
#    'SJT402',
#    'SJT403',
#    'SJT404',
#    'SJT405',
#    'SJT308',
#    'SJT324',
#    'SJT311',
#    'SJT311A',
#    'SJT323',
#    'SMV109',
#    'CDMM105',
#    'SMV116',
#    'TT207',
#    'TT208',
#    'MB214',
#    'TT630',
#    'TT631',
#    'MB218',
#    'TT531A',
#    'MB219',
#    'MB224',
#    'MB225',
#    'SJT224',
#    'SJT127',
#    'SJT505',
#    'SJT514',
#    'SJT508',
#    'SJT521',
#    'SJT513',
#    'SJT522',
#    'MB226',
#    'SMV128',
#    'MB227',
#    'SMV217',
#    'TT424',
#    'TT423',
#    'TT434',
#    'TT303',
#    'SJT409',
#    'SJT415',
#    'SJT421',
#    'SMV220',
#    'SMV234',
#    'SMV209',
#    'SMV218',
#    'SMV219',
#    'CDMM301',
#    'SMV101',
#    'SMV102',
#    'SJT423',
#    'MGB304',
#    'MGB305',
#    'SJT601',
#    'SJT202',
#    'SJT207A',
#    'SJT422',
#    'MGB105',
#    'MGB202',
#    'SJT807',
#    'SJT501',
#    'MGB106',
#    'SJT424',
#    'MGB201',
#    'TT413',
#    'TT415',
#    'TT414',
#    'TT504',
#    'TT434A',
#    'TT301',
#    'TT302',
#    'CBMR101',
#    'CBMR301',
#    'CBMR402',
#    'CBMR403',
#    'SJT207',
#    'SJT109',
#    'SJT112',
#    'SJT114',
#    'SJT126',
#    'SJT201',
#    'SJT205',
#    'MB305A',
#    'GDN129',
#    'MB312',
#    'PLB522',
#    'MB309A',
#    'GDN128',
#    'MB309',
#    'MB311',
#    'PLB523',
#    'PLB509',
#    'MGB207',
#    'MGB 303',
#    'TT524',
#    'TT206',
#    'SMV313',
#    'SMVG10',
#    'SJT118'],
#   ['5',
#    'SJT617',
#    'SMV116',
#    'SMV220',
#    'SMV219',
#    'SMV111',
#    'SMV109',
#    'SMV128',
#    'CDMM105',
#    'CDMM302',
#    'SMVG11',
#    'SJT514',
#    'SJT405',
#    'SJT423',
#    'SJT513',
#    'SJT522',
#    'SJT501',
#    'MGB 303',
#    'MGB106',
#    'MGB201',
#    'MGB304',
#    'SJT601',
#    'MB218',
#    'SJT521',
#    'SJT323',
#    'MGB305',
#    'SJT404',
#    'SJT508',
#    'MB219',
#    'SJT322',
#    'MGB202',
#    'SJT401',
#    'SJT409',
#    'MGB105',
#    'TT423',
#    'TT414',
#    'CBMR403',
#    'TT304',
#    'TT630',
#    'TT631',
#    'CBMR101',
#    'CBMR402',
#    'CBMR301',
#    'TT504',
#    'TT523',
#    'TT524',
#    'SJT109',
#    'SJT113',
#    'SJT114',
#    'SJT126',
#    'SJT127',
#    'SJT807',
#    'SJT201',
#    'SJT205',
#    'SJT207',
#    'SJT207A',
#    'SJT208',
#    'SJT211',
#    'SJT211A',
#    'SJT215',
#    'SJT221',
#    'SJT222',
#    'SJT224',
#    'GDN128',
#    'CDMM303',
#    'MB225',
#    'MB226',
#    'MB227',
#    'MB305A',
#    'MB309',
#    'SMV234',
#    'GDN129',
#    'SJT308',
#    'SJT403',
#    'SJT505',
#    'SJT415',
#    'SMV217',
#    'SJT324',
#    'SJT602'],
#   ['25',
#    'SJT109',
#    'SJT112',
#    'SJT113',
#    'SJT114',
#    'SJT522',
#    'SJT401',
#    'TT413',
#    'SMV128',
#    'SMV112',
#    'SMV220',
#    'SMV116',
#    'SMV217',
#    'SMV218',
#    'CDMM304',
#    'SMV102',
#    'SMV101',
#    'SMVG11',
#    'SMV219',
#    'SJT402',
#    'SJT505',
#    'MGB304',
#    'SJT308',
#    'SJT508',
#    'SJT311',
#    'SJT315',
#    'SJT423',
#    'SJT405',
#    'SJT501',
#    'SJT513',
#    'SJT514',
#    'MB214',
#    'MGB303',
#    'SJT504',
#    'SJT323',
#    'SJT403',
#    'SJT324',
#    'SJT404',
#    'MGB 303',
#    'MGB110',
#    'SJT521',
#    'SJT424',
#    'SJT601',
#    'MGB209',
#    'MB219',
#    'MGB207',
#    'MB218',
#    'SJT415',
#    'SJT422',
#    'TT524',
#    'SJT409',
#    'MGB208',
#    'TT415',
#    'TT423',
#    'TT424',
#    'TT434',
#    'TT304',
#    'TT531A',
#    'TT301',
#    'TT208',
#    'TT303',
#    'TT530A',
#    'CBMR301',
#    'TT523',
#    'CBMR101',
#    'SJT127',
#    'SJT201',
#    'SJT205',
#    'SJT207A',
#    'SJT208',
#    'SJT211',
#    'SJT211A',
#    'SJT126',
#    'SJT215',
#    'SJT807',
#    'MB311',
#    'MB224',
#    'GDN128',
#    'MB226',
#    'MB309A',
#    'MB210',
#    'MB312',
#    'SMV209',
#    'SJT602',
#    'TT206'],
#   ['2',
#    'TT523',
#    'SJT415',
#    'SJT505',
#    'SJT508',
#    'SJT513',
#    'SJT514',
#    'SJT521',
#    'SJT401',
#    'SJT402',
#    'SJT403',
#    'SJT404',
#    'SJT112',
#    'SJT113',
#    'TT630',
#    'MB219',
#    'MB224',
#    'CDMM105',
#    'SJT617',
#    'CDMM302',
#    'SMV116',
#    'SMV219',
#    'SMV218',
#    'SMV217',
#    'SMV209',
#    'SMV234',
#    'SMV220',
#    'CDMM301',
#    'SMV112',
#    'SMV101',
#    'SMV128',
#    'SMV102',
#    'SJT303',
#    'SJT224',
#    'SJT315',
#    'SJT323',
#    'SJT305',
#    'SJT501',
#    'MGB109',
#    'MGB202',
#    'TT631',
#    'SJT522',
#    'SJT302',
#    'SJT311A',
#    'MGB110',
#    'SJT421',
#    'SJT807',
#    'SJT504',
#    'SJT322',
#    'SJT405',
#    'MGB207',
#    'SJT423',
#    'SJT409',
#    'SJT424',
#    'MGB106',
#    'SJT503',
#    'SJT601',
#    'TT112',
#    'SJT222',
#    'TT423',
#    'TT424',
#    'TT434A',
#    'TT434',
#    'TT504',
#    'TT531A',
#    'CBMR101',
#    'SJT205',
#    'CBMR301',
#    'CBMR403',
#    'SJT211A',
#    'CBMR402',
#    'SJT109',
#    'SJT114',
#    'SJT115',
#    'SJT118',
#    'SJT124',
#    'SJT125',
#    'SJT207',
#    'SJT126',
#    'SJT127',
#    'SJT201',
#    'SJT202',
#    'SJT203',
#    'SJT204',
#    'SJT207A',
#    'MB214',
#    'GDN107',
#    'MB309',
#    'MB225',
#    'PLB622',
#    'PLB509',
#    'SMV109',
#    'PLB504',
#    'PLB519',
#    'PLB522',
#    'MB227',
#    'MGB303',
#    'SJT308',
#    'SJT304',
#    'SJT208',
#    'SMVG10',
#    'SJT211',
#    'TT524',
#    'TT619',
#    'SJT221',
#    'SJT215',
#    'SJT324',
#    'SJT422',
#    'TT331',
#    'SJT311'],
#   ['22',
#    'SMV109',
#    'MB214',
#    'TT630',
#    'TT434',
#    'SJT415',
#    'SJT522',
#    'SMV217',
#    'SMV111',
#    'SMV219',
#    'SMV218',
#    'SMV128',
#    'SMV214',
#    'SMV116',
#    'CDMM304',
#    'CDMM301',
#    'CDMM105',
#    'SMV102',
#    'SJT423',
#    'SJT223',
#    'SJT305',
#    'SJT401',
#    'SJT311A',
#    'SJT405',
#    'SJT501',
#    'SJT208',
#    'SJT211',
#    'SJT211A',
#    'SJT125',
#    'SJT126',
#    'SJT222',
#    'SJT308',
#    'SJT403',
#    'SJT402',
#    'SJT409',
#    'SJT323',
#    'SJT404',
#    'SJT201',
#    'SJT421',
#    'SJT221',
#    'SJT202',
#    'SJT504',
#    'SJT503',
#    'SJT505',
#    'SJT422',
#    'SJT508',
#    'SJT315',
#    'SJT322',
#    'SJT424',
#    'SJT324',
#    'TT434A',
#    'TT414',
#    'TT415',
#    'TT424',
#    'CBMR101',
#    'TT301',
#    'TT302',
#    'TT303',
#    'TT621',
#    'TT504',
#    'TT207',
#    'TT208',
#    'TT331',
#    'TT631',
#    'TT413',
#    'TT423',
#    'SJT112',
#    'SJT113',
#    'SJT114',
#    'SJT109',
#    'SJT115',
#    'SJT118',
#    'SJT124',
#    'MB225',
#    'MB226',
#    'MB227',
#    'MB218',
#    'MB305A',
#    'MB309',
#    'MB312',
#    'MB311',
#    'MB309A',
#    'MB224',
#    'MB219',
#    'GDN107',
#    'GDN129',
#    'GDN128',
#    'PLB523',
#    'MGB105',
#    'MGB106',
#    'CDMM303',
#    'TT524',
#    'SMVG11',
#    'SJT207A'],
#   ['14',
#    'SJT322',
#    'SJT315',
#    'SJT208',
#    'SJT215',
#    'SJT211A',
#    'SJT211',
#    'SJT221',
#    'SJT222',
#    'SJT401',
#    'SJT402',
#    'SJT403',
#    'SJT404',
#    'SJT405',
#    'SJT308',
#    'SJT311',
#    'SJT324',
#    'SJT311A',
#    'SJT323',
#    'SMV109',
#    'CDMM105',
#    'SMV116',
#    'TT207',
#    'TT208',
#    'MB214',
#    'TT630',
#    'TT631',
#    'MB218',
#    'MB219',
#    'TT531A',
#    'MB224',
#    'MB225',
#    'SJT224',
#    'SJT127',
#    'SJT505',
#    'SJT514',
#    'SJT508',
#    'SJT521',
#    'SJT513',
#    'SJT522',
#    'SMV128',
#    'MB226',
#    'MB227',
#    'MB305A',
#    'TT424',
#    'TT423',
#    'TT434',
#    'TT303',
#    'SJT409',
#    'SJT415',
#    'SMV112',
#    'SMV220',
#    'SMV219',
#    'SMV218',
#    'SMV217',
#    'CDMM301',
#    'CDMM303',
#    'SMV102',
#    'SMV101',
#    'SJT807',
#    'SJT423',
#    'SJT504',
#    'SJT115',
#    'SJT125',
#    'SJT303',
#    'SJT202',
#    'SJT203',
#    'SJT501',
#    'SJT305',
#    'SJT421',
#    'SJT422',
#    'SJT503',
#    'TT414',
#    'TT112',
#    'TT413',
#    'TT434A',
#    'TT206',
#    'TT301',
#    'TT302',
#    'CBMR101',
#    'CBMR301',
#    'CBMR403',
#    'CBMR402',
#    'SJT124',
#    'SJT118',
#    'SJT109',
#    'SJT112',
#    'SJT113',
#    'SJT114',
#    'GDN107',
#    'MB309',
#    'CDMM302',
#    'GDN129',
#    'PLB519',
#    'MB312',
#    'MB311',
#    'MB309A',
#    'SMV234',
#    'GDN128',
#    'PLB522',
#    'SJT617',
#    'TT415'],
#   ['7',
#    'SJT415',
#    'SJT401',
#    'SJT807',
#    'SMV112',
#    'SMV116',
#    'SMV111',
#    'SMV218',
#    'SMV217',
#    'CDMM105',
#    'CDMM302',
#    'CDMM303',
#    'SMV128',
#    'SMV102',
#    'SJT305',
#    'SJT403',
#    'SJT404',
#    'SJT421',
#    'SJT423',
#    'SJT508',
#    'SJT513',
#    'SJT409',
#    'SJT424',
#    'SJT504',
#    'SJT311A',
#    'SJT501',
#    'SJT505',
#    'SJT521',
#    'SJT405',
#    'TT424',
#    'TT434',
#    'TT434A',
#    'TT523',
#    'TT304',
#    'TT531A',
#    'TT630',
#    'CBMR101',
#    'CBMR301',
#    'CBMR402',
#    'TT631',
#    'CBMR403',
#    'TT504',
#    'SJT208',
#    'SJT113',
#    'SJT114',
#    'SJT115',
#    'SJT118',
#    'SJT124',
#    'SJT125',
#    'SJT127',
#    'SJT112',
#    'SJT202',
#    'SJT203',
#    'SJT204',
#    'SJT205',
#    'SJT207',
#    'SJT207A',
#    'SJT211',
#    'MB305A',
#    'MB214',
#    'MB309',
#    'MB218',
#    'MB219',
#    'MB224',
#    'MB225',
#    'MB226',
#    'SJT222',
#    'MGB 303',
#    'MB312',
#    'MB227',
#    'MB311',
#    'MB309A',
#    'PLB504',
#    'SJT602',
#    'SJT323',
#    'SJT303'],
#   ['27',
#    'SJT109',
#    'SJT112',
#    'SJT113',
#    'SJT324',
#    'SMV116',
#    'SMV214',
#    'SMV128',
#    'CDMM304',
#    'SMV109',
#    'SMV102',
#    'SMV101',
#    'SJT305',
#    'SJT403',
#    'SJT311',
#    'SJT401',
#    'SJT423',
#    'SJT402',
#    'SJT323',
#    'SJT405',
#    'SJT424',
#    'SJT501',
#    'SJT502',
#    'SJT508',
#    'SJT311A',
#    'SJT404',
#    'SJT315',
#    'SJT505',
#    'SJT215',
#    'SJT224',
#    'SJT221',
#    'SJT422',
#    'MB214',
#    'SJT514',
#    'SJT222',
#    'SJT415',
#    'SJT409',
#    'SJT308',
#    'SJT504',
#    'SJT322',
#    'SJT513',
#    'TT434A',
#    'TT415',
#    'TT413',
#    'TT414',
#    'TT423',
#    'TT424',
#    'TT302',
#    'TT301',
#    'TT303',
#    'TT530',
#    'CBMR101',
#    'TT206',
#    'TT631',
#    'SJT211A',
#    'SJT114',
#    'SJT115',
#    'SJT118',
#    'SJT125',
#    'SJT127',
#    'SJT201',
#    'SJT202',
#    'SJT126',
#    'SJT203',
#    'SJT207',
#    'MB219',
#    'MGB105',
#    'MB225',
#    'MB218',
#    'MB312',
#    'SMVG11',
#    'SJT207A']],
#  ['1',
#   ['4',
#    'SJT617',
#    'SMV116',
#    'SMV220',
#    'SMV219',
#    'SMV111',
#    'SMV214',
#    'SMV109',
#    'SMV128',
#    'SMV218',
#    'CDMM105',
#    'CDMM302',
#    'CDMM301',
#    'SMVG11',
#    'SMV101',
#    'SMV102',
#    'SMVG10',
#    'SJT514',
#    'SJT405',
#    'SJT423',
#    'SJT513',
#    'SJT522',
#    'SJT501',
#    'MGB 303',
#    'MGB106',
#    'MGB201',
#    'MGB304',
#    'SJT601',
#    'MB218',
#    'SJT311A',
#    'SJT424',
#    'MGB110',
#    'SJT521',
#    'SJT323',
#    'MGB305',
#    'SJT404',
#    'SJT508',
#    'MB219',
#    'SJT322',
#    'MGB202',
#    'SJT401',
#    'SJT409',
#    'MGB105',
#    'SJT421',
#    'MGB108',
#    'MB214',
#    'SJT402',
#    'SJT422',
#    'TT112',
#    'TT423',
#    'TT414',
#    'CBMR403',
#    'MGB111',
#    'TT630',
#    'TT631',
#    'CBMR101',
#    'CBMR402',
#    'CBMR301',
#    'MGB208',
#    'TT413',
#    'TT424',
#    'TT415',
#    'TT434A',
#    'TT504',
#    'TT619',
#    'TT523',
#    'TT524',
#    'SJT109',
#    'SJT113',
#    'SJT114',
#    'SJT126',
#    'SJT127',
#    'SJT807',
#    'SJT201',
#    'SJT205',
#    'SJT207',
#    'SJT207A',
#    'SJT208',
#    'SJT211',
#    'SJT211A',
#    'SJT215',
#    'SJT221',
#    'SJT222',
#    'SJT224',
#    'GDN128',
#    'CDMM303',
#    'MB225',
#    'MB226',
#    'MB227',
#    'MB305A',
#    'MB309',
#    'SMV234',
#    'GDN129',
#    'SJT308',
#    'SJT315',
#    'TT531A',
#    'SJT403',
#    'SJT505',
#    'SJT415',
#    'SMV217',
#    'SJT324',
#    'SJT602',
#    'SJT311'],
#   ['24',
#    'SJT109',
#    'SJT112',
#    'SJT113',
#    'SJT114',
#    'SJT522',
#    'SJT401',
#    'SMV128',
#    'SMV220',
#    'SMV116',
#    'SMV217',
#    'SMV218',
#    'CDMM105',
#    'CDMM301',
#    'CDMM302',
#    'SMV102',
#    'SMV101',
#    'SMVG11',
#    'SMV219',
#    'SJT311A',
#    'SJT402',
#    'MGB304',
#    'SJT308',
#    'SJT508',
#    'SJT311',
#    'SJT315',
#    'SJT423',
#    'SJT405',
#    'SJT501',
#    'SJT513',
#    'SJT514',
#    'MB214',
#    'MGB303',
#    'SJT504',
#    'SJT323',
#    'SJT403',
#    'SJT324',
#    'SJT404',
#    'MGB 303',
#    'MGB110',
#    'SJT521',
#    'SJT424',
#    'SJT601',
#    'MGB209',
#    'MB219',
#    'MGB207',
#    'MB218',
#    'SJT415',
#    'TT619',
#    'SJT422',
#    'TT524',
#    'SJT409',
#    'SJT505',
#    'MGB208',
#    'TT415',
#    'TT423',
#    'TT434A',
#    'TT424',
#    'TT434',
#    'CBMR402',
#    'TT304',
#    'TT531A',
#    'TT630',
#    'TT631',
#    'CBMR101',
#    'TT301',
#    'TT208',
#    'TT303',
#    'TT530A',
#    'CBMR403',
#    'CBMR301',
#    'TT523',
#    'SJT127',
#    'SJT201',
#    'SJT205',
#    'SJT207',
#    'SJT207A',
#    'SJT208',
#    'SJT211',
#    'SJT211A',
#    'SJT126',
#    'SJT215',
#    'SJT221',
#    'SJT222',
#    'SJT224',
#    'SJT807',
#    'MB227',
#    'MB311',
#    'MB224',
#    'MB225',
#    'GDN128',
#    'MB226',
#    'MB309A',
#    'MB210',
#    'MB312',
#    'SJT322',
#    'SMVG10',
#    'SMV109',
#    'TT504',
#    'TT413',
#    'TT414',
#    'SJT421',
#    'SMV111',
#    'SMV234',
#    'SMV209',
#    'TT206'],
#   ['16',
#    'SJT201',
#    'SJT202',
#    'SJT505',
#    'SJT508',
#    'SJT513',
#    'SJT204',
#    'SJT207',
#    'SMV101',
#    'TT531A',
#    'SMV102',
#    'SJT203',
#    'SMV104',
#    'SJT205',
#    'MB110',
#    'SJT207A',
#    'TT423',
#    'SJT401',
#    'MB111',
#    'SJT402',
#    'MB124',
#    'SJT403',
#    'TT424',
#    'SJT404',
#    'MB211',
#    'TT621',
#    'MB212',
#    'SJT405',
#    'TT630',
#    'MB213',
#    'SJT323',
#    'TT725',
#    'SJT409',
#    'TT631',
#    'SJT415',
#    'SJT421',
#    'SJT514',
#    'SJT422',
#    'SJT521',
#    'SJT423',
#    'SJT522',
#    'SJT424',
#    'SJT324',
#    'SMV219',
#    'SMV116',
#    'SMV128',
#    'SMV217',
#    'SMVG10',
#    'SMV214',
#    'SMV218',
#    'CDMM105',
#    'CDMM301',
#    'CDMM302',
#    'SMV234',
#    'SMV220',
#    'SMV111',
#    'MGB303',
#    'MB312',
#    'SJT311',
#    'SJT311A',
#    'MGB110',
#    'MGB304',
#    'MGB106',
#    'MB219',
#    'MGB202',
#    'SJT501',
#    'MGB105',
#    'MGB201',
#    'SJT601',
#    'MB218',
#    'SJT602',
#    'MGB 303',
#    'SJT322',
#    'TT434A',
#    'SJT315',
#    'MB214',
#    'MGB305',
#    'CBMR301',
#    'MGB111',
#    'CBMR402',
#    'CBMR403',
#    'TT504',
#    'TT523',
#    'TT524',
#    'TT619',
#    'CBMR101',
#    'SJT113',
#    'SJT126',
#    'SJT127',
#    'SJT208',
#    'SJT211',
#    'SJT211A',
#    'SJT215',
#    'SJT221',
#    'SJT222',
#    'SJT112',
#    'SJT224',
#    'PLB522',
#    'PLB504',
#    'PLB509',
#    'MB226',
#    'MB227',
#    'MB305A',
#    'MB309',
#    'MB311',
#    'MB225',
#    'MB309A',
#    'MB224',
#    'SJT308',
#    'TT434',
#    'SMV109',
#    'TT331'],
#   ['9',
#    'SJT302',
#    'SJT617',
#    'MB214',
#    'SJT508',
#    'SJT513',
#    'SJT514',
#    'SJT521',
#    'SJT522',
#    'SJT401',
#    'SJT402',
#    'SJT403',
#    'SJT404',
#    'SJT112',
#    'SJT113',
#    'SJT405',
#    'SJT409',
#    'SJT315',
#    'SJT415',
#    'MB218',
#    'MB219',
#    'MB224',
#    'SJT215',
#    'TT630',
#    'TT301',
#    'SJT224',
#    'SMV217',
#    'SMV109',
#    'SMV116',
#    'SMV128',
#    'SMV209',
#    'SMV320',
#    'CDMM105',
#    'CDMM303',
#    'CDMM301',
#    'CDMM302',
#    'SMV102',
#    'SMV101',
#    'SJT421',
#    'MGB304',
#    'MGB106',
#    'SJT323',
#    'MGB305',
#    'SJT311A',
#    'SJT505',
#    'MGB 303',
#    'SJT601',
#    'MGB303',
#    'TT206',
#    'TT504',
#    'TT619',
#    'MB309',
#    'SJT807',
#    'SJT501',
#    'SJT423',
#    'SJT308',
#    'MB311',
#    'SJT303',
#    'SJT422',
#    'SJT424',
#    'MB227',
#    'MB305A',
#    'MGB207',
#    'SJT322',
#    '519',
#    'MGB201',
#    'TT424',
#    'TT423',
#    'MB226',
#    'TT434',
#    'TT302',
#    'TT207',
#    'TT303',
#    'CBMR101',
#    'CBMR301',
#    'CBMR402',
#    'SJT109',
#    'SJT114',
#    'SJT126',
#    'SJT201',
#    'SJT204',
#    'SJT205',
#    'SJT207A',
#    'SJT221',
#    'SJT207',
#    'GDN129',
#    'PLB519',
#    'GDN107',
#    'GDN128',
#    'MB312',
#    'CDMM304',
#    'PLB523',
#    'PLB504',
#    'PLB509',
#    'PLB522',
#    'PLB619'],
#   ['6',
#    'SJT415',
#    'SJT401',
#    'SJT807',
#    'SMV112',
#    'SMV116',
#    'SMV111',
#    'SMV218',
#    'SMV214',
#    'SMV217',
#    'CDMM105',
#    'CDMM302',
#    'CDMM303',
#    'SMV128',
#    'CDMM301',
#    'SMV101',
#    'SMV102',
#    'SJT305',
#    'SJT403',
#    'SJT404',
#    'SJT421',
#    'SJT423',
#    'SJT508',
#    'SJT513',
#    'SJT409',
#    'SJT324',
#    'SJT224',
#    'SJT424',
#    'SJT504',
#    'SJT311A',
#    'SJT501',
#    'SJT505',
#    'SJT521',
#    'SJT405',
#    'SJT402',
#    'SJT503',
#    'SJT514',
#    'SJT322',
#    'SJT422',
#    'TT424',
#    'TT434',
#    'TT434A',
#    'TT523',
#    'TT531A',
#    'TT630',
#    'CBMR101',
#    'CBMR301',
#    'CBMR402',
#    'TT631',
#    'TT415',
#    'TT423',
#    'TT414',
#    'CBMR403',
#    'TT504',
#    'SJT208',
#    'SJT109',
#    'SJT113',
#    'SJT114',
#    'SJT115',
#    'SJT118',
#    'SJT124',
#    'SJT125',
#    'SJT127',
#    'SJT201',
#    'SJT112',
#    'SJT202',
#    'SJT203',
#    'SJT204',
#    'SJT205',
#    'SJT207',
#    'SJT207A',
#    'SJT211',
#    'MB305A',
#    'MB214',
#    'MB309',
#    'MB218',
#    'MB219',
#    'MB224',
#    'MB225',
#    'MB226',
#    'SJT222',
#    'MGB 303',
#    'MB312',
#    'MB227',
#    'MB311',
#    'MB309A',
#    'PLB504',
#    'SJT315',
#    'SJT221',
#    'SMVG10',
#    'SMV109',
#    'SJT211A',
#    'SMVG11',
#    'TT619',
#    'SJT126',
#    'SJT323',
#    'SJT303',
#    'SJT215',
#    'SJT311'],
#   ['26',
#    'SJT109',
#    'SJT112',
#    'SJT113',
#    'SJT324',
#    'SMV111',
#    'TT523',
#    'SMV116',
#    'SMV217',
#    'SMV214',
#    'SMV128',
#    'CDMM304',
#    'CDMM105',
#    'SMV109',
#    'SMV102',
#    'SMV101',
#    'SJT305',
#    'SJT403',
#    'SJT311',
#    'SJT401',
#    'SJT423',
#    'SJT402',
#    'SJT323',
#    'SJT405',
#    'SJT424',
#    'SJT501',
#    'SJT502',
#    'SJT508',
#    'SJT311A',
#    'SJT404',
#    'SJT315',
#    'SJT503',
#    'SJT505',
#    'SJT215',
#    'SJT224',
#    'SJT221',
#    'SJT422',
#    'MB214',
#    'SJT514',
#    'SJT222',
#    'SJT415',
#    'SJT409',
#    'SJT308',
#    'SJT504',
#    'SJT322',
#    'SJT421',
#    'SJT513',
#    'TT112',
#    'TT434A',
#    'TT415',
#    'TT413',
#    'TT414',
#    'TT434',
#    'TT423',
#    'TT424',
#    'TT531A',
#    'TT630',
#    'TT207',
#    'TT208',
#    'TT301',
#    'TT303',
#    'TT530',
#    'CBMR101',
#    'TT206',
#    'TT631',
#    'SJT211A',
#    'SJT114',
#    'SJT115',
#    'SJT118',
#    'SJT124',
#    'SJT807',
#    'SJT125',
#    'SJT127',
#    'SJT201',
#    'SJT202',
#    'SJT126',
#    'SJT203',
#    'SJT204',
#    'SJT205',
#    'SJT211',
#    'SJT208',
#    'SJT207',
#    'GDN107',
#    'MB309',
#    'MB219',
#    'MB224',
#    'MGB105',
#    'MB225',
#    'MB226',
#    'MB311',
#    'MB218',
#    'MB312',
#    'SMVG11',
#    'SMVG10',
#    'SJT207A',
#    'SMV219',
#    'SMV218'],
#   ['18',
#    'SJT201',
#    'SJT202',
#    'SJT505',
#    'SJT508',
#    'SJT513',
#    'SJT204',
#    'SJT207',
#    'SMV101',
#    'TT531A',
#    'SMV102',
#    'SJT203',
#    'SMV104',
#    'SJT205',
#    'MB110',
#    'SJT207A',
#    'SJT401',
#    'TT423',
#    'MB111',
#    'SJT402',
#    'MB124',
#    'SJT403',
#    'TT424',
#    'MB211',
#    'SJT404',
#    'TT621',
#    'MB212',
#    'SJT405',
#    'TT630',
#    'MB213',
#    'SJT323',
#    'TT725',
#    'SJT409',
#    'TT631',
#    'SJT415',
#    'SJT421',
#    'SJT514',
#    'SJT521',
#    'SJT422',
#    'SJT522',
#    'SJT423',
#    'SJT424',
#    'SJT324',
#    'SMV109',
#    'SMV112',
#    'SMV116',
#    'SMV218',
#    'SMV214',
#    'SMV128',
#    'CDMM105',
#    'CDMM303',
#    'SMV219',
#    'SMV220',
#    'SMVG10',
#    'SJT501',
#    'SJT322',
#    'SJT223',
#    'SJT308',
#    'SJT315',
#    'SJT504',
#    'SJT311',
#    'SJT311A',
#    'SJT502',
#    'SJT503',
#    'SJT224',
#    'SJT601',
#    'MB214',
#    'SJT222',
#    'TT434A',
#    'TT434',
#    'TT530',
#    'CBMR101',
#    'CBMR301',
#    'CBMR403',
#    'CBMR402',
#    'TT504',
#    'TT523',
#    'TT524',
#    'TT303',
#    'SJT109',
#    'SJT112',
#    'SJT114',
#    'SJT113',
#    'SJT115',
#    'SJT118',
#    'SJT124',
#    'SJT125',
#    'SJT126',
#    'SJT127',
#    'SJT208',
#    'SJT211',
#    'SJT211A',
#    'SJT215',
#    'MB311',
#    'MB312',
#    'MB219',
#    'MB224',
#    'GDN107',
#    'MB225',
#    'MB226',
#    'MB227',
#    'MB218',
#    'MB309',
#    'PLB509',
#    'TT619',
#    'SJT221'],
#   ['11',
#    'MB214',
#    'SJT421',
#    'SJT505',
#    'SJT508',
#    'SJT513',
#    'SJT514',
#    'SJT521',
#    'SJT522',
#    'SJT401',
#    'SJT402',
#    'SJT404',
#    'SJT403',
#    'SJT112',
#    'SJT405',
#    'MB218',
#    'MB224',
#    'MB225',
#    'SJT617',
#    'TT423',
#    'SJT204',
#    'TT302',
#    'SMV116',
#    'SMV217',
#    'SMV220',
#    'SMV112',
#    'SMV218',
#    'CDMM301',
#    'CDMM105',
#    'SJT224',
#    'SJT504',
#    'SJT423',
#    'SJT315',
#    'SJT422',
#    'SJT415',
#    'SJT202',
#    'SJT807',
#    'SJT203',
#    'SJT222',
#    'SJT308',
#    'SJT501',
#    'SJT303',
#    'SJT324',
#    'SJT322',
#    'SJT424',
#    'SJT113',
#    'SJT207',
#    'SJT221',
#    'SJT323',
#    'TT112',
#    'TT523',
#    'TT434',
#    'TT434A',
#    'TT424',
#    'CBMR101',
#    'TT206',
#    'TT301',
#    'TT531A',
#    'TT207',
#    'CBMR301',
#    'TT630',
#    'SJT109',
#    'SJT114',
#    'SJT115',
#    'SJT118',
#    'SJT126',
#    'SJT211A',
#    'SJT208',
#    'MB312',
#    'MB219',
#    'MB305A',
#    'MB309',
#    'PLB519',
#    'CDMM303',
#    'MB311',
#    'PLB522',
#    'PLB523',
#    'MB226',
#    'MB227',
#    'SJT201',
#    'SJT602',
#    'TT504']],
#  ['2',
#   ['8',
#    'SJT617',
#    'MB214',
#    'SJT508',
#    'SJT513',
#    'SJT514',
#    'SJT521',
#    'SJT522',
#    'SJT401',
#    'SJT402',
#    'SJT403',
#    'SJT404',
#    'SJT112',
#    'SJT113',
#    'SJT405',
#    'SJT409',
#    'SJT315',
#    'SJT415',
#    'MB218',
#    'MB219',
#    'MB224',
#    'SMV217',
#    'SMV109',
#    'SMV116',
#    'SMV128',
#    'SMV209',
#    'SMV219',
#    'SMV220',
#    'SMV234',
#    'SMV218',
#    'SMV320',
#    'CDMM105',
#    'CDMM303',
#    'CDMM301',
#    'CDMM302',
#    'SMV102',
#    'SMV101',
#    'SJT421',
#    'MGB304',
#    'MGB106',
#    'SJT323',
#    'SJT311',
#    'MGB305',
#    'SJT311A',
#    'SJT505',
#    'MGB 303',
#    'SJT601',
#    'MGB303',
#    'TT206',
#    'TT504',
#    'TT619',
#    'MB309',
#    'SJT807',
#    'SJT324',
#    'SJT501',
#    'SJT423',
#    'MGB202',
#    'SJT308',
#    'MB311',
#    'SJT422',
#    'SJT424',
#    'MB227',
#    'MB305A',
#    'MGB207',
#    'SJT322',
#    '519',
#    'MGB201',
#    'MGB110',
#    'MB225',
#    'TT424',
#    'TT423',
#    'TT434A',
#    'MB226',
#    'TT434',
#    'TT531A',
#    'TT630',
#    'TT301',
#    'TT302',
#    'TT621A',
#    'TT631',
#    'TT207',
#    'TT303',
#    'CBMR403',
#    'CBMR101',
#    'CBMR301',
#    'CBMR402',
#    'SJT109',
#    'SJT114',
#    'SJT126',
#    'SJT201',
#    'SJT204',
#    'SJT205',
#    'SJT224',
#    'SJT207A',
#    'SJT208',
#    'SJT222',
#    'SJT211A',
#    'SJT215',
#    'SJT221',
#    'SJT207',
#    'GDN129',
#    'PLB519',
#    'GDN107',
#    'GDN128',
#    'MB312',
#    'CDMM304',
#    'PLB523',
#    'PLB504',
#    'PLB509',
#    'PLB522',
#    'PLB619',
#    'MB309A',
#    'TT524',
#    'TT523',
#    'SMVG11',
#    'SMVG10'],
#   ['0',
#    'SJT415',
#    'SJT617',
#    'MB214',
#    'SJT508',
#    'SJT513',
#    'SJT521',
#    'SJT315',
#    'SJT112',
#    'SJT113',
#    'SJT401',
#    'SJT404',
#    'SJT405',
#    'MB218',
#    'MB224',
#    'MB225',
#    'SMVG10',
#    'SMV116',
#    'SMV217',
#    'SMV218',
#    'SMV219',
#    'SMV128',
#    'SMV209',
#    'SMV234',
#    'SMV109',
#    'CDMM105',
#    'CDMM302',
#    'SMV101',
#    'SMV102',
#    'SJT505',
#    'SJT324',
#    'SJT402',
#    'SJT403',
#    'SJT422',
#    'SJT423',
#    'SJT302',
#    'SJT322',
#    'SJT501',
#    'MGB105',
#    'TT630',
#    'MGB201',
#    'MGB110',
#    'MGB305',
#    'MB226',
#    'SJT601',
#    'SJT323',
#    'SJT421',
#    'SJT522',
#    'SJT303',
#    'SJT308',
#    'SJT311A',
#    'MGB 303',
#    'SJT305',
#    'SJT409',
#    'SJT424',
#    'SJT514',
#    'MGB304',
#    'SJT602',
#    'TT434A',
#    'TT424',
#    'TT423',
#    'TT434',
#    'SMV220',
#    'TT335',
#    'TT531A',
#    'TT631',
#    'CBMR101',
#    'CBMR402',
#    'TT619',
#    'CBMR403',
#    'TT504',
#    'TT523',
#    'SJT201',
#    'SJT205',
#    'SJT207',
#    'SJT207A',
#    'SJT208',
#    'SJT211',
#    'SJT211A',
#    'SJT215',
#    'SJT221',
#    'SJT222',
#    'SJT224',
#    'SJT807',
#    'CDMM303',
#    'MB305A',
#    'PLB519',
#    'MB219',
#    'GDN128',
#    'MB227',
#    'PLB509',
#    'GDN129',
#    'PLB504',
#    'PLB522',
#    'MB312',
#    'PLB622',
#    'MB311',
#    'MB309A',
#    'SJT304',
#    'SJT127',
#    'TT524',
#    'SMV320',
#    'SJT311'],
#   ['20',
#    'SMV109',
#    'MB214',
#    'MB218',
#    'TT630',
#    'TT434',
#    'SJT109',
#    'SMV116',
#    'SMV111',
#    'SMV209',
#    'SMV217',
#    'SMV219',
#    'SMV220',
#    'SMV218',
#    'SMV234',
#    'SMV214',
#    'SMV128',
#    'CDMM301',
#    'CDMM303',
#    'CDMM302',
#    'SMV102',
#    'SMV101',
#    'SJT204',
#    'SJT617',
#    'SJT311A',
#    'SJT404',
#    'SJT501',
#    'SJT521',
#    'SJT208',
#    'SJT211',
#    'SJT211A',
#    'SJT215',
#    'SJT221',
#    'SJT222',
#    'SJT224',
#    'SJT402',
#    'SJT308',
#    'SJT323',
#    'SJT403',
#    'SJT401',
#    'SJT409',
#    'SJT422',
#    'SJT423',
#    'SJT504',
#    'SJT505',
#    'SJT508',
#    'SJT513',
#    'SJT807',
#    'SJT522',
#    'MGB201',
#    'MGB106',
#    'MGB 303',
#    'SJT415',
#    'SJT421',
#    'MGB110',
#    'SJT405',
#    'SJT424',
#    'TT413',
#    'TT424',
#    'TT434A',
#    'TT414',
#    'TT415',
#    'TT423',
#    'TT301',
#    'TT302',
#    'TT303',
#    'TT531A',
#    'TT631',
#    'CBMR101',
#    'CBMR301',
#    'CBMR402',
#    'CBMR403',
#    'TT334',
#    'SJT203',
#    'SJT207',
#    'SJT207A',
#    'SJT112',
#    'SJT113',
#    'SJT114',
#    'SJT126',
#    'SJT201',
#    'SJT205',
#    'SJT127',
#    'SMVG11',
#    'MB225',
#    'MB226',
#    'MB224',
#    'MB305A',
#    'PLB509',
#    'MB227',
#    'MB309A',
#    'GDN129',
#    'MB309',
#    'CDMM105',
#    'MB311',
#    'CDMM304',
#    'GDN128',
#    'MB219',
#    'MGB202',
#    'PLB622',
#    'MB312',
#    'PLB519',
#    'SJT322',
#    'SMVG10',
#    'TT523',
#    'SJT315',
#    'TT504',
#    'SJT324',
#    'TT524',
#    'SJT311',
#    'TT206'],
#   ['10',
#    'MB214',
#    'SJT421',
#    'SJT505',
#    'SJT508',
#    'SJT513',
#    'SJT514',
#    'SJT521',
#    'SJT522',
#    'SJT401',
#    'SJT402',
#    'SJT404',
#    'SJT403',
#    'SJT112',
#    'SJT405',
#    'MB218',
#    'MB224',
#    'MB225',
#    'SJT617',
#    'SMV217',
#    'SMV220',
#    'SMV112',
#    'SMV218',
#    'SMV219',
#    'SMV128',
#    'CDMM301',
#    'CDMM105',
#    'CDMM302',
#    'SJT224',
#    'SJT504',
#    'SJT423',
#    'SJT315',
#    'SJT422',
#    'SJT415',
#    'SJT202',
#    'SJT807',
#    'SJT203',
#    'SJT222',
#    'SJT308',
#    'SJT409',
#    'SJT501',
#    'SJT311',
#    'SJT303',
#    'SJT324',
#    'SJT322',
#    'SJT424',
#    'SJT113',
#    'SJT207',
#    'SJT221',
#    'SJT323',
#    'SJT311A',
#    'TT112',
#    'TT523',
#    'TT434',
#    'TT434A',
#    'TT424',
#    'TT208',
#    'CBMR101',
#    'TT301',
#    'TT302',
#    'TT531A',
#    'TT207',
#    'TT423',
#    'CBMR301',
#    'TT630',
#    'SJT109',
#    'SJT114',
#    'SJT115',
#    'SJT204',
#    'SJT118',
#    'SJT124',
#    'SJT127',
#    'SJT207A',
#    'SJT205',
#    'SJT125',
#    'SJT126',
#    'SJT211A',
#    'SJT208',
#    'MB312',
#    'MB219',
#    'MB305A',
#    'MB309',
#    'PLB519',
#    'CDMM303',
#    'MB311',
#    'PLB522',
#    'PLB523',
#    'MB226',
#    'MB227',
#    'SJT201',
#    'SJT305',
#    'SMV109',
#    'SJT211',
#    'SJT215',
#    'TT331',
#    'SMV234',
#    'TT504'],
#   ['2',
#    'TT523',
#    'SJT415',
#    'SJT505',
#    'SJT508',
#    'SJT513',
#    'SJT514',
#    'SJT521',
#    'SJT401',
#    'SJT402',
#    'SJT403',
#    'SJT404',
#    'SJT112',
#    'SJT113',
#    'TT630',
#    'MB219',
#    'MB224',
#    'CDMM105',
#    'SJT617',
#    'CDMM302',
#    'SMV116',
#    'SMV219',
#    'SMV218',
#    'SMV217',
#    'SMV209',
#    'SMV234',
#    'SMV220',
#    'CDMM301',
#    'SMV112',
#    'SMV101',
#    'SMV128',
#    'SMV102',
#    'SJT303',
#    'SJT224',
#    'SJT315',
#    'SJT323',
#    'SJT305',
#    'SJT501',
#    'MGB109',
#    'MGB202',
#    'TT631',
#    'SJT522',
#    'SJT302',
#    'SJT311A',
#    'MGB110',
#    'SJT421',
#    'SJT807',
#    'SJT504',
#    'SJT322',
#    'SJT405',
#    'MGB207',
#    'SJT423',
#    'SJT409',
#    'SJT424',
#    'MGB106',
#    'SJT503',
#    'SJT601',
#    'TT112',
#    'SJT222',
#    'TT423',
#    'TT424',
#    'TT434A',
#    'TT434',
#    'TT504',
#    'TT531A',
#    'CBMR101',
#    'SJT205',
#    'CBMR301',
#    'CBMR403',
#    'SJT211A',
#    'CBMR402',
#    'SJT109',
#    'SJT114',
#    'SJT115',
#    'SJT118',
#    'SJT124',
#    'SJT125',
#    'SJT207',
#    'SJT126',
#    'SJT127',
#    'SJT201',
#    'SJT202',
#    'SJT203',
#    'SJT204',
#    'SJT207A',
#    'MB214',
#    'GDN107',
#    'MB309',
#    'MB225',
#    'PLB622',
#    'PLB509',
#    'SMV109',
#    'PLB504',
#    'PLB519',
#    'PLB522',
#    'MB227',
#    'MGB303',
#    'SJT308',
#    'SJT304',
#    'SJT208',
#    'SMVG10',
#    'SJT211',
#    'TT524',
#    'TT619',
#    'SJT221',
#    'SJT215',
#    'SJT324',
#    'SJT422',
#    'TT331',
#    'SJT311'],
#   ['22',
#    'SMV109',
#    'MB214',
#    'TT630',
#    'TT434',
#    'SJT415',
#    'SJT522',
#    'SMV217',
#    'SMV111',
#    'SMV219',
#    'SMV218',
#    'SMV128',
#    'SMV214',
#    'SMV116',
#    'CDMM304',
#    'CDMM301',
#    'CDMM105',
#    'SMV102',
#    'SJT423',
#    'SJT223',
#    'SJT305',
#    'SJT401',
#    'SJT311A',
#    'SJT405',
#    'SJT501',
#    'SJT208',
#    'SJT211',
#    'SJT211A',
#    'SJT125',
#    'SJT126',
#    'SJT222',
#    'SJT308',
#    'SJT403',
#    'SJT402',
#    'SJT409',
#    'SJT323',
#    'SJT404',
#    'SJT201',
#    'SJT421',
#    'SJT221',
#    'SJT202',
#    'SJT504',
#    'SJT503',
#    'SJT505',
#    'SJT422',
#    'SJT508',
#    'SJT315',
#    'SJT322',
#    'SJT424',
#    'SJT324',
#    'TT434A',
#    'TT414',
#    'TT415',
#    'TT424',
#    'CBMR101',
#    'TT301',
#    'TT302',
#    'TT303',
#    'TT621',
#    'TT504',
#    'TT207',
#    'TT208',
#    'TT331',
#    'TT631',
#    'TT413',
#    'TT423',
#    'SJT112',
#    'SJT113',
#    'SJT114',
#    'SJT109',
#    'SJT115',
#    'SJT118',
#    'SJT124',
#    'MB225',
#    'MB226',
#    'MB227',
#    'MB218',
#    'MB305A',
#    'MB309',
#    'MB312',
#    'MB311',
#    'MB309A',
#    'MB224',
#    'MB219',
#    'GDN107',
#    'GDN129',
#    'GDN128',
#    'PLB523',
#    'MGB105',
#    'MGB106',
#    'CDMM303',
#    'TT524',
#    'SMVG11',
#    'SJT207A'],
#   ['15',
#    'SJT322',
#    'SJT315',
#    'SJT208',
#    'SJT215',
#    'SJT211A',
#    'SJT211',
#    'SJT221',
#    'SJT222',
#    'SJT401',
#    'SJT402',
#    'SJT403',
#    'SJT404',
#    'SJT405',
#    'SJT308',
#    'SJT311',
#    'SJT324',
#    'SJT311A',
#    'SJT323',
#    'SMV109',
#    'CDMM105',
#    'SMV116',
#    'TT207',
#    'TT208',
#    'MB214',
#    'TT630',
#    'TT631',
#    'MB218',
#    'MB219',
#    'TT531A',
#    'MB224',
#    'MB225',
#    'SJT224',
#    'SJT127',
#    'SJT505',
#    'SJT514',
#    'SJT508',
#    'SJT521',
#    'SJT513',
#    'SJT522',
#    'SMV128',
#    'MB226',
#    'MB227',
#    'MB305A',
#    'TT424',
#    'TT423',
#    'TT434',
#    'TT303',
#    'SJT409',
#    'SJT415',
#    'SJT203',
#    'TT621',
#    'TT619',
#    'TT524',
#    'SMV112',
#    'SMV220',
#    'SMV219',
#    'SMV217',
#    'SMV102',
#    'SJT423',
#    'SJT115',
#    'SJT125',
#    'SJT303',
#    'SJT202',
#    'SJT305',
#    'SJT421',
#    'SJT422',
#    'SJT503',
#    'TT112',
#    'TT434A',
#    'TT206',
#    'TT301',
#    'TT302',
#    'CBMR101',
#    'CBMR301',
#    'CBMR402',
#    'SJT124',
#    'SJT112',
#    'SJT114',
#    'GDN107',
#    'MB309',
#    'GDN129',
#    'PLB519',
#    'MB312',
#    'MB311',
#    'MB309A',
#    'SMV234',
#    'GDN128',
#    'PLB522',
#    'SJT617']],
#  ['3',
#   ['12',
#    'SJT322',
#    'SJT315',
#    'SJT208',
#    'SJT211A',
#    'SJT211',
#    'SJT215',
#    'SJT221',
#    'SJT222',
#    'SJT401',
#    'SJT402',
#    'SJT403',
#    'SJT404',
#    'SJT405',
#    'SJT308',
#    'SJT324',
#    'SJT311',
#    'SJT311A',
#    'SJT323',
#    'SMV109',
#    'CDMM105',
#    'SMV116',
#    'TT207',
#    'TT208',
#    'MB214',
#    'TT630',
#    'TT631',
#    'MB218',
#    'TT531A',
#    'MB219',
#    'MB224',
#    'MB225',
#    'SJT224',
#    'SJT127',
#    'SJT505',
#    'SJT514',
#    'SJT508',
#    'SJT521',
#    'SJT513',
#    'SJT522',
#    'MB226',
#    'SMV128',
#    'MB227',
#    'SMV217',
#    'TT424',
#    'TT423',
#    'TT434',
#    'TT303',
#    'SJT409',
#    'SJT415',
#    'SJT421',
#    'SMV220',
#    'SMV234',
#    'SMV209',
#    'SMV218',
#    'SMV219',
#    'CDMM301',
#    'SMV101',
#    'SMV102',
#    'SJT423',
#    'MGB304',
#    'MGB305',
#    'SJT601',
#    'SJT202',
#    'SJT207A',
#    'SJT422',
#    'MGB105',
#    'MGB202',
#    'SJT807',
#    'SJT501',
#    'MGB106',
#    'SJT424',
#    'MGB201',
#    'TT413',
#    'TT415',
#    'TT414',
#    'TT504',
#    'TT434A',
#    'TT301',
#    'TT302',
#    'CBMR101',
#    'CBMR301',
#    'CBMR402',
#    'CBMR403',
#    'SJT207',
#    'SJT109',
#    'SJT112',
#    'SJT114',
#    'SJT126',
#    'SJT201',
#    'SJT205',
#    'MB305A',
#    'GDN129',
#    'MB312',
#    'PLB522',
#    'MB309A',
#    'GDN128',
#    'MB309',
#    'MB311',
#    'PLB523',
#    'PLB509',
#    'MGB207',
#    'MGB 303',
#    'TT524',
#    'TT206',
#    'SMV313',
#    'SMVG10',
#    'SJT118'],
#   ['4',
#    'SJT617',
#    'SMV116',
#    'SMV220',
#    'SMV219',
#    'SMV111',
#    'SMV214',
#    'SMV109',
#    'SMV128',
#    'SMV218',
#    'CDMM105',
#    'CDMM302',
#    'CDMM301',
#    'SMVG11',
#    'SMV101',
#    'SMV102',
#    'SMVG10',
#    'SJT514',
#    'SJT405',
#    'SJT423',
#    'SJT513',
#    'SJT522',
#    'SJT501',
#    'MGB 303',
#    'MGB106',
#    'MGB201',
#    'MGB304',
#    'SJT601',
#    'MB218',
#    'SJT311A',
#    'SJT424',
#    'MGB110',
#    'SJT521',
#    'SJT323',
#    'MGB305',
#    'SJT404',
#    'SJT508',
#    'MB219',
#    'SJT322',
#    'MGB202',
#    'SJT401',
#    'SJT409',
#    'MGB105',
#    'SJT421',
#    'MGB108',
#    'MB214',
#    'SJT402',
#    'SJT422',
#    'TT112',
#    'TT423',
#    'TT414',
#    'CBMR403',
#    'MGB111',
#    'TT630',
#    'TT631',
#    'CBMR101',
#    'CBMR402',
#    'CBMR301',
#    'MGB208',
#    'TT413',
#    'TT424',
#    'TT415',
#    'TT434A',
#    'TT504',
#    'TT619',
#    'TT523',
#    'TT524',
#    'SJT109',
#    'SJT113',
#    'SJT114',
#    'SJT126',
#    'SJT127',
#    'SJT807',
#    'SJT201',
#    'SJT205',
#    'SJT207',
#    'SJT207A',
#    'SJT208',
#    'SJT211',
#    'SJT211A',
#    'SJT215',
#    'SJT221',
#    'SJT222',
#    'SJT224',
#    'GDN128',
#    'CDMM303',
#    'MB225',
#    'MB226',
#    'MB227',
#    'MB305A',
#    'MB309',
#    'SMV234',
#    'GDN129',
#    'SJT308',
#    'SJT315',
#    'TT531A',
#    'SJT403',
#    'SJT505',
#    'SJT415',
#    'SMV217',
#    'SJT324',
#    'SJT602',
#    'SJT311'],
#   ['24',
#    'SJT109',
#    'SJT112',
#    'SJT113',
#    'SJT114',
#    'SJT522',
#    'SJT401',
#    'SMV128',
#    'SMV220',
#    'SMV116',
#    'SMV217',
#    'SMV218',
#    'CDMM105',
#    'CDMM301',
#    'CDMM302',
#    'SMV102',
#    'SMV101',
#    'SMVG11',
#    'SMV219',
#    'SJT311A',
#    'SJT402',
#    'MGB304',
#    'SJT308',
#    'SJT508',
#    'SJT311',
#    'SJT315',
#    'SJT423',
#    'SJT405',
#    'SJT501',
#    'SJT513',
#    'SJT514',
#    'MB214',
#    'MGB303',
#    'SJT504',
#    'SJT323',
#    'SJT403',
#    'SJT324',
#    'SJT404',
#    'MGB 303',
#    'MGB110',
#    'SJT521',
#    'SJT424',
#    'SJT601',
#    'MGB209',
#    'MB219',
#    'MGB207',
#    'MB218',
#    'SJT415',
#    'TT619',
#    'SJT422',
#    'TT524',
#    'SJT409',
#    'SJT505',
#    'MGB208',
#    'TT415',
#    'TT423',
#    'TT434A',
#    'TT424',
#    'TT434',
#    'CBMR402',
#    'TT304',
#    'TT531A',
#    'TT630',
#    'TT631',
#    'CBMR101',
#    'TT301',
#    'TT208',
#    'TT303',
#    'TT530A',
#    'CBMR403',
#    'CBMR301',
#    'TT523',
#    'SJT127',
#    'SJT201',
#    'SJT205',
#    'SJT207',
#    'SJT207A',
#    'SJT208',
#    'SJT211',
#    'SJT211A',
#    'SJT126',
#    'SJT215',
#    'SJT221',
#    'SJT222',
#    'SJT224',
#    'SJT807',
#    'MB227',
#    'MB311',
#    'MB224',
#    'MB225',
#    'GDN128',
#    'MB226',
#    'MB309A',
#    'MB210',
#    'MB312',
#    'SJT322',
#    'SMVG10',
#    'SMV109',
#    'TT504',
#    'TT413',
#    'TT414',
#    'SJT421',
#    'SMV111',
#    'SMV234',
#    'SMV209',
#    'TT206'],
#   ['17',
#    'TT331',
#    'MB218',
#    'MB219',
#    'MB225',
#    'MB227',
#    'MB305A',
#    'SMV126',
#    'SMV130',
#    'SMV214',
#    'SMV218',
#    'SMV220',
#    'SMV235',
#    'SMV320',
#    'SJT201',
#    'SJT202',
#    'SJT505',
#    'SJT508',
#    'SJT513',
#    'SJT204',
#    'SJT207',
#    'SMV101',
#    'TT531A',
#    'SMV102',
#    'SJT203',
#    'SMV104',
#    'SJT205',
#    'MB110',
#    'SJT207A',
#    'TT423',
#    'SJT401',
#    'MB111',
#    'SJT402',
#    'MB124',
#    'SJT403',
#    'TT424',
#    'SJT404',
#    'MB211',
#    'TT621',
#    'MB212',
#    'SJT405',
#    'TT630',
#    'MB213',
#    'SJT323',
#    'TT725',
#    'SJT409',
#    'TT631',
#    'SJT415',
#    'SJT421',
#    'SJT514',
#    'SJT422',
#    'SJT521',
#    'SJT423',
#    'SJT522',
#    'SJT424',
#    'SJT324',
#    'SJT302',
#    'TT304',
#    'SMV219',
#    'SMV116',
#    'SMV128',
#    'SMV217',
#    'SMVG10',
#    'CDMM105',
#    'CDMM301',
#    'CDMM302',
#    'SMV234',
#    'SMV111',
#    'MB312',
#    'SJT304',
#    'MGB304',
#    'MGB106',
#    'MGB202',
#    'SJT602',
#    'MGB 303',
#    'SJT322',
#    'TT434',
#    'TT434A',
#    'SJT315',
#    'MGB305',
#    'CBMR301',
#    'CBMR402',
#    'CBMR403',
#    'TT504',
#    'TT523',
#    'TT524',
#    'TT619',
#    'CBMR101',
#    'SJT113',
#    'SJT222',
#    'SJT126',
#    'SJT127',
#    'SJT208',
#    'SJT211',
#    'SJT224',
#    'SJT211A',
#    'SJT215',
#    'PLB522',
#    'PLB504',
#    'MB214',
#    'MB226',
#    'MB309',
#    'MB311',
#    'MB309A',
#    'MB224',
#    'SJT308',
#    'SMV109'],
#   ['14',
#    'SJT322',
#    'SJT315',
#    'SJT208',
#    'SJT215',
#    'SJT211A',
#    'SJT211',
#    'SJT221',
#    'SJT222',
#    'SJT401',
#    'SJT402',
#    'SJT403',
#    'SJT404',
#    'SJT405',
#    'SJT308',
#    'SJT311',
#    'SJT324',
#    'SJT311A',
#    'SJT323',
#    'SMV109',
#    'CDMM105',
#    'SMV116',
#    'TT207',
#    'TT208',
#    'MB214',
#    'TT630',
#    'TT631',
#    'MB218',
#    'MB219',
#    'TT531A',
#    'MB224',
#    'MB225',
#    'SJT224',
#    'SJT127',
#    'SJT505',
#    'SJT514',
#    'SJT508',
#    'SJT521',
#    'SJT513',
#    'SJT522',
#    'SMV128',
#    'MB226',
#    'MB227',
#    'MB305A',
#    'TT424',
#    'TT423',
#    'TT434',
#    'TT303',
#    'SJT409',
#    'SJT415',
#    'SMV112',
#    'SMV220',
#    'SMV219',
#    'SMV218',
#    'SMV217',
#    'CDMM301',
#    'CDMM303',
#    'SMV102',
#    'SMV101',
#    'SJT807',
#    'SJT423',
#    'SJT504',
#    'SJT115',
#    'SJT125',
#    'SJT303',
#    'SJT202',
#    'SJT203',
#    'SJT501',
#    'SJT305',
#    'SJT421',
#    'SJT422',
#    'SJT503',
#    'TT414',
#    'TT112',
#    'TT413',
#    'TT434A',
#    'TT206',
#    'TT301',
#    'TT302',
#    'CBMR101',
#    'CBMR301',
#    'CBMR403',
#    'CBMR402',
#    'SJT124',
#    'SJT118',
#    'SJT109',
#    'SJT112',
#    'SJT113',
#    'SJT114',
#    'GDN107',
#    'MB309',
#    'CDMM302',
#    'GDN129',
#    'PLB519',
#    'MB312',
#    'MB311',
#    'MB309A',
#    'SMV234',
#    'GDN128',
#    'PLB522',
#    'SJT617',
#    'TT415'],
#   ['6',
#    'SJT415',
#    'SJT401',
#    'SJT807',
#    'SMV112',
#    'SMV116',
#    'SMV111',
#    'SMV218',
#    'SMV214',
#    'SMV217',
#    'CDMM105',
#    'CDMM302',
#    'CDMM303',
#    'SMV128',
#    'CDMM301',
#    'SMV101',
#    'SMV102',
#    'SJT305',
#    'SJT403',
#    'SJT404',
#    'SJT421',
#    'SJT423',
#    'SJT508',
#    'SJT513',
#    'SJT409',
#    'SJT324',
#    'SJT224',
#    'SJT424',
#    'SJT504',
#    'SJT311A',
#    'SJT501',
#    'SJT505',
#    'SJT521',
#    'SJT405',
#    'SJT402',
#    'SJT503',
#    'SJT514',
#    'SJT322',
#    'SJT422',
#    'TT424',
#    'TT434',
#    'TT434A',
#    'TT523',
#    'TT531A',
#    'TT630',
#    'CBMR101',
#    'CBMR301',
#    'CBMR402',
#    'TT631',
#    'TT415',
#    'TT423',
#    'TT414',
#    'CBMR403',
#    'TT504',
#    'SJT208',
#    'SJT109',
#    'SJT113',
#    'SJT114',
#    'SJT115',
#    'SJT118',
#    'SJT124',
#    'SJT125',
#    'SJT127',
#    'SJT201',
#    'SJT112',
#    'SJT202',
#    'SJT203',
#    'SJT204',
#    'SJT205',
#    'SJT207',
#    'SJT207A',
#    'SJT211',
#    'MB305A',
#    'MB214',
#    'MB309',
#    'MB218',
#    'MB219',
#    'MB224',
#    'MB225',
#    'MB226',
#    'SJT222',
#    'MGB 303',
#    'MB312',
#    'MB227',
#    'MB311',
#    'MB309A',
#    'PLB504',
#    'SJT315',
#    'SJT221',
#    'SMVG10',
#    'SMV109',
#    'SJT211A',
#    'SMVG11',
#    'TT619',
#    'SJT126',
#    'SJT323',
#    'SJT303',
#    'SJT215',
#    'SJT311'],
#   ['26',
#    'SJT109',
#    'SJT112',
#    'SJT113',
#    'SJT324',
#    'SMV111',
#    'TT523',
#    'SMV116',
#    'SMV217',
#    'SMV214',
#    'SMV128',
#    'CDMM304',
#    'CDMM105',
#    'SMV109',
#    'SMV102',
#    'SMV101',
#    'SJT305',
#    'SJT403',
#    'SJT311',
#    'SJT401',
#    'SJT423',
#    'SJT402',
#    'SJT323',
#    'SJT405',
#    'SJT424',
#    'SJT501',
#    'SJT502',
#    'SJT508',
#    'SJT311A',
#    'SJT404',
#    'SJT315',
#    'SJT503',
#    'SJT505',
#    'SJT215',
#    'SJT224',
#    'SJT221',
#    'SJT422',
#    'MB214',
#    'SJT514',
#    'SJT222',
#    'SJT415',
#    'SJT409',
#    'SJT308',
#    'SJT504',
#    'SJT322',
#    'SJT421',
#    'SJT513',
#    'TT112',
#    'TT434A',
#    'TT415',
#    'TT413',
#    'TT414',
#    'TT434',
#    'TT423',
#    'TT424',
#    'TT531A',
#    'TT630',
#    'TT207',
#    'TT208',
#    'TT301',
#    'TT303',
#    'TT530',
#    'CBMR101',
#    'TT206',
#    'TT631',
#    'SJT211A',
#    'SJT114',
#    'SJT115',
#    'SJT118',
#    'SJT124',
#    'SJT807',
#    'SJT125',
#    'SJT127',
#    'SJT201',
#    'SJT202',
#    'SJT126',
#    'SJT203',
#    'SJT204',
#    'SJT205',
#    'SJT211',
#    'SJT208',
#    'SJT207',
#    'GDN107',
#    'MB309',
#    'MB219',
#    'MB224',
#    'MGB105',
#    'MB225',
#    'MB226',
#    'MB311',
#    'MB218',
#    'MB312',
#    'SMVG11',
#    'SMVG10',
#    'SJT207A',
#    'SMV219',
#    'SMV218'],
#   ['19',
#    'MB218',
#    'MB224',
#    'MB225',
#    'MB227',
#    'MB305A',
#    'SMV112',
#    'SMV128',
#    'SMV217',
#    'SMV234',
#    'SMV235',
#    'SMV126',
#    'SJT201',
#    'SJT202',
#    'SJT505',
#    'SJT508',
#    'SJT513',
#    'SJT204',
#    'SJT207',
#    'SMV101',
#    'TT531A',
#    'SMV102',
#    'SJT203',
#    'SMV104',
#    'SJT205',
#    'MB110',
#    'SJT207A',
#    'SJT401',
#    'TT423',
#    'MB111',
#    'SJT402',
#    'MB124',
#    'SJT403',
#    'TT424',
#    'MB211',
#    'SJT404',
#    'TT621',
#    'MB212',
#    'SJT405',
#    'TT630',
#    'MB213',
#    'SJT323',
#    'TT725',
#    'SJT409',
#    'TT631',
#    'SJT415',
#    'SJT421',
#    'SJT514',
#    'SJT521',
#    'SJT422',
#    'SJT522',
#    'SJT423',
#    'SJT424',
#    'SJT324',
#    'SJT303',
#    'TT304',
#    'SMV109',
#    'SMV116',
#    'SMV218',
#    'CDMM105',
#    'CDMM303',
#    'SMV219',
#    'SMV220',
#    'SMVG10',
#    'SJT322',
#    'SJT315',
#    'SJT601',
#    'MB214',
#    'SJT222',
#    'TT434A',
#    'CBMR101',
#    'TT530',
#    'CBMR301',
#    'CBMR403',
#    'CBMR402',
#    'TT504',
#    'TT523',
#    'TT524',
#    'TT303',
#    'SJT112',
#    'SJT114',
#    'SJT126',
#    'SJT113',
#    'SJT115',
#    'SJT118',
#    'SJT124',
#    'SJT211',
#    'SJT211A',
#    'SJT215',
#    'SJT109',
#    'SJT125',
#    'MB311',
#    'MB219',
#    'GDN107',
#    'MB226',
#    'MB309',
#    'PLB509',
#    'TT619',
#    'SJT221']],
#  ['4',
#   ['16',
#    'SJT201',
#    'SJT202',
#    'SJT505',
#    'SJT508',
#    'SJT513',
#    'SJT204',
#    'SJT207',
#    'SMV101',
#    'TT531A',
#    'SMV102',
#    'SJT203',
#    'SMV104',
#    'SJT205',
#    'MB110',
#    'SJT207A',
#    'TT423',
#    'SJT401',
#    'MB111',
#    'SJT402',
#    'MB124',
#    'SJT403',
#    'TT424',
#    'SJT404',
#    'MB211',
#    'TT621',
#    'MB212',
#    'SJT405',
#    'TT630',
#    'MB213',
#    'SJT323',
#    'TT725',
#    'SJT409',
#    'TT631',
#    'SJT415',
#    'SJT421',
#    'SJT514',
#    'SJT422',
#    'SJT521',
#    'SJT423',
#    'SJT522',
#    'SJT424',
#    'SJT324',
#    'SMV219',
#    'SMV116',
#    'SMV128',
#    'SMV217',
#    'SMVG10',
#    'SMV214',
#    'SMV218',
#    'CDMM105',
#    'CDMM301',
#    'CDMM302',
#    'SMV234',
#    'SMV220',
#    'SMV111',
#    'MGB303',
#    'MB312',
#    'SJT311',
#    'SJT311A',
#    'MGB110',
#    'MGB304',
#    'MGB106',
#    'MB219',
#    'MGB202',
#    'SJT501',
#    'MGB105',
#    'MGB201',
#    'SJT601',
#    'MB218',
#    'SJT602',
#    'MGB 303',
#    'SJT322',
#    'TT434A',
#    'SJT315',
#    'MB214',
#    'MGB305',
#    'CBMR301',
#    'MGB111',
#    'CBMR402',
#    'CBMR403',
#    'TT504',
#    'TT523',
#    'TT524',
#    'TT619',
#    'CBMR101',
#    'SJT113',
#    'SJT126',
#    'SJT127',
#    'SJT208',
#    'SJT211',
#    'SJT211A',
#    'SJT215',
#    'SJT221',
#    'SJT222',
#    'SJT112',
#    'SJT224',
#    'PLB522',
#    'PLB504',
#    'PLB509',
#    'MB226',
#    'MB227',
#    'MB305A',
#    'MB309',
#    'MB311',
#    'MB225',
#    'MB309A',
#    'MB224',
#    'SJT308',
#    'TT434',
#    'SMV109',
#    'TT331'],
#   ['8',
#    'SJT617',
#    'MB214',
#    'SJT508',
#    'SJT513',
#    'SJT514',
#    'SJT521',
#    'SJT522',
#    'SJT401',
#    'SJT402',
#    'SJT403',
#    'SJT404',
#    'SJT112',
#    'SJT113',
#    'SJT405',
#    'SJT409',
#    'SJT315',
#    'SJT415',
#    'MB218',
#    'MB219',
#    'MB224',
#    'SMV217',
#    'SMV109',
#    'SMV116',
#    'SMV128',
#    'SMV209',
#    'SMV219',
#    'SMV220',
#    'SMV234',
#    'SMV218',
#    'SMV320',
#    'CDMM105',
#    'CDMM303',
#    'CDMM301',
#    'CDMM302',
#    'SMV102',
#    'SMV101',
#    'SJT421',
#    'MGB304',
#    'MGB106',
#    'SJT323',
#    'SJT311',
#    'MGB305',
#    'SJT311A',
#    'SJT505',
#    'MGB 303',
#    'SJT601',
#    'MGB303',
#    'TT206',
#    'TT504',
#    'TT619',
#    'MB309',
#    'SJT807',
#    'SJT324',
#    'SJT501',
#    'SJT423',
#    'MGB202',
#    'SJT308',
#    'MB311',
#    'SJT422',
#    'SJT424',
#    'MB227',
#    'MB305A',
#    'MGB207',
#    'SJT322',
#    '519',
#    'MGB201',
#    'MGB110',
#    'MB225',
#    'TT424',
#    'TT423',
#    'TT434A',
#    'MB226',
#    'TT434',
#    'TT531A',
#    'TT630',
#    'TT301',
#    'TT302',
#    'TT621A',
#    'TT631',
#    'TT207',
#    'TT303',
#    'CBMR403',
#    'CBMR101',
#    'CBMR301',
#    'CBMR402',
#    'SJT109',
#    'SJT114',
#    'SJT126',
#    'SJT201',
#    'SJT204',
#    'SJT205',
#    'SJT224',
#    'SJT207A',
#    'SJT208',
#    'SJT222',
#    'SJT211A',
#    'SJT215',
#    'SJT221',
#    'SJT207',
#    'GDN129',
#    'PLB519',
#    'GDN107',
#    'GDN128',
#    'MB312',
#    'CDMM304',
#    'PLB523',
#    'PLB504',
#    'PLB509',
#    'PLB522',
#    'PLB619',
#    'MB309A',
#    'TT524',
#    'TT523',
#    'SMVG11',
#    'SMVG10'],
#   ['1',
#    'SJT415',
#    'SJT617',
#    'MB214',
#    'SJT508',
#    'SJT513',
#    'SJT521',
#    'SJT315',
#    'SJT112',
#    'SJT113',
#    'SJT401',
#    'SJT404',
#    'SJT405',
#    'MB218',
#    'MB224',
#    'MB225',
#    'SJT323',
#    'SMVG10',
#    'SMV116',
#    'SMV217',
#    'SMV219',
#    'SMV128',
#    'SMV209',
#    'SMV234',
#    'SMV109',
#    'CDMM301',
#    'CDMM105',
#    'SMV101',
#    'SJT505',
#    'SJT402',
#    'SJT423',
#    'SJT302',
#    'SJT322',
#    'SJT501',
#    'MGB105',
#    'TT630',
#    'MGB201',
#    'MGB110',
#    'MGB305',
#    'MB226',
#    'SJT601',
#    'SJT421',
#    'SJT303',
#    'SJT308',
#    'SJT311A',
#    'MGB 303',
#    'SJT305',
#    'SJT409',
#    'SJT424',
#    'SJT514',
#    'MGB304',
#    'SJT602',
#    'TT434A',
#    'SMV220',
#    'TT530A',
#    'TT531A',
#    'TT631',
#    'CBMR101',
#    'CBMR402',
#    'TT619',
#    'CBMR403',
#    'TT504',
#    'TT523',
#    'SJT201',
#    'SJT205',
#    'SJT207',
#    'SJT207A',
#    'SJT208',
#    'SJT211',
#    'SJT211A',
#    'SJT221',
#    'SJT222',
#    'SJT807',
#    'MB309',
#    'CDMM303',
#    'MB305A',
#    'PLB519',
#    'MB219',
#    'GDN128',
#    'MB227',
#    'PLB509',
#    'GDN129',
#    'PLB504',
#    'PLB522',
#    'MB312',
#    'PLB622',
#    'MB309A'],
#   ['21',
#    'SMV109',
#    'MB214',
#    'MB218',
#    'TT630',
#    'TT434',
#    'SJT109',
#    'TT621',
#    'TT619',
#    'SMV111',
#    'SMV209',
#    'SMV217',
#    'SMV219',
#    'SMV220',
#    'SMV218',
#    'SMV234',
#    'CDMM303',
#    'SMV101',
#    'SMV102',
#    'MGB110',
#    'SJT405',
#    'SJT424',
#    'TT413',
#    'TT424',
#    'TT434A',
#    'TT423',
#    'TT414',
#    'TT301',
#    'TT302',
#    'TT303',
#    'TT531A',
#    'TT631',
#    'SJT207',
#    'SJT207A',
#    'SJT112',
#    'SJT126',
#    'SJT201',
#    'SJT205',
#    'SJT127',
#    'SMVG11',
#    'MB225',
#    'MB226',
#    'MB305A',
#    'PLB509',
#    'MB224',
#    'MB311',
#    'MB309A',
#    'CDMM105',
#    'SJT807',
#    'MB227',
#    'MB219',
#    'SMV112',
#    'SMV116',
#    'PLB519',
#    'SJT315',
#    'TT504',
#    'TT524',
#    'TT206'],
#   ['13',
#    'SJT322',
#    'SJT315',
#    'SJT208',
#    'SJT211A',
#    'SJT211',
#    'SJT215',
#    'SJT221',
#    'SJT222',
#    'SJT401',
#    'SJT402',
#    'SJT403',
#    'SJT404',
#    'SJT405',
#    'SJT308',
#    'SJT324',
#    'SJT311',
#    'SJT311A',
#    'SJT323',
#    'SMV109',
#    'CDMM105',
#    'SMV116',
#    'TT207',
#    'TT208',
#    'MB214',
#    'TT630',
#    'TT631',
#    'MB218',
#    'TT531A',
#    'MB219',
#    'MB224',
#    'MB225',
#    'SJT224',
#    'SJT127',
#    'SJT505',
#    'SJT514',
#    'SJT508',
#    'SJT521',
#    'SJT513',
#    'SJT522',
#    'MB226',
#    'SMV128',
#    'MB227',
#    'SMV217',
#    'TT424',
#    'TT423',
#    'TT434',
#    'TT303',
#    'SJT409',
#    'SJT415',
#    'SJT421',
#    'SJT202',
#    'SMV220',
#    'SMV234',
#    'SMV218',
#    'SMV219',
#    'SMV102',
#    'SJT423',
#    'MGB304',
#    'MGB305',
#    'SJT207A',
#    'SJT807',
#    'SJT501',
#    'MGB106',
#    'SJT424',
#    'MGB201',
#    'TT504',
#    'TT434A',
#    'TT206',
#    'TT301',
#    'TT302',
#    'CBMR101',
#    'CBMR301',
#    'CBMR402',
#    'CBMR403',
#    'SJT207',
#    'SJT109',
#    'SJT112',
#    'SJT114',
#    'SJT126',
#    'SJT201',
#    'SJT205',
#    'GDN129',
#    'MB312',
#    'PLB522',
#    'GDN128',
#    'MB309',
#    'PLB509',
#    'MGB207',
#    'SMVG10',
#    'SJT118'],
#   ['18',
#    'SJT201',
#    'SJT202',
#    'SJT505',
#    'SJT508',
#    'SJT513',
#    'SJT204',
#    'SJT207',
#    'SMV101',
#    'TT531A',
#    'SMV102',
#    'SJT203',
#    'SMV104',
#    'SJT205',
#    'MB110',
#    'SJT207A',
#    'SJT401',
#    'TT423',
#    'MB111',
#    'SJT402',
#    'MB124',
#    'SJT403',
#    'TT424',
#    'MB211',
#    'SJT404',
#    'TT621',
#    'MB212',
#    'SJT405',
#    'TT630',
#    'MB213',
#    'SJT323',
#    'TT725',
#    'SJT409',
#    'TT631',
#    'SJT415',
#    'SJT421',
#    'SJT514',
#    'SJT521',
#    'SJT422',
#    'SJT522',
#    'SJT423',
#    'SJT424',
#    'SJT324',
#    'SMV109',
#    'SMV112',
#    'SMV116',
#    'SMV218',
#    'SMV214',
#    'SMV128',
#    'CDMM105',
#    'CDMM303',
#    'SMV219',
#    'SMV220',
#    'SMVG10',
#    'SJT501',
#    'SJT322',
#    'SJT223',
#    'SJT308',
#    'SJT315',
#    'SJT504',
#    'SJT311',
#    'SJT311A',
#    'SJT502',
#    'SJT503',
#    'SJT224',
#    'SJT601',
#    'MB214',
#    'SJT222',
#    'TT434A',
#    'TT434',
#    'TT530',
#    'CBMR101',
#    'CBMR301',
#    'CBMR403',
#    'CBMR402',
#    'TT504',
#    'TT523',
#    'TT524',
#    'TT303',
#    'SJT109',
#    'SJT112',
#    'SJT114',
#    'SJT113',
#    'SJT115',
#    'SJT118',
#    'SJT124',
#    'SJT125',
#    'SJT126',
#    'SJT127',
#    'SJT208',
#    'SJT211',
#    'SJT211A',
#    'SJT215',
#    'MB311',
#    'MB312',
#    'MB219',
#    'MB224',
#    'GDN107',
#    'MB225',
#    'MB226',
#    'MB227',
#    'MB218',
#    'MB309',
#    'PLB509',
#    'TT619',
#    'SJT221'],
#   ['10',
#    'MB214',
#    'SJT421',
#    'SJT505',
#    'SJT508',
#    'SJT513',
#    'SJT514',
#    'SJT521',
#    'SJT522',
#    'SJT401',
#    'SJT402',
#    'SJT404',
#    'SJT403',
#    'SJT112',
#    'SJT405',
#    'MB218',
#    'MB224',
#    'MB225',
#    'SJT617',
#    'SMV217',
#    'SMV220',
#    'SMV112',
#    'SMV218',
#    'SMV219',
#    'SMV128',
#    'CDMM301',
#    'CDMM105',
#    'CDMM302',
#    'SJT224',
#    'SJT504',
#    'SJT423',
#    'SJT315',
#    'SJT422',
#    'SJT415',
#    'SJT202',
#    'SJT807',
#    'SJT203',
#    'SJT222',
#    'SJT308',
#    'SJT409',
#    'SJT501',
#    'SJT311',
#    'SJT303',
#    'SJT324',
#    'SJT322',
#    'SJT424',
#    'SJT113',
#    'SJT207',
#    'SJT221',
#    'SJT323',
#    'SJT311A',
#    'TT112',
#    'TT523',
#    'TT434',
#    'TT434A',
#    'TT424',
#    'TT208',
#    'CBMR101',
#    'TT301',
#    'TT302',
#    'TT531A',
#    'TT207',
#    'TT423',
#    'CBMR301',
#    'TT630',
#    'SJT109',
#    'SJT114',
#    'SJT115',
#    'SJT204',
#    'SJT118',
#    'SJT124',
#    'SJT127',
#    'SJT207A',
#    'SJT205',
#    'SJT125',
#    'SJT126',
#    'SJT211A',
#    'SJT208',
#    'MB312',
#    'MB219',
#    'MB305A',
#    'MB309',
#    'PLB519',
#    'CDMM303',
#    'MB311',
#    'PLB522',
#    'PLB523',
#    'MB226',
#    'MB227',
#    'SJT201',
#    'SJT305',
#    'SMV109',
#    'SJT211',
#    'SJT215',
#    'TT331',
#    'SMV234',
#    'TT504'],
#   ['3',
#    'TT523',
#    'SJT415',
#    'SJT505',
#    'SJT508',
#    'SJT513',
#    'SJT514',
#    'SJT521',
#    'SJT401',
#    'SJT402',
#    'SJT403',
#    'SJT404',
#    'SJT112',
#    'SJT113',
#    'TT630',
#    'MB219',
#    'MB224',
#    'CDMM105',
#    'SJT223',
#    'CDMM302',
#    'SMV116',
#    'SMV219',
#    'SMV218',
#    'SMV217',
#    'SMV209',
#    'SMV234',
#    'SMV220',
#    'CDMM301',
#    'SMV112',
#    'SMV101',
#    'SMV128',
#    'SJT315',
#    'SJT323',
#    'SJT305',
#    'SJT501',
#    'MGB109',
#    'MGB202',
#    'TT631',
#    'SJT522',
#    'SJT421',
#    'SJT807',
#    'SJT322',
#    'SJT405',
#    'MGB207',
#    'SJT423',
#    'SJT409',
#    'SJT424',
#    'MGB106',
#    'SJT503',
#    'SJT601',
#    'TT112',
#    'SJT222',
#    'TT434A',
#    'TT434',
#    'TT504',
#    'TT531A',
#    'CBMR101',
#    'SJT205',
#    'CBMR301',
#    'SJT211A',
#    'CBMR402',
#    'SJT109',
#    'SJT114',
#    'SJT115',
#    'SJT118',
#    'SJT124',
#    'SJT125',
#    'SJT207',
#    'SJT126',
#    'SJT202',
#    'SJT204',
#    'SJT207A',
#    'MB226',
#    'MB214',
#    'GDN107',
#    'MB309',
#    'MB225',
#    'PLB622',
#    'PLB509',
#    'SMV109',
#    'PLB504',
#    'PLB519',
#    'PLB522',
#    'MB227',
#    'MGB303',
#    'SJT308',
#    'TT331'],
#   ['23',
#    'SMV109',
#    'MB214',
#    'TT630',
#    'TT434',
#    'SJT415',
#    'TT619',
#    'SMV217',
#    'SMV111',
#    'SMV219',
#    'SMV218',
#    'SMV128',
#    'CDMM301',
#    'CDMM105',
#    'SMV102',
#    'SJT401',
#    'SJT501',
#    'SJT324',
#    'TT434A',
#    'TT424',
#    'TT206',
#    'TT301',
#    'TT302',
#    'TT303',
#    'TT621',
#    'TT504',
#    'SJT112',
#    'SJT114',
#    'SJT109',
#    'SJT115',
#    'SJT118',
#    'SJT124',
#    'MB225',
#    'MB226',
#    'MB227',
#    'MB305A',
#    'MB309',
#    'MB312',
#    'MB311',
#    'MB309A',
#    'MB218',
#    'MB219',
#    'MB224',
#    'SMV101',
#    'SMV116',
#    'SMVG11',
#    'SJT207A']]]

# %%
buildingwise=[]
buildings=['SJT','TT','SMV','MGB','MB','CBMR','CDMM','GDN','PLB','PRB']
c=0
for i in range(len(daywise)):
    buildingwise.append([])
    for j in range(1,len(daywise[i])):
        buildingwise[i].append([[],[],[],[],[],[],[],[],[],[]])
        for k in range(1,len(daywise[i][j])):
            for l in range(len(buildings)):
                if(daywise[i][j][k][:len(buildings[l])]==buildings[l]):
                    buildingwise[i][j-1][l].append(daywise[i][j][k])

# %%
print(str(daywise[1][4][64]))
print(c)
# Out:
# 519
# 0

# %%
buildingwise
# Out:
# [[[['SJT415',
#     'SJT617',
#     'SJT508',
#     'SJT513',
#     'SJT521',
#     'SJT315',
#     'SJT112',
#     'SJT113',
#     'SJT401',
#     'SJT404',
#     'SJT405',
#     'SJT505',
#     'SJT324',
#     'SJT402',
#     'SJT403',
#     'SJT422',
#     'SJT423',
#     'SJT302',
#     'SJT322',
#     'SJT501',
#     'SJT601',
#     'SJT323',
#     'SJT421',
#     'SJT522',
#     'SJT303',
#     'SJT308',
#     'SJT311A',
#     'SJT305',
#     'SJT409',
#     'SJT424',
#     'SJT514',
#     'SJT602',
#     'SJT201',
#     'SJT205',
#     'SJT207',
#     'SJT207A',
#     'SJT208',
#     'SJT211',
#     'SJT211A',
#     'SJT215',
#     'SJT221',
#     'SJT222',
#     'SJT224',
#     'SJT807',
#     'SJT304',
#     'SJT127',
#     'SJT311'],
#    ['TT630',
#     'TT434A',
#     'TT424',
#     'TT423',
#     'TT434',
#     'TT335',
#     'TT531A',
#     'TT631',
#     'TT619',
#     'TT504',
#     'TT523',
#     'TT524'],
#    ['SMVG10',
#     'SMV116',
#     'SMV217',
#     'SMV218',
#     'SMV219',
#     'SMV128',
#     'SMV209',
#     'SMV234',
#     'SMV109',
#     'SMV101',
#     'SMV102',
#     'SMV220',
#     'SMV320'],
#    ['MGB105', 'MGB201', 'MGB110', 'MGB305', 'MGB 303', 'MGB304'],
#    ['MB214',
#     'MB218',
#     'MB224',
#     'MB225',
#     'MB226',
#     'MB305A',
#     'MB219',
#     'MB227',
#     'MB312',
#     'MB311',
#     'MB309A'],
#    ['CBMR101', 'CBMR402', 'CBMR403'],
#    ['CDMM105', 'CDMM302', 'CDMM303'],
#    ['GDN128', 'GDN129'],
#    ['PLB519', 'PLB509', 'PLB504', 'PLB522', 'PLB622'],
#    []],
#   [['SJT109',
#     'SJT204',
#     'SJT617',
#     'SJT311A',
#     'SJT404',
#     'SJT501',
#     'SJT521',
#     'SJT208',
#     'SJT211',
#     'SJT211A',
#     'SJT215',
#     'SJT221',
#     'SJT222',
#     'SJT224',
#     'SJT402',
#     'SJT308',
#     'SJT323',
#     'SJT403',
#     'SJT401',
#     'SJT409',
#     'SJT422',
#     'SJT423',
#     'SJT504',
#     'SJT505',
#     'SJT508',
#     'SJT513',
#     'SJT807',
#     'SJT522',
#     'SJT415',
#     'SJT421',
#     'SJT405',
#     'SJT424',
#     'SJT203',
#     'SJT207',
#     'SJT207A',
#     'SJT112',
#     'SJT113',
#     'SJT114',
#     'SJT126',
#     'SJT201',
#     'SJT205',
#     'SJT127',
#     'SJT322',
#     'SJT315',
#     'SJT324',
#     'SJT311'],
#    ['TT630',
#     'TT434',
#     'TT413',
#     'TT424',
#     'TT434A',
#     'TT414',
#     'TT415',
#     'TT423',
#     'TT301',
#     'TT302',
#     'TT303',
#     'TT531A',
#     'TT631',
#     'TT334',
#     'TT523',
#     'TT504',
#     'TT524',
#     'TT206'],
#    ['SMV109',
#     'SMV116',
#     'SMV111',
#     'SMV209',
#     'SMV217',
#     'SMV219',
#     'SMV220',
#     'SMV218',
#     'SMV234',
#     'SMV214',
#     'SMV128',
#     'SMV102',
#     'SMV101',
#     'SMVG11',
#     'SMVG10'],
#    ['MGB201', 'MGB106', 'MGB 303', 'MGB110', 'MGB202'],
#    ['MB214',
#     'MB218',
#     'MB225',
#     'MB226',
#     'MB224',
#     'MB305A',
#     'MB227',
#     'MB309A',
#     'MB309',
#     'MB311',
#     'MB219',
#     'MB312'],
#    ['CBMR101', 'CBMR301', 'CBMR402', 'CBMR403'],
#    ['CDMM301', 'CDMM303', 'CDMM302', 'CDMM105', 'CDMM304'],
#    ['GDN129', 'GDN128'],
#    ['PLB509', 'PLB622', 'PLB519'],
#    []],
#   [['SJT322',
#     'SJT315',
#     'SJT208',
#     'SJT211A',
#     'SJT211',
#     'SJT215',
#     'SJT221',
#     'SJT222',
#     'SJT401',
#     'SJT402',
#     'SJT403',
#     'SJT404',
#     'SJT405',
#     'SJT308',
#     'SJT324',
#     'SJT311',
#     'SJT311A',
#     'SJT323',
#     'SJT224',
#     'SJT127',
#     'SJT505',
#     'SJT514',
#     'SJT508',
#     'SJT521',
#     'SJT513',
#     'SJT522',
#     'SJT409',
#     'SJT415',
#     'SJT421',
#     'SJT423',
#     'SJT601',
#     'SJT202',
#     'SJT207A',
#     'SJT422',
#     'SJT807',
#     'SJT501',
#     'SJT424',
#     'SJT207',
#     'SJT109',
#     'SJT112',
#     'SJT114',
#     'SJT126',
#     'SJT201',
#     'SJT205',
#     'SJT118'],
#    ['TT207',
#     'TT208',
#     'TT630',
#     'TT631',
#     'TT531A',
#     'TT424',
#     'TT423',
#     'TT434',
#     'TT303',
#     'TT413',
#     'TT415',
#     'TT414',
#     'TT504',
#     'TT434A',
#     'TT301',
#     'TT302',
#     'TT524',
#     'TT206'],
#    ['SMV109',
#     'SMV116',
#     'SMV128',
#     'SMV217',
#     'SMV220',
#     'SMV234',
#     'SMV209',
#     'SMV218',
#     'SMV219',
#     'SMV101',
#     'SMV102',
#     'SMV313',
#     'SMVG10'],
#    ['MGB304',
#     'MGB305',
#     'MGB105',
#     'MGB202',
#     'MGB106',
#     'MGB201',
#     'MGB207',
#     'MGB 303'],
#    ['MB214',
#     'MB218',
#     'MB219',
#     'MB224',
#     'MB225',
#     'MB226',
#     'MB227',
#     'MB305A',
#     'MB312',
#     'MB309A',
#     'MB309',
#     'MB311'],
#    ['CBMR101', 'CBMR301', 'CBMR402', 'CBMR403'],
#    ['CDMM105', 'CDMM301'],
#    ['GDN129', 'GDN128'],
#    ['PLB522', 'PLB523', 'PLB509'],
#    []],
#   [['SJT617',
#     'SJT514',
#     'SJT405',
#     'SJT423',
#     'SJT513',
#     'SJT522',
#     'SJT501',
#     'SJT601',
#     'SJT521',
#     'SJT323',
#     'SJT404',
#     'SJT508',
#     'SJT322',
#     'SJT401',
#     'SJT409',
#     'SJT109',
#     'SJT113',
#     'SJT114',
#     'SJT126',
#     'SJT127',
#     'SJT807',
#     'SJT201',
#     'SJT205',
#     'SJT207',
#     'SJT207A',
#     'SJT208',
#     'SJT211',
#     'SJT211A',
#     'SJT215',
#     'SJT221',
#     'SJT222',
#     'SJT224',
#     'SJT308',
#     'SJT403',
#     'SJT505',
#     'SJT415',
#     'SJT324',
#     'SJT602'],
#    ['TT423', 'TT414', 'TT304', 'TT630', 'TT631', 'TT504', 'TT523', 'TT524'],
#    ['SMV116',
#     'SMV220',
#     'SMV219',
#     'SMV111',
#     'SMV109',
#     'SMV128',
#     'SMVG11',
#     'SMV234',
#     'SMV217'],
#    ['MGB 303', 'MGB106', 'MGB201', 'MGB304', 'MGB305', 'MGB202', 'MGB105'],
#    ['MB218', 'MB219', 'MB225', 'MB226', 'MB227', 'MB305A', 'MB309'],
#    ['CBMR403', 'CBMR101', 'CBMR402', 'CBMR301'],
#    ['CDMM105', 'CDMM302', 'CDMM303'],
#    ['GDN128', 'GDN129'],
#    [],
#    []],
#   [['SJT109',
#     'SJT112',
#     'SJT113',
#     'SJT114',
#     'SJT522',
#     'SJT401',
#     'SJT402',
#     'SJT505',
#     'SJT308',
#     'SJT508',
#     'SJT311',
#     'SJT315',
#     'SJT423',
#     'SJT405',
#     'SJT501',
#     'SJT513',
#     'SJT514',
#     'SJT504',
#     'SJT323',
#     'SJT403',
#     'SJT324',
#     'SJT404',
#     'SJT521',
#     'SJT424',
#     'SJT601',
#     'SJT415',
#     'SJT422',
#     'SJT409',
#     'SJT127',
#     'SJT201',
#     'SJT205',
#     'SJT207A',
#     'SJT208',
#     'SJT211',
#     'SJT211A',
#     'SJT126',
#     'SJT215',
#     'SJT807',
#     'SJT602'],
#    ['TT413',
#     'TT524',
#     'TT415',
#     'TT423',
#     'TT424',
#     'TT434',
#     'TT304',
#     'TT531A',
#     'TT301',
#     'TT208',
#     'TT303',
#     'TT530A',
#     'TT523',
#     'TT206'],
#    ['SMV128',
#     'SMV112',
#     'SMV220',
#     'SMV116',
#     'SMV217',
#     'SMV218',
#     'SMV102',
#     'SMV101',
#     'SMVG11',
#     'SMV219',
#     'SMV209'],
#    ['MGB304', 'MGB303', 'MGB 303', 'MGB110', 'MGB209', 'MGB207', 'MGB208'],
#    ['MB214',
#     'MB219',
#     'MB218',
#     'MB311',
#     'MB224',
#     'MB226',
#     'MB309A',
#     'MB210',
#     'MB312'],
#    ['CBMR301', 'CBMR101'],
#    ['CDMM304'],
#    ['GDN128'],
#    [],
#    []],
#   [['SJT415',
#     'SJT505',
#     'SJT508',
#     'SJT513',
#     'SJT514',
#     'SJT521',
#     'SJT401',
#     'SJT402',
#     'SJT403',
#     'SJT404',
#     'SJT112',
#     'SJT113',
#     'SJT617',
#     'SJT303',
#     'SJT224',
#     'SJT315',
#     'SJT323',
#     'SJT305',
#     'SJT501',
#     'SJT522',
#     'SJT302',
#     'SJT311A',
#     'SJT421',
#     'SJT807',
#     'SJT504',
#     'SJT322',
#     'SJT405',
#     'SJT423',
#     'SJT409',
#     'SJT424',
#     'SJT503',
#     'SJT601',
#     'SJT222',
#     'SJT205',
#     'SJT211A',
#     'SJT109',
#     'SJT114',
#     'SJT115',
#     'SJT118',
#     'SJT124',
#     'SJT125',
#     'SJT207',
#     'SJT126',
#     'SJT127',
#     'SJT201',
#     'SJT202',
#     'SJT203',
#     'SJT204',
#     'SJT207A',
#     'SJT308',
#     'SJT304',
#     'SJT208',
#     'SJT211',
#     'SJT221',
#     'SJT215',
#     'SJT324',
#     'SJT422',
#     'SJT311'],
#    ['TT523',
#     'TT630',
#     'TT631',
#     'TT112',
#     'TT423',
#     'TT424',
#     'TT434A',
#     'TT434',
#     'TT504',
#     'TT531A',
#     'TT524',
#     'TT619',
#     'TT331'],
#    ['SMV116',
#     'SMV219',
#     'SMV218',
#     'SMV217',
#     'SMV209',
#     'SMV234',
#     'SMV220',
#     'SMV112',
#     'SMV101',
#     'SMV128',
#     'SMV102',
#     'SMV109',
#     'SMVG10'],
#    ['MGB109', 'MGB202', 'MGB110', 'MGB207', 'MGB106', 'MGB303'],
#    ['MB219', 'MB224', 'MB214', 'MB309', 'MB225', 'MB227'],
#    ['CBMR101', 'CBMR301', 'CBMR403', 'CBMR402'],
#    ['CDMM105', 'CDMM302', 'CDMM301'],
#    ['GDN107'],
#    ['PLB622', 'PLB509', 'PLB504', 'PLB519', 'PLB522'],
#    []],
#   [['SJT415',
#     'SJT522',
#     'SJT423',
#     'SJT223',
#     'SJT305',
#     'SJT401',
#     'SJT311A',
#     'SJT405',
#     'SJT501',
#     'SJT208',
#     'SJT211',
#     'SJT211A',
#     'SJT125',
#     'SJT126',
#     'SJT222',
#     'SJT308',
#     'SJT403',
#     'SJT402',
#     'SJT409',
#     'SJT323',
#     'SJT404',
#     'SJT201',
#     'SJT421',
#     'SJT221',
#     'SJT202',
#     'SJT504',
#     'SJT503',
#     'SJT505',
#     'SJT422',
#     'SJT508',
#     'SJT315',
#     'SJT322',
#     'SJT424',
#     'SJT324',
#     'SJT112',
#     'SJT113',
#     'SJT114',
#     'SJT109',
#     'SJT115',
#     'SJT118',
#     'SJT124',
#     'SJT207A'],
#    ['TT630',
#     'TT434',
#     'TT434A',
#     'TT414',
#     'TT415',
#     'TT424',
#     'TT301',
#     'TT302',
#     'TT303',
#     'TT621',
#     'TT504',
#     'TT207',
#     'TT208',
#     'TT331',
#     'TT631',
#     'TT413',
#     'TT423',
#     'TT524'],
#    ['SMV109',
#     'SMV217',
#     'SMV111',
#     'SMV219',
#     'SMV218',
#     'SMV128',
#     'SMV214',
#     'SMV116',
#     'SMV102',
#     'SMVG11'],
#    ['MGB105', 'MGB106'],
#    ['MB214',
#     'MB225',
#     'MB226',
#     'MB227',
#     'MB218',
#     'MB305A',
#     'MB309',
#     'MB312',
#     'MB311',
#     'MB309A',
#     'MB224',
#     'MB219'],
#    ['CBMR101'],
#    ['CDMM304', 'CDMM301', 'CDMM105', 'CDMM303'],
#    ['GDN107', 'GDN129', 'GDN128'],
#    ['PLB523'],
#    []],
#   [['SJT322',
#     'SJT315',
#     'SJT208',
#     'SJT215',
#     'SJT211A',
#     'SJT211',
#     'SJT221',
#     'SJT222',
#     'SJT401',
#     'SJT402',
#     'SJT403',
#     'SJT404',
#     'SJT405',
#     'SJT308',
#     'SJT311',
#     'SJT324',
#     'SJT311A',
#     'SJT323',
#     'SJT224',
#     'SJT127',
#     'SJT505',
#     'SJT514',
#     'SJT508',
#     'SJT521',
#     'SJT513',
#     'SJT522',
#     'SJT409',
#     'SJT415',
#     'SJT807',
#     'SJT423',
#     'SJT504',
#     'SJT115',
#     'SJT125',
#     'SJT303',
#     'SJT202',
#     'SJT203',
#     'SJT501',
#     'SJT305',
#     'SJT421',
#     'SJT422',
#     'SJT503',
#     'SJT124',
#     'SJT118',
#     'SJT109',
#     'SJT112',
#     'SJT113',
#     'SJT114',
#     'SJT617'],
#    ['TT207',
#     'TT208',
#     'TT630',
#     'TT631',
#     'TT531A',
#     'TT424',
#     'TT423',
#     'TT434',
#     'TT303',
#     'TT414',
#     'TT112',
#     'TT413',
#     'TT434A',
#     'TT206',
#     'TT301',
#     'TT302',
#     'TT415'],
#    ['SMV109',
#     'SMV116',
#     'SMV128',
#     'SMV112',
#     'SMV220',
#     'SMV219',
#     'SMV218',
#     'SMV217',
#     'SMV102',
#     'SMV101',
#     'SMV234'],
#    [],
#    ['MB214',
#     'MB218',
#     'MB219',
#     'MB224',
#     'MB225',
#     'MB226',
#     'MB227',
#     'MB305A',
#     'MB309',
#     'MB312',
#     'MB311',
#     'MB309A'],
#    ['CBMR101', 'CBMR301', 'CBMR403', 'CBMR402'],
#    ['CDMM105', 'CDMM301', 'CDMM303', 'CDMM302'],
#    ['GDN107', 'GDN129', 'GDN128'],
#    ['PLB519', 'PLB522'],
#    []],
#   [['SJT415',
#     'SJT401',
#     'SJT807',
#     'SJT305',
#     'SJT403',
#     'SJT404',
#     'SJT421',
#     'SJT423',
#     'SJT508',
#     'SJT513',
#     'SJT409',
#     'SJT424',
#     'SJT504',
#     'SJT311A',
#     'SJT501',
#     'SJT505',
#     'SJT521',
#     'SJT405',
#     'SJT208',
#     'SJT113',
#     'SJT114',
#     'SJT115',
#     'SJT118',
#     'SJT124',
#     'SJT125',
#     'SJT127',
#     'SJT112',
#     'SJT202',
#     'SJT203',
#     'SJT204',
#     'SJT205',
#     'SJT207',
#     'SJT207A',
#     'SJT211',
#     'SJT222',
#     'SJT602',
#     'SJT323',
#     'SJT303'],
#    ['TT424',
#     'TT434',
#     'TT434A',
#     'TT523',
#     'TT304',
#     'TT531A',
#     'TT630',
#     'TT631',
#     'TT504'],
#    ['SMV112', 'SMV116', 'SMV111', 'SMV218', 'SMV217', 'SMV128', 'SMV102'],
#    ['MGB 303'],
#    ['MB305A',
#     'MB214',
#     'MB309',
#     'MB218',
#     'MB219',
#     'MB224',
#     'MB225',
#     'MB226',
#     'MB312',
#     'MB227',
#     'MB311',
#     'MB309A'],
#    ['CBMR101', 'CBMR301', 'CBMR402', 'CBMR403'],
#    ['CDMM105', 'CDMM302', 'CDMM303'],
#    [],
#    ['PLB504'],
#    []],
#   [['SJT109',
#     'SJT112',
#     'SJT113',
#     'SJT324',
#     'SJT305',
#     'SJT403',
#     'SJT311',
#     'SJT401',
#     'SJT423',
#     'SJT402',
#     'SJT323',
#     'SJT405',
#     'SJT424',
#     'SJT501',
#     'SJT502',
#     'SJT508',
#     'SJT311A',
#     'SJT404',
#     'SJT315',
#     'SJT505',
#     'SJT215',
#     'SJT224',
#     'SJT221',
#     'SJT422',
#     'SJT514',
#     'SJT222',
#     'SJT415',
#     'SJT409',
#     'SJT308',
#     'SJT504',
#     'SJT322',
#     'SJT513',
#     'SJT211A',
#     'SJT114',
#     'SJT115',
#     'SJT118',
#     'SJT125',
#     'SJT127',
#     'SJT201',
#     'SJT202',
#     'SJT126',
#     'SJT203',
#     'SJT207',
#     'SJT207A'],
#    ['TT434A',
#     'TT415',
#     'TT413',
#     'TT414',
#     'TT423',
#     'TT424',
#     'TT302',
#     'TT301',
#     'TT303',
#     'TT530',
#     'TT206',
#     'TT631'],
#    ['SMV116', 'SMV214', 'SMV128', 'SMV109', 'SMV102', 'SMV101', 'SMVG11'],
#    ['MGB105'],
#    ['MB214', 'MB219', 'MB225', 'MB218', 'MB312'],
#    ['CBMR101'],
#    ['CDMM304'],
#    [],
#    [],
#    []]],
#  [[['SJT617',
#     'SJT514',
#     'SJT405',
#     'SJT423',
#     'SJT513',
#     'SJT522',
#     'SJT501',
#     'SJT601',
#     'SJT311A',
#     'SJT424',
#     'SJT521',
#     'SJT323',
#     'SJT404',
#     'SJT508',
#     'SJT322',
#     'SJT401',
#     'SJT409',
#     'SJT421',
#     'SJT402',
#     'SJT422',
#     'SJT109',
#     'SJT113',
#     'SJT114',
#     'SJT126',
#     'SJT127',
#     'SJT807',
#     'SJT201',
#     'SJT205',
#     'SJT207',
#     'SJT207A',
#     'SJT208',
#     'SJT211',
#     'SJT211A',
#     'SJT215',
#     'SJT221',
#     'SJT222',
#     'SJT224',
#     'SJT308',
#     'SJT315',
#     'SJT403',
#     'SJT505',
#     'SJT415',
#     'SJT324',
#     'SJT602',
#     'SJT311'],
#    ['TT112',
#     'TT423',
#     'TT414',
#     'TT630',
#     'TT631',
#     'TT413',
#     'TT424',
#     'TT415',
#     'TT434A',
#     'TT504',
#     'TT619',
#     'TT523',
#     'TT524',
#     'TT531A'],
#    ['SMV116',
#     'SMV220',
#     'SMV219',
#     'SMV111',
#     'SMV214',
#     'SMV109',
#     'SMV128',
#     'SMV218',
#     'SMVG11',
#     'SMV101',
#     'SMV102',
#     'SMVG10',
#     'SMV234',
#     'SMV217'],
#    ['MGB 303',
#     'MGB106',
#     'MGB201',
#     'MGB304',
#     'MGB110',
#     'MGB305',
#     'MGB202',
#     'MGB105',
#     'MGB108',
#     'MGB111',
#     'MGB208'],
#    ['MB218', 'MB219', 'MB214', 'MB225', 'MB226', 'MB227', 'MB305A', 'MB309'],
#    ['CBMR403', 'CBMR101', 'CBMR402', 'CBMR301'],
#    ['CDMM105', 'CDMM302', 'CDMM301', 'CDMM303'],
#    ['GDN128', 'GDN129'],
#    [],
#    []],
#   [['SJT109',
#     'SJT112',
#     'SJT113',
#     'SJT114',
#     'SJT522',
#     'SJT401',
#     'SJT311A',
#     'SJT402',
#     'SJT308',
#     'SJT508',
#     'SJT311',
#     'SJT315',
#     'SJT423',
#     'SJT405',
#     'SJT501',
#     'SJT513',
#     'SJT514',
#     'SJT504',
#     'SJT323',
#     'SJT403',
#     'SJT324',
#     'SJT404',
#     'SJT521',
#     'SJT424',
#     'SJT601',
#     'SJT415',
#     'SJT422',
#     'SJT409',
#     'SJT505',
#     'SJT127',
#     'SJT201',
#     'SJT205',
#     'SJT207',
#     'SJT207A',
#     'SJT208',
#     'SJT211',
#     'SJT211A',
#     'SJT126',
#     'SJT215',
#     'SJT221',
#     'SJT222',
#     'SJT224',
#     'SJT807',
#     'SJT322',
#     'SJT421'],
#    ['TT619',
#     'TT524',
#     'TT415',
#     'TT423',
#     'TT434A',
#     'TT424',
#     'TT434',
#     'TT304',
#     'TT531A',
#     'TT630',
#     'TT631',
#     'TT301',
#     'TT208',
#     'TT303',
#     'TT530A',
#     'TT523',
#     'TT504',
#     'TT413',
#     'TT414',
#     'TT206'],
#    ['SMV128',
#     'SMV220',
#     'SMV116',
#     'SMV217',
#     'SMV218',
#     'SMV102',
#     'SMV101',
#     'SMVG11',
#     'SMV219',
#     'SMVG10',
#     'SMV109',
#     'SMV111',
#     'SMV234',
#     'SMV209'],
#    ['MGB304', 'MGB303', 'MGB 303', 'MGB110', 'MGB209', 'MGB207', 'MGB208'],
#    ['MB214',
#     'MB219',
#     'MB218',
#     'MB227',
#     'MB311',
#     'MB224',
#     'MB225',
#     'MB226',
#     'MB309A',
#     'MB210',
#     'MB312'],
#    ['CBMR402', 'CBMR101', 'CBMR403', 'CBMR301'],
#    ['CDMM105', 'CDMM301', 'CDMM302'],
#    ['GDN128'],
#    [],
#    []],
#   [['SJT201',
#     'SJT202',
#     'SJT505',
#     'SJT508',
#     'SJT513',
#     'SJT204',
#     'SJT207',
#     'SJT203',
#     'SJT205',
#     'SJT207A',
#     'SJT401',
#     'SJT402',
#     'SJT403',
#     'SJT404',
#     'SJT405',
#     'SJT323',
#     'SJT409',
#     'SJT415',
#     'SJT421',
#     'SJT514',
#     'SJT422',
#     'SJT521',
#     'SJT423',
#     'SJT522',
#     'SJT424',
#     'SJT324',
#     'SJT311',
#     'SJT311A',
#     'SJT501',
#     'SJT601',
#     'SJT602',
#     'SJT322',
#     'SJT315',
#     'SJT113',
#     'SJT126',
#     'SJT127',
#     'SJT208',
#     'SJT211',
#     'SJT211A',
#     'SJT215',
#     'SJT221',
#     'SJT222',
#     'SJT112',
#     'SJT224',
#     'SJT308'],
#    ['TT531A',
#     'TT423',
#     'TT424',
#     'TT621',
#     'TT630',
#     'TT725',
#     'TT631',
#     'TT434A',
#     'TT504',
#     'TT523',
#     'TT524',
#     'TT619',
#     'TT434',
#     'TT331'],
#    ['SMV101',
#     'SMV102',
#     'SMV104',
#     'SMV219',
#     'SMV116',
#     'SMV128',
#     'SMV217',
#     'SMVG10',
#     'SMV214',
#     'SMV218',
#     'SMV234',
#     'SMV220',
#     'SMV111',
#     'SMV109'],
#    ['MGB303',
#     'MGB110',
#     'MGB304',
#     'MGB106',
#     'MGB202',
#     'MGB105',
#     'MGB201',
#     'MGB 303',
#     'MGB305',
#     'MGB111'],
#    ['MB110',
#     'MB111',
#     'MB124',
#     'MB211',
#     'MB212',
#     'MB213',
#     'MB312',
#     'MB219',
#     'MB218',
#     'MB214',
#     'MB226',
#     'MB227',
#     'MB305A',
#     'MB309',
#     'MB311',
#     'MB225',
#     'MB309A',
#     'MB224'],
#    ['CBMR301', 'CBMR402', 'CBMR403', 'CBMR101'],
#    ['CDMM105', 'CDMM301', 'CDMM302'],
#    [],
#    ['PLB522', 'PLB504', 'PLB509'],
#    []],
#   [['SJT302',
#     'SJT617',
#     'SJT508',
#     'SJT513',
#     'SJT514',
#     'SJT521',
#     'SJT522',
#     'SJT401',
#     'SJT402',
#     'SJT403',
#     'SJT404',
#     'SJT112',
#     'SJT113',
#     'SJT405',
#     'SJT409',
#     'SJT315',
#     'SJT415',
#     'SJT215',
#     'SJT224',
#     'SJT421',
#     'SJT323',
#     'SJT311A',
#     'SJT505',
#     'SJT601',
#     'SJT807',
#     'SJT501',
#     'SJT423',
#     'SJT308',
#     'SJT303',
#     'SJT422',
#     'SJT424',
#     'SJT322',
#     'SJT109',
#     'SJT114',
#     'SJT126',
#     'SJT201',
#     'SJT204',
#     'SJT205',
#     'SJT207A',
#     'SJT221',
#     'SJT207'],
#    ['TT630',
#     'TT301',
#     'TT206',
#     'TT504',
#     'TT619',
#     'TT424',
#     'TT423',
#     'TT434',
#     'TT302',
#     'TT207',
#     'TT303'],
#    ['SMV217',
#     'SMV109',
#     'SMV116',
#     'SMV128',
#     'SMV209',
#     'SMV320',
#     'SMV102',
#     'SMV101'],
#    ['MGB304', 'MGB106', 'MGB305', 'MGB 303', 'MGB303', 'MGB207', 'MGB201'],
#    ['MB214',
#     'MB218',
#     'MB219',
#     'MB224',
#     'MB309',
#     'MB311',
#     'MB227',
#     'MB305A',
#     'MB226',
#     'MB312'],
#    ['CBMR101', 'CBMR301', 'CBMR402'],
#    ['CDMM105', 'CDMM303', 'CDMM301', 'CDMM302', 'CDMM304'],
#    ['GDN129', 'GDN107', 'GDN128'],
#    ['PLB519', 'PLB523', 'PLB504', 'PLB509', 'PLB522', 'PLB619'],
#    []],
#   [['SJT415',
#     'SJT401',
#     'SJT807',
#     'SJT305',
#     'SJT403',
#     'SJT404',
#     'SJT421',
#     'SJT423',
#     'SJT508',
#     'SJT513',
#     'SJT409',
#     'SJT324',
#     'SJT224',
#     'SJT424',
#     'SJT504',
#     'SJT311A',
#     'SJT501',
#     'SJT505',
#     'SJT521',
#     'SJT405',
#     'SJT402',
#     'SJT503',
#     'SJT514',
#     'SJT322',
#     'SJT422',
#     'SJT208',
#     'SJT109',
#     'SJT113',
#     'SJT114',
#     'SJT115',
#     'SJT118',
#     'SJT124',
#     'SJT125',
#     'SJT127',
#     'SJT201',
#     'SJT112',
#     'SJT202',
#     'SJT203',
#     'SJT204',
#     'SJT205',
#     'SJT207',
#     'SJT207A',
#     'SJT211',
#     'SJT222',
#     'SJT315',
#     'SJT221',
#     'SJT211A',
#     'SJT126',
#     'SJT323',
#     'SJT303',
#     'SJT215',
#     'SJT311'],
#    ['TT424',
#     'TT434',
#     'TT434A',
#     'TT523',
#     'TT531A',
#     'TT630',
#     'TT631',
#     'TT415',
#     'TT423',
#     'TT414',
#     'TT504',
#     'TT619'],
#    ['SMV112',
#     'SMV116',
#     'SMV111',
#     'SMV218',
#     'SMV214',
#     'SMV217',
#     'SMV128',
#     'SMV101',
#     'SMV102',
#     'SMVG10',
#     'SMV109',
#     'SMVG11'],
#    ['MGB 303'],
#    ['MB305A',
#     'MB214',
#     'MB309',
#     'MB218',
#     'MB219',
#     'MB224',
#     'MB225',
#     'MB226',
#     'MB312',
#     'MB227',
#     'MB311',
#     'MB309A'],
#    ['CBMR101', 'CBMR301', 'CBMR402', 'CBMR403'],
#    ['CDMM105', 'CDMM302', 'CDMM303', 'CDMM301'],
#    [],
#    ['PLB504'],
#    []],
#   [['SJT109',
#     'SJT112',
#     'SJT113',
#     'SJT324',
#     'SJT305',
#     'SJT403',
#     'SJT311',
#     'SJT401',
#     'SJT423',
#     'SJT402',
#     'SJT323',
#     'SJT405',
#     'SJT424',
#     'SJT501',
#     'SJT502',
#     'SJT508',
#     'SJT311A',
#     'SJT404',
#     'SJT315',
#     'SJT503',
#     'SJT505',
#     'SJT215',
#     'SJT224',
#     'SJT221',
#     'SJT422',
#     'SJT514',
#     'SJT222',
#     'SJT415',
#     'SJT409',
#     'SJT308',
#     'SJT504',
#     'SJT322',
#     'SJT421',
#     'SJT513',
#     'SJT211A',
#     'SJT114',
#     'SJT115',
#     'SJT118',
#     'SJT124',
#     'SJT807',
#     'SJT125',
#     'SJT127',
#     'SJT201',
#     'SJT202',
#     'SJT126',
#     'SJT203',
#     'SJT204',
#     'SJT205',
#     'SJT211',
#     'SJT208',
#     'SJT207',
#     'SJT207A'],
#    ['TT523',
#     'TT112',
#     'TT434A',
#     'TT415',
#     'TT413',
#     'TT414',
#     'TT434',
#     'TT423',
#     'TT424',
#     'TT531A',
#     'TT630',
#     'TT207',
#     'TT208',
#     'TT301',
#     'TT303',
#     'TT530',
#     'TT206',
#     'TT631'],
#    ['SMV111',
#     'SMV116',
#     'SMV217',
#     'SMV214',
#     'SMV128',
#     'SMV109',
#     'SMV102',
#     'SMV101',
#     'SMVG11',
#     'SMVG10',
#     'SMV219',
#     'SMV218'],
#    ['MGB105'],
#    ['MB214',
#     'MB309',
#     'MB219',
#     'MB224',
#     'MB225',
#     'MB226',
#     'MB311',
#     'MB218',
#     'MB312'],
#    ['CBMR101'],
#    ['CDMM304', 'CDMM105'],
#    ['GDN107'],
#    [],
#    []],
#   [['SJT201',
#     'SJT202',
#     'SJT505',
#     'SJT508',
#     'SJT513',
#     'SJT204',
#     'SJT207',
#     'SJT203',
#     'SJT205',
#     'SJT207A',
#     'SJT401',
#     'SJT402',
#     'SJT403',
#     'SJT404',
#     'SJT405',
#     'SJT323',
#     'SJT409',
#     'SJT415',
#     'SJT421',
#     'SJT514',
#     'SJT521',
#     'SJT422',
#     'SJT522',
#     'SJT423',
#     'SJT424',
#     'SJT324',
#     'SJT501',
#     'SJT322',
#     'SJT223',
#     'SJT308',
#     'SJT315',
#     'SJT504',
#     'SJT311',
#     'SJT311A',
#     'SJT502',
#     'SJT503',
#     'SJT224',
#     'SJT601',
#     'SJT222',
#     'SJT109',
#     'SJT112',
#     'SJT114',
#     'SJT113',
#     'SJT115',
#     'SJT118',
#     'SJT124',
#     'SJT125',
#     'SJT126',
#     'SJT127',
#     'SJT208',
#     'SJT211',
#     'SJT211A',
#     'SJT215',
#     'SJT221'],
#    ['TT531A',
#     'TT423',
#     'TT424',
#     'TT621',
#     'TT630',
#     'TT725',
#     'TT631',
#     'TT434A',
#     'TT434',
#     'TT530',
#     'TT504',
#     'TT523',
#     'TT524',
#     'TT303',
#     'TT619'],
#    ['SMV101',
#     'SMV102',
#     'SMV104',
#     'SMV109',
#     'SMV112',
#     'SMV116',
#     'SMV218',
#     'SMV214',
#     'SMV128',
#     'SMV219',
#     'SMV220',
#     'SMVG10'],
#    [],
#    ['MB110',
#     'MB111',
#     'MB124',
#     'MB211',
#     'MB212',
#     'MB213',
#     'MB214',
#     'MB311',
#     'MB312',
#     'MB219',
#     'MB224',
#     'MB225',
#     'MB226',
#     'MB227',
#     'MB218',
#     'MB309'],
#    ['CBMR101', 'CBMR301', 'CBMR403', 'CBMR402'],
#    ['CDMM105', 'CDMM303'],
#    ['GDN107'],
#    ['PLB509'],
#    []],
#   [['SJT421',
#     'SJT505',
#     'SJT508',
#     'SJT513',
#     'SJT514',
#     'SJT521',
#     'SJT522',
#     'SJT401',
#     'SJT402',
#     'SJT404',
#     'SJT403',
#     'SJT112',
#     'SJT405',
#     'SJT617',
#     'SJT204',
#     'SJT224',
#     'SJT504',
#     'SJT423',
#     'SJT315',
#     'SJT422',
#     'SJT415',
#     'SJT202',
#     'SJT807',
#     'SJT203',
#     'SJT222',
#     'SJT308',
#     'SJT501',
#     'SJT303',
#     'SJT324',
#     'SJT322',
#     'SJT424',
#     'SJT113',
#     'SJT207',
#     'SJT221',
#     'SJT323',
#     'SJT109',
#     'SJT114',
#     'SJT115',
#     'SJT118',
#     'SJT126',
#     'SJT211A',
#     'SJT208',
#     'SJT201',
#     'SJT602'],
#    ['TT423',
#     'TT302',
#     'TT112',
#     'TT523',
#     'TT434',
#     'TT434A',
#     'TT424',
#     'TT206',
#     'TT301',
#     'TT531A',
#     'TT207',
#     'TT630',
#     'TT504'],
#    ['SMV116', 'SMV217', 'SMV220', 'SMV112', 'SMV218'],
#    [],
#    ['MB214',
#     'MB218',
#     'MB224',
#     'MB225',
#     'MB312',
#     'MB219',
#     'MB305A',
#     'MB309',
#     'MB311',
#     'MB226',
#     'MB227'],
#    ['CBMR101', 'CBMR301'],
#    ['CDMM301', 'CDMM105', 'CDMM303'],
#    [],
#    ['PLB519', 'PLB522', 'PLB523'],
#    []]],
#  [[['SJT617',
#     'SJT508',
#     'SJT513',
#     'SJT514',
#     'SJT521',
#     'SJT522',
#     'SJT401',
#     'SJT402',
#     'SJT403',
#     'SJT404',
#     'SJT112',
#     'SJT113',
#     'SJT405',
#     'SJT409',
#     'SJT315',
#     'SJT415',
#     'SJT421',
#     'SJT323',
#     'SJT311',
#     'SJT311A',
#     'SJT505',
#     'SJT601',
#     'SJT807',
#     'SJT324',
#     'SJT501',
#     'SJT423',
#     'SJT308',
#     'SJT422',
#     'SJT424',
#     'SJT322',
#     'SJT109',
#     'SJT114',
#     'SJT126',
#     'SJT201',
#     'SJT204',
#     'SJT205',
#     'SJT224',
#     'SJT207A',
#     'SJT208',
#     'SJT222',
#     'SJT211A',
#     'SJT215',
#     'SJT221',
#     'SJT207'],
#    ['TT206',
#     'TT504',
#     'TT619',
#     'TT424',
#     'TT423',
#     'TT434A',
#     'TT434',
#     'TT531A',
#     'TT630',
#     'TT301',
#     'TT302',
#     'TT621A',
#     'TT631',
#     'TT207',
#     'TT303',
#     'TT524',
#     'TT523'],
#    ['SMV217',
#     'SMV109',
#     'SMV116',
#     'SMV128',
#     'SMV209',
#     'SMV219',
#     'SMV220',
#     'SMV234',
#     'SMV218',
#     'SMV320',
#     'SMV102',
#     'SMV101',
#     'SMVG11',
#     'SMVG10'],
#    ['MGB304',
#     'MGB106',
#     'MGB305',
#     'MGB 303',
#     'MGB303',
#     'MGB202',
#     'MGB207',
#     'MGB201',
#     'MGB110'],
#    ['MB214',
#     'MB218',
#     'MB219',
#     'MB224',
#     'MB309',
#     'MB311',
#     'MB227',
#     'MB305A',
#     'MB225',
#     'MB226',
#     'MB312',
#     'MB309A'],
#    ['CBMR403', 'CBMR101', 'CBMR301', 'CBMR402'],
#    ['CDMM105', 'CDMM303', 'CDMM301', 'CDMM302', 'CDMM304'],
#    ['GDN129', 'GDN107', 'GDN128'],
#    ['PLB519', 'PLB523', 'PLB504', 'PLB509', 'PLB522', 'PLB619'],
#    []],
#   [['SJT415',
#     'SJT617',
#     'SJT508',
#     'SJT513',
#     'SJT521',
#     'SJT315',
#     'SJT112',
#     'SJT113',
#     'SJT401',
#     'SJT404',
#     'SJT405',
#     'SJT505',
#     'SJT324',
#     'SJT402',
#     'SJT403',
#     'SJT422',
#     'SJT423',
#     'SJT302',
#     'SJT322',
#     'SJT501',
#     'SJT601',
#     'SJT323',
#     'SJT421',
#     'SJT522',
#     'SJT303',
#     'SJT308',
#     'SJT311A',
#     'SJT305',
#     'SJT409',
#     'SJT424',
#     'SJT514',
#     'SJT602',
#     'SJT201',
#     'SJT205',
#     'SJT207',
#     'SJT207A',
#     'SJT208',
#     'SJT211',
#     'SJT211A',
#     'SJT215',
#     'SJT221',
#     'SJT222',
#     'SJT224',
#     'SJT807',
#     'SJT304',
#     'SJT127',
#     'SJT311'],
#    ['TT630',
#     'TT434A',
#     'TT424',
#     'TT423',
#     'TT434',
#     'TT335',
#     'TT531A',
#     'TT631',
#     'TT619',
#     'TT504',
#     'TT523',
#     'TT524'],
#    ['SMVG10',
#     'SMV116',
#     'SMV217',
#     'SMV218',
#     'SMV219',
#     'SMV128',
#     'SMV209',
#     'SMV234',
#     'SMV109',
#     'SMV101',
#     'SMV102',
#     'SMV220',
#     'SMV320'],
#    ['MGB105', 'MGB201', 'MGB110', 'MGB305', 'MGB 303', 'MGB304'],
#    ['MB214',
#     'MB218',
#     'MB224',
#     'MB225',
#     'MB226',
#     'MB305A',
#     'MB219',
#     'MB227',
#     'MB312',
#     'MB311',
#     'MB309A'],
#    ['CBMR101', 'CBMR402', 'CBMR403'],
#    ['CDMM105', 'CDMM302', 'CDMM303'],
#    ['GDN128', 'GDN129'],
#    ['PLB519', 'PLB509', 'PLB504', 'PLB522', 'PLB622'],
#    []],
#   [['SJT109',
#     'SJT204',
#     'SJT617',
#     'SJT311A',
#     'SJT404',
#     'SJT501',
#     'SJT521',
#     'SJT208',
#     'SJT211',
#     'SJT211A',
#     'SJT215',
#     'SJT221',
#     'SJT222',
#     'SJT224',
#     'SJT402',
#     'SJT308',
#     'SJT323',
#     'SJT403',
#     'SJT401',
#     'SJT409',
#     'SJT422',
#     'SJT423',
#     'SJT504',
#     'SJT505',
#     'SJT508',
#     'SJT513',
#     'SJT807',
#     'SJT522',
#     'SJT415',
#     'SJT421',
#     'SJT405',
#     'SJT424',
#     'SJT203',
#     'SJT207',
#     'SJT207A',
#     'SJT112',
#     'SJT113',
#     'SJT114',
#     'SJT126',
#     'SJT201',
#     'SJT205',
#     'SJT127',
#     'SJT322',
#     'SJT315',
#     'SJT324',
#     'SJT311'],
#    ['TT630',
#     'TT434',
#     'TT413',
#     'TT424',
#     'TT434A',
#     'TT414',
#     'TT415',
#     'TT423',
#     'TT301',
#     'TT302',
#     'TT303',
#     'TT531A',
#     'TT631',
#     'TT334',
#     'TT523',
#     'TT504',
#     'TT524',
#     'TT206'],
#    ['SMV109',
#     'SMV116',
#     'SMV111',
#     'SMV209',
#     'SMV217',
#     'SMV219',
#     'SMV220',
#     'SMV218',
#     'SMV234',
#     'SMV214',
#     'SMV128',
#     'SMV102',
#     'SMV101',
#     'SMVG11',
#     'SMVG10'],
#    ['MGB201', 'MGB106', 'MGB 303', 'MGB110', 'MGB202'],
#    ['MB214',
#     'MB218',
#     'MB225',
#     'MB226',
#     'MB224',
#     'MB305A',
#     'MB227',
#     'MB309A',
#     'MB309',
#     'MB311',
#     'MB219',
#     'MB312'],
#    ['CBMR101', 'CBMR301', 'CBMR402', 'CBMR403'],
#    ['CDMM301', 'CDMM303', 'CDMM302', 'CDMM105', 'CDMM304'],
#    ['GDN129', 'GDN128'],
#    ['PLB509', 'PLB622', 'PLB519'],
#    []],
#   [['SJT421',
#     'SJT505',
#     'SJT508',
#     'SJT513',
#     'SJT514',
#     'SJT521',
#     'SJT522',
#     'SJT401',
#     'SJT402',
#     'SJT404',
#     'SJT403',
#     'SJT112',
#     'SJT405',
#     'SJT617',
#     'SJT224',
#     'SJT504',
#     'SJT423',
#     'SJT315',
#     'SJT422',
#     'SJT415',
#     'SJT202',
#     'SJT807',
#     'SJT203',
#     'SJT222',
#     'SJT308',
#     'SJT409',
#     'SJT501',
#     'SJT311',
#     'SJT303',
#     'SJT324',
#     'SJT322',
#     'SJT424',
#     'SJT113',
#     'SJT207',
#     'SJT221',
#     'SJT323',
#     'SJT311A',
#     'SJT109',
#     'SJT114',
#     'SJT115',
#     'SJT204',
#     'SJT118',
#     'SJT124',
#     'SJT127',
#     'SJT207A',
#     'SJT205',
#     'SJT125',
#     'SJT126',
#     'SJT211A',
#     'SJT208',
#     'SJT201',
#     'SJT305',
#     'SJT211',
#     'SJT215'],
#    ['TT112',
#     'TT523',
#     'TT434',
#     'TT434A',
#     'TT424',
#     'TT208',
#     'TT301',
#     'TT302',
#     'TT531A',
#     'TT207',
#     'TT423',
#     'TT630',
#     'TT331',
#     'TT504'],
#    ['SMV217',
#     'SMV220',
#     'SMV112',
#     'SMV218',
#     'SMV219',
#     'SMV128',
#     'SMV109',
#     'SMV234'],
#    [],
#    ['MB214',
#     'MB218',
#     'MB224',
#     'MB225',
#     'MB312',
#     'MB219',
#     'MB305A',
#     'MB309',
#     'MB311',
#     'MB226',
#     'MB227'],
#    ['CBMR101', 'CBMR301'],
#    ['CDMM301', 'CDMM105', 'CDMM302', 'CDMM303'],
#    [],
#    ['PLB519', 'PLB522', 'PLB523'],
#    []],
#   [['SJT415',
#     'SJT505',
#     'SJT508',
#     'SJT513',
#     'SJT514',
#     'SJT521',
#     'SJT401',
#     'SJT402',
#     'SJT403',
#     'SJT404',
#     'SJT112',
#     'SJT113',
#     'SJT617',
#     'SJT303',
#     'SJT224',
#     'SJT315',
#     'SJT323',
#     'SJT305',
#     'SJT501',
#     'SJT522',
#     'SJT302',
#     'SJT311A',
#     'SJT421',
#     'SJT807',
#     'SJT504',
#     'SJT322',
#     'SJT405',
#     'SJT423',
#     'SJT409',
#     'SJT424',
#     'SJT503',
#     'SJT601',
#     'SJT222',
#     'SJT205',
#     'SJT211A',
#     'SJT109',
#     'SJT114',
#     'SJT115',
#     'SJT118',
#     'SJT124',
#     'SJT125',
#     'SJT207',
#     'SJT126',
#     'SJT127',
#     'SJT201',
#     'SJT202',
#     'SJT203',
#     'SJT204',
#     'SJT207A',
#     'SJT308',
#     'SJT304',
#     'SJT208',
#     'SJT211',
#     'SJT221',
#     'SJT215',
#     'SJT324',
#     'SJT422',
#     'SJT311'],
#    ['TT523',
#     'TT630',
#     'TT631',
#     'TT112',
#     'TT423',
#     'TT424',
#     'TT434A',
#     'TT434',
#     'TT504',
#     'TT531A',
#     'TT524',
#     'TT619',
#     'TT331'],
#    ['SMV116',
#     'SMV219',
#     'SMV218',
#     'SMV217',
#     'SMV209',
#     'SMV234',
#     'SMV220',
#     'SMV112',
#     'SMV101',
#     'SMV128',
#     'SMV102',
#     'SMV109',
#     'SMVG10'],
#    ['MGB109', 'MGB202', 'MGB110', 'MGB207', 'MGB106', 'MGB303'],
#    ['MB219', 'MB224', 'MB214', 'MB309', 'MB225', 'MB227'],
#    ['CBMR101', 'CBMR301', 'CBMR403', 'CBMR402'],
#    ['CDMM105', 'CDMM302', 'CDMM301'],
#    ['GDN107'],
#    ['PLB622', 'PLB509', 'PLB504', 'PLB519', 'PLB522'],
#    []],
#   [['SJT415',
#     'SJT522',
#     'SJT423',
#     'SJT223',
#     'SJT305',
#     'SJT401',
#     'SJT311A',
#     'SJT405',
#     'SJT501',
#     'SJT208',
#     'SJT211',
#     'SJT211A',
#     'SJT125',
#     'SJT126',
#     'SJT222',
#     'SJT308',
#     'SJT403',
#     'SJT402',
#     'SJT409',
#     'SJT323',
#     'SJT404',
#     'SJT201',
#     'SJT421',
#     'SJT221',
#     'SJT202',
#     'SJT504',
#     'SJT503',
#     'SJT505',
#     'SJT422',
#     'SJT508',
#     'SJT315',
#     'SJT322',
#     'SJT424',
#     'SJT324',
#     'SJT112',
#     'SJT113',
#     'SJT114',
#     'SJT109',
#     'SJT115',
#     'SJT118',
#     'SJT124',
#     'SJT207A'],
#    ['TT630',
#     'TT434',
#     'TT434A',
#     'TT414',
#     'TT415',
#     'TT424',
#     'TT301',
#     'TT302',
#     'TT303',
#     'TT621',
#     'TT504',
#     'TT207',
#     'TT208',
#     'TT331',
#     'TT631',
#     'TT413',
#     'TT423',
#     'TT524'],
#    ['SMV109',
#     'SMV217',
#     'SMV111',
#     'SMV219',
#     'SMV218',
#     'SMV128',
#     'SMV214',
#     'SMV116',
#     'SMV102',
#     'SMVG11'],
#    ['MGB105', 'MGB106'],
#    ['MB214',
#     'MB225',
#     'MB226',
#     'MB227',
#     'MB218',
#     'MB305A',
#     'MB309',
#     'MB312',
#     'MB311',
#     'MB309A',
#     'MB224',
#     'MB219'],
#    ['CBMR101'],
#    ['CDMM304', 'CDMM301', 'CDMM105', 'CDMM303'],
#    ['GDN107', 'GDN129', 'GDN128'],
#    ['PLB523'],
#    []],
#   [['SJT322',
#     'SJT315',
#     'SJT208',
#     'SJT215',
#     'SJT211A',
#     'SJT211',
#     'SJT221',
#     'SJT222',
#     'SJT401',
#     'SJT402',
#     'SJT403',
#     'SJT404',
#     'SJT405',
#     'SJT308',
#     'SJT311',
#     'SJT324',
#     'SJT311A',
#     'SJT323',
#     'SJT224',
#     'SJT127',
#     'SJT505',
#     'SJT514',
#     'SJT508',
#     'SJT521',
#     'SJT513',
#     'SJT522',
#     'SJT409',
#     'SJT415',
#     'SJT203',
#     'SJT423',
#     'SJT115',
#     'SJT125',
#     'SJT303',
#     'SJT202',
#     'SJT305',
#     'SJT421',
#     'SJT422',
#     'SJT503',
#     'SJT124',
#     'SJT112',
#     'SJT114',
#     'SJT617'],
#    ['TT207',
#     'TT208',
#     'TT630',
#     'TT631',
#     'TT531A',
#     'TT424',
#     'TT423',
#     'TT434',
#     'TT303',
#     'TT621',
#     'TT619',
#     'TT524',
#     'TT112',
#     'TT434A',
#     'TT206',
#     'TT301',
#     'TT302'],
#    ['SMV109',
#     'SMV116',
#     'SMV128',
#     'SMV112',
#     'SMV220',
#     'SMV219',
#     'SMV217',
#     'SMV102',
#     'SMV234'],
#    [],
#    ['MB214',
#     'MB218',
#     'MB219',
#     'MB224',
#     'MB225',
#     'MB226',
#     'MB227',
#     'MB305A',
#     'MB309',
#     'MB312',
#     'MB311',
#     'MB309A'],
#    ['CBMR101', 'CBMR301', 'CBMR402'],
#    ['CDMM105'],
#    ['GDN107', 'GDN129', 'GDN128'],
#    ['PLB519', 'PLB522'],
#    []]],
#  [[['SJT322',
#     'SJT315',
#     'SJT208',
#     'SJT211A',
#     'SJT211',
#     'SJT215',
#     'SJT221',
#     'SJT222',
#     'SJT401',
#     'SJT402',
#     'SJT403',
#     'SJT404',
#     'SJT405',
#     'SJT308',
#     'SJT324',
#     'SJT311',
#     'SJT311A',
#     'SJT323',
#     'SJT224',
#     'SJT127',
#     'SJT505',
#     'SJT514',
#     'SJT508',
#     'SJT521',
#     'SJT513',
#     'SJT522',
#     'SJT409',
#     'SJT415',
#     'SJT421',
#     'SJT423',
#     'SJT601',
#     'SJT202',
#     'SJT207A',
#     'SJT422',
#     'SJT807',
#     'SJT501',
#     'SJT424',
#     'SJT207',
#     'SJT109',
#     'SJT112',
#     'SJT114',
#     'SJT126',
#     'SJT201',
#     'SJT205',
#     'SJT118'],
#    ['TT207',
#     'TT208',
#     'TT630',
#     'TT631',
#     'TT531A',
#     'TT424',
#     'TT423',
#     'TT434',
#     'TT303',
#     'TT413',
#     'TT415',
#     'TT414',
#     'TT504',
#     'TT434A',
#     'TT301',
#     'TT302',
#     'TT524',
#     'TT206'],
#    ['SMV109',
#     'SMV116',
#     'SMV128',
#     'SMV217',
#     'SMV220',
#     'SMV234',
#     'SMV209',
#     'SMV218',
#     'SMV219',
#     'SMV101',
#     'SMV102',
#     'SMV313',
#     'SMVG10'],
#    ['MGB304',
#     'MGB305',
#     'MGB105',
#     'MGB202',
#     'MGB106',
#     'MGB201',
#     'MGB207',
#     'MGB 303'],
#    ['MB214',
#     'MB218',
#     'MB219',
#     'MB224',
#     'MB225',
#     'MB226',
#     'MB227',
#     'MB305A',
#     'MB312',
#     'MB309A',
#     'MB309',
#     'MB311'],
#    ['CBMR101', 'CBMR301', 'CBMR402', 'CBMR403'],
#    ['CDMM105', 'CDMM301'],
#    ['GDN129', 'GDN128'],
#    ['PLB522', 'PLB523', 'PLB509'],
#    []],
#   [['SJT617',
#     'SJT514',
#     'SJT405',
#     'SJT423',
#     'SJT513',
#     'SJT522',
#     'SJT501',
#     'SJT601',
#     'SJT311A',
#     'SJT424',
#     'SJT521',
#     'SJT323',
#     'SJT404',
#     'SJT508',
#     'SJT322',
#     'SJT401',
#     'SJT409',
#     'SJT421',
#     'SJT402',
#     'SJT422',
#     'SJT109',
#     'SJT113',
#     'SJT114',
#     'SJT126',
#     'SJT127',
#     'SJT807',
#     'SJT201',
#     'SJT205',
#     'SJT207',
#     'SJT207A',
#     'SJT208',
#     'SJT211',
#     'SJT211A',
#     'SJT215',
#     'SJT221',
#     'SJT222',
#     'SJT224',
#     'SJT308',
#     'SJT315',
#     'SJT403',
#     'SJT505',
#     'SJT415',
#     'SJT324',
#     'SJT602',
#     'SJT311'],
#    ['TT112',
#     'TT423',
#     'TT414',
#     'TT630',
#     'TT631',
#     'TT413',
#     'TT424',
#     'TT415',
#     'TT434A',
#     'TT504',
#     'TT619',
#     'TT523',
#     'TT524',
#     'TT531A'],
#    ['SMV116',
#     'SMV220',
#     'SMV219',
#     'SMV111',
#     'SMV214',
#     'SMV109',
#     'SMV128',
#     'SMV218',
#     'SMVG11',
#     'SMV101',
#     'SMV102',
#     'SMVG10',
#     'SMV234',
#     'SMV217'],
#    ['MGB 303',
#     'MGB106',
#     'MGB201',
#     'MGB304',
#     'MGB110',
#     'MGB305',
#     'MGB202',
#     'MGB105',
#     'MGB108',
#     'MGB111',
#     'MGB208'],
#    ['MB218', 'MB219', 'MB214', 'MB225', 'MB226', 'MB227', 'MB305A', 'MB309'],
#    ['CBMR403', 'CBMR101', 'CBMR402', 'CBMR301'],
#    ['CDMM105', 'CDMM302', 'CDMM301', 'CDMM303'],
#    ['GDN128', 'GDN129'],
#    [],
#    []],
#   [['SJT109',
#     'SJT112',
#     'SJT113',
#     'SJT114',
#     'SJT522',
#     'SJT401',
#     'SJT311A',
#     'SJT402',
#     'SJT308',
#     'SJT508',
#     'SJT311',
#     'SJT315',
#     'SJT423',
#     'SJT405',
#     'SJT501',
#     'SJT513',
#     'SJT514',
#     'SJT504',
#     'SJT323',
#     'SJT403',
#     'SJT324',
#     'SJT404',
#     'SJT521',
#     'SJT424',
#     'SJT601',
#     'SJT415',
#     'SJT422',
#     'SJT409',
#     'SJT505',
#     'SJT127',
#     'SJT201',
#     'SJT205',
#     'SJT207',
#     'SJT207A',
#     'SJT208',
#     'SJT211',
#     'SJT211A',
#     'SJT126',
#     'SJT215',
#     'SJT221',
#     'SJT222',
#     'SJT224',
#     'SJT807',
#     'SJT322',
#     'SJT421'],
#    ['TT619',
#     'TT524',
#     'TT415',
#     'TT423',
#     'TT434A',
#     'TT424',
#     'TT434',
#     'TT304',
#     'TT531A',
#     'TT630',
#     'TT631',
#     'TT301',
#     'TT208',
#     'TT303',
#     'TT530A',
#     'TT523',
#     'TT504',
#     'TT413',
#     'TT414',
#     'TT206'],
#    ['SMV128',
#     'SMV220',
#     'SMV116',
#     'SMV217',
#     'SMV218',
#     'SMV102',
#     'SMV101',
#     'SMVG11',
#     'SMV219',
#     'SMVG10',
#     'SMV109',
#     'SMV111',
#     'SMV234',
#     'SMV209'],
#    ['MGB304', 'MGB303', 'MGB 303', 'MGB110', 'MGB209', 'MGB207', 'MGB208'],
#    ['MB214',
#     'MB219',
#     'MB218',
#     'MB227',
#     'MB311',
#     'MB224',
#     'MB225',
#     'MB226',
#     'MB309A',
#     'MB210',
#     'MB312'],
#    ['CBMR402', 'CBMR101', 'CBMR403', 'CBMR301'],
#    ['CDMM105', 'CDMM301', 'CDMM302'],
#    ['GDN128'],
#    [],
#    []],
#   [['SJT201',
#     'SJT202',
#     'SJT505',
#     'SJT508',
#     'SJT513',
#     'SJT204',
#     'SJT207',
#     'SJT203',
#     'SJT205',
#     'SJT207A',
#     'SJT401',
#     'SJT402',
#     'SJT403',
#     'SJT404',
#     'SJT405',
#     'SJT323',
#     'SJT409',
#     'SJT415',
#     'SJT421',
#     'SJT514',
#     'SJT422',
#     'SJT521',
#     'SJT423',
#     'SJT522',
#     'SJT424',
#     'SJT324',
#     'SJT302',
#     'SJT304',
#     'SJT602',
#     'SJT322',
#     'SJT315',
#     'SJT113',
#     'SJT222',
#     'SJT126',
#     'SJT127',
#     'SJT208',
#     'SJT211',
#     'SJT224',
#     'SJT211A',
#     'SJT215',
#     'SJT308'],
#    ['TT331',
#     'TT531A',
#     'TT423',
#     'TT424',
#     'TT621',
#     'TT630',
#     'TT725',
#     'TT631',
#     'TT304',
#     'TT434',
#     'TT434A',
#     'TT504',
#     'TT523',
#     'TT524',
#     'TT619'],
#    ['SMV126',
#     'SMV130',
#     'SMV214',
#     'SMV218',
#     'SMV220',
#     'SMV235',
#     'SMV320',
#     'SMV101',
#     'SMV102',
#     'SMV104',
#     'SMV219',
#     'SMV116',
#     'SMV128',
#     'SMV217',
#     'SMVG10',
#     'SMV234',
#     'SMV111',
#     'SMV109'],
#    ['MGB304', 'MGB106', 'MGB202', 'MGB 303', 'MGB305'],
#    ['MB218',
#     'MB219',
#     'MB225',
#     'MB227',
#     'MB305A',
#     'MB110',
#     'MB111',
#     'MB124',
#     'MB211',
#     'MB212',
#     'MB213',
#     'MB312',
#     'MB214',
#     'MB226',
#     'MB309',
#     'MB311',
#     'MB309A',
#     'MB224'],
#    ['CBMR301', 'CBMR402', 'CBMR403', 'CBMR101'],
#    ['CDMM105', 'CDMM301', 'CDMM302'],
#    [],
#    ['PLB522', 'PLB504'],
#    []],
#   [['SJT322',
#     'SJT315',
#     'SJT208',
#     'SJT215',
#     'SJT211A',
#     'SJT211',
#     'SJT221',
#     'SJT222',
#     'SJT401',
#     'SJT402',
#     'SJT403',
#     'SJT404',
#     'SJT405',
#     'SJT308',
#     'SJT311',
#     'SJT324',
#     'SJT311A',
#     'SJT323',
#     'SJT224',
#     'SJT127',
#     'SJT505',
#     'SJT514',
#     'SJT508',
#     'SJT521',
#     'SJT513',
#     'SJT522',
#     'SJT409',
#     'SJT415',
#     'SJT807',
#     'SJT423',
#     'SJT504',
#     'SJT115',
#     'SJT125',
#     'SJT303',
#     'SJT202',
#     'SJT203',
#     'SJT501',
#     'SJT305',
#     'SJT421',
#     'SJT422',
#     'SJT503',
#     'SJT124',
#     'SJT118',
#     'SJT109',
#     'SJT112',
#     'SJT113',
#     'SJT114',
#     'SJT617'],
#    ['TT207',
#     'TT208',
#     'TT630',
#     'TT631',
#     'TT531A',
#     'TT424',
#     'TT423',
#     'TT434',
#     'TT303',
#     'TT414',
#     'TT112',
#     'TT413',
#     'TT434A',
#     'TT206',
#     'TT301',
#     'TT302',
#     'TT415'],
#    ['SMV109',
#     'SMV116',
#     'SMV128',
#     'SMV112',
#     'SMV220',
#     'SMV219',
#     'SMV218',
#     'SMV217',
#     'SMV102',
#     'SMV101',
#     'SMV234'],
#    [],
#    ['MB214',
#     'MB218',
#     'MB219',
#     'MB224',
#     'MB225',
#     'MB226',
#     'MB227',
#     'MB305A',
#     'MB309',
#     'MB312',
#     'MB311',
#     'MB309A'],
#    ['CBMR101', 'CBMR301', 'CBMR403', 'CBMR402'],
#    ['CDMM105', 'CDMM301', 'CDMM303', 'CDMM302'],
#    ['GDN107', 'GDN129', 'GDN128'],
#    ['PLB519', 'PLB522'],
#    []],
#   [['SJT415',
#     'SJT401',
#     'SJT807',
#     'SJT305',
#     'SJT403',
#     'SJT404',
#     'SJT421',
#     'SJT423',
#     'SJT508',
#     'SJT513',
#     'SJT409',
#     'SJT324',
#     'SJT224',
#     'SJT424',
#     'SJT504',
#     'SJT311A',
#     'SJT501',
#     'SJT505',
#     'SJT521',
#     'SJT405',
#     'SJT402',
#     'SJT503',
#     'SJT514',
#     'SJT322',
#     'SJT422',
#     'SJT208',
#     'SJT109',
#     'SJT113',
#     'SJT114',
#     'SJT115',
#     'SJT118',
#     'SJT124',
#     'SJT125',
#     'SJT127',
#     'SJT201',
#     'SJT112',
#     'SJT202',
#     'SJT203',
#     'SJT204',
#     'SJT205',
#     'SJT207',
#     'SJT207A',
#     'SJT211',
#     'SJT222',
#     'SJT315',
#     'SJT221',
#     'SJT211A',
#     'SJT126',
#     'SJT323',
#     'SJT303',
#     'SJT215',
#     'SJT311'],
#    ['TT424',
#     'TT434',
#     'TT434A',
#     'TT523',
#     'TT531A',
#     'TT630',
#     'TT631',
#     'TT415',
#     'TT423',
#     'TT414',
#     'TT504',
#     'TT619'],
#    ['SMV112',
#     'SMV116',
#     'SMV111',
#     'SMV218',
#     'SMV214',
#     'SMV217',
#     'SMV128',
#     'SMV101',
#     'SMV102',
#     'SMVG10',
#     'SMV109',
#     'SMVG11'],
#    ['MGB 303'],
#    ['MB305A',
#     'MB214',
#     'MB309',
#     'MB218',
#     'MB219',
#     'MB224',
#     'MB225',
#     'MB226',
#     'MB312',
#     'MB227',
#     'MB311',
#     'MB309A'],
#    ['CBMR101', 'CBMR301', 'CBMR402', 'CBMR403'],
#    ['CDMM105', 'CDMM302', 'CDMM303', 'CDMM301'],
#    [],
#    ['PLB504'],
#    []],
#   [['SJT109',
#     'SJT112',
#     'SJT113',
#     'SJT324',
#     'SJT305',
#     'SJT403',
#     'SJT311',
#     'SJT401',
#     'SJT423',
#     'SJT402',
#     'SJT323',
#     'SJT405',
#     'SJT424',
#     'SJT501',
#     'SJT502',
#     'SJT508',
#     'SJT311A',
#     'SJT404',
#     'SJT315',
#     'SJT503',
#     'SJT505',
#     'SJT215',
#     'SJT224',
#     'SJT221',
#     'SJT422',
#     'SJT514',
#     'SJT222',
#     'SJT415',
#     'SJT409',
#     'SJT308',
#     'SJT504',
#     'SJT322',
#     'SJT421',
#     'SJT513',
#     'SJT211A',
#     'SJT114',
#     'SJT115',
#     'SJT118',
#     'SJT124',
#     'SJT807',
#     'SJT125',
#     'SJT127',
#     'SJT201',
#     'SJT202',
#     'SJT126',
#     'SJT203',
#     'SJT204',
#     'SJT205',
#     'SJT211',
#     'SJT208',
#     'SJT207',
#     'SJT207A'],
#    ['TT523',
#     'TT112',
#     'TT434A',
#     'TT415',
#     'TT413',
#     'TT414',
#     'TT434',
#     'TT423',
#     'TT424',
#     'TT531A',
#     'TT630',
#     'TT207',
#     'TT208',
#     'TT301',
#     'TT303',
#     'TT530',
#     'TT206',
#     'TT631'],
#    ['SMV111',
#     'SMV116',
#     'SMV217',
#     'SMV214',
#     'SMV128',
#     'SMV109',
#     'SMV102',
#     'SMV101',
#     'SMVG11',
#     'SMVG10',
#     'SMV219',
#     'SMV218'],
#    ['MGB105'],
#    ['MB214',
#     'MB309',
#     'MB219',
#     'MB224',
#     'MB225',
#     'MB226',
#     'MB311',
#     'MB218',
#     'MB312'],
#    ['CBMR101'],
#    ['CDMM304', 'CDMM105'],
#    ['GDN107'],
#    [],
#    []],
#   [['SJT201',
#     'SJT202',
#     'SJT505',
#     'SJT508',
#     'SJT513',
#     'SJT204',
#     'SJT207',
#     'SJT203',
#     'SJT205',
#     'SJT207A',
#     'SJT401',
#     'SJT402',
#     'SJT403',
#     'SJT404',
#     'SJT405',
#     'SJT323',
#     'SJT409',
#     'SJT415',
#     'SJT421',
#     'SJT514',
#     'SJT521',
#     'SJT422',
#     'SJT522',
#     'SJT423',
#     'SJT424',
#     'SJT324',
#     'SJT303',
#     'SJT322',
#     'SJT315',
#     'SJT601',
#     'SJT222',
#     'SJT112',
#     'SJT114',
#     'SJT126',
#     'SJT113',
#     'SJT115',
#     'SJT118',
#     'SJT124',
#     'SJT211',
#     'SJT211A',
#     'SJT215',
#     'SJT109',
#     'SJT125',
#     'SJT221'],
#    ['TT531A',
#     'TT423',
#     'TT424',
#     'TT621',
#     'TT630',
#     'TT725',
#     'TT631',
#     'TT304',
#     'TT434A',
#     'TT530',
#     'TT504',
#     'TT523',
#     'TT524',
#     'TT303',
#     'TT619'],
#    ['SMV112',
#     'SMV128',
#     'SMV217',
#     'SMV234',
#     'SMV235',
#     'SMV126',
#     'SMV101',
#     'SMV102',
#     'SMV104',
#     'SMV109',
#     'SMV116',
#     'SMV218',
#     'SMV219',
#     'SMV220',
#     'SMVG10'],
#    [],
#    ['MB218',
#     'MB224',
#     'MB225',
#     'MB227',
#     'MB305A',
#     'MB110',
#     'MB111',
#     'MB124',
#     'MB211',
#     'MB212',
#     'MB213',
#     'MB214',
#     'MB311',
#     'MB219',
#     'MB226',
#     'MB309'],
#    ['CBMR101', 'CBMR301', 'CBMR403', 'CBMR402'],
#    ['CDMM105', 'CDMM303'],
#    ['GDN107'],
#    ['PLB509'],
#    []]],
#  [[['SJT201',
#     'SJT202',
#     'SJT505',
#     'SJT508',
#     'SJT513',
#     'SJT204',
#     'SJT207',
#     'SJT203',
#     'SJT205',
#     'SJT207A',
#     'SJT401',
#     'SJT402',
#     'SJT403',
#     'SJT404',
#     'SJT405',
#     'SJT323',
#     'SJT409',
#     'SJT415',
#     'SJT421',
#     'SJT514',
#     'SJT422',
#     'SJT521',
#     'SJT423',
#     'SJT522',
#     'SJT424',
#     'SJT324',
#     'SJT311',
#     'SJT311A',
#     'SJT501',
#     'SJT601',
#     'SJT602',
#     'SJT322',
#     'SJT315',
#     'SJT113',
#     'SJT126',
#     'SJT127',
#     'SJT208',
#     'SJT211',
#     'SJT211A',
#     'SJT215',
#     'SJT221',
#     'SJT222',
#     'SJT112',
#     'SJT224',
#     'SJT308'],
#    ['TT531A',
#     'TT423',
#     'TT424',
#     'TT621',
#     'TT630',
#     'TT725',
#     'TT631',
#     'TT434A',
#     'TT504',
#     'TT523',
#     'TT524',
#     'TT619',
#     'TT434',
#     'TT331'],
#    ['SMV101',
#     'SMV102',
#     'SMV104',
#     'SMV219',
#     'SMV116',
#     'SMV128',
#     'SMV217',
#     'SMVG10',
#     'SMV214',
#     'SMV218',
#     'SMV234',
#     'SMV220',
#     'SMV111',
#     'SMV109'],
#    ['MGB303',
#     'MGB110',
#     'MGB304',
#     'MGB106',
#     'MGB202',
#     'MGB105',
#     'MGB201',
#     'MGB 303',
#     'MGB305',
#     'MGB111'],
#    ['MB110',
#     'MB111',
#     'MB124',
#     'MB211',
#     'MB212',
#     'MB213',
#     'MB312',
#     'MB219',
#     'MB218',
#     'MB214',
#     'MB226',
#     'MB227',
#     'MB305A',
#     'MB309',
#     'MB311',
#     'MB225',
#     'MB309A',
#     'MB224'],
#    ['CBMR301', 'CBMR402', 'CBMR403', 'CBMR101'],
#    ['CDMM105', 'CDMM301', 'CDMM302'],
#    [],
#    ['PLB522', 'PLB504', 'PLB509'],
#    []],
#   [['SJT617',
#     'SJT508',
#     'SJT513',
#     'SJT514',
#     'SJT521',
#     'SJT522',
#     'SJT401',
#     'SJT402',
#     'SJT403',
#     'SJT404',
#     'SJT112',
#     'SJT113',
#     'SJT405',
#     'SJT409',
#     'SJT315',
#     'SJT415',
#     'SJT421',
#     'SJT323',
#     'SJT311',
#     'SJT311A',
#     'SJT505',
#     'SJT601',
#     'SJT807',
#     'SJT324',
#     'SJT501',
#     'SJT423',
#     'SJT308',
#     'SJT422',
#     'SJT424',
#     'SJT322',
#     'SJT109',
#     'SJT114',
#     'SJT126',
#     'SJT201',
#     'SJT204',
#     'SJT205',
#     'SJT224',
#     'SJT207A',
#     'SJT208',
#     'SJT222',
#     'SJT211A',
#     'SJT215',
#     'SJT221',
#     'SJT207'],
#    ['TT206',
#     'TT504',
#     'TT619',
#     'TT424',
#     'TT423',
#     'TT434A',
#     'TT434',
#     'TT531A',
#     'TT630',
#     'TT301',
#     'TT302',
#     'TT621A',
#     'TT631',
#     'TT207',
#     'TT303',
#     'TT524',
#     'TT523'],
#    ['SMV217',
#     'SMV109',
#     'SMV116',
#     'SMV128',
#     'SMV209',
#     'SMV219',
#     'SMV220',
#     'SMV234',
#     'SMV218',
#     'SMV320',
#     'SMV102',
#     'SMV101',
#     'SMVG11',
#     'SMVG10'],
#    ['MGB304',
#     'MGB106',
#     'MGB305',
#     'MGB 303',
#     'MGB303',
#     'MGB202',
#     'MGB207',
#     'MGB201',
#     'MGB110'],
#    ['MB214',
#     'MB218',
#     'MB219',
#     'MB224',
#     'MB309',
#     'MB311',
#     'MB227',
#     'MB305A',
#     'MB225',
#     'MB226',
#     'MB312',
#     'MB309A'],
#    ['CBMR403', 'CBMR101', 'CBMR301', 'CBMR402'],
#    ['CDMM105', 'CDMM303', 'CDMM301', 'CDMM302', 'CDMM304'],
#    ['GDN129', 'GDN107', 'GDN128'],
#    ['PLB519', 'PLB523', 'PLB504', 'PLB509', 'PLB522', 'PLB619'],
#    []],
#   [['SJT415',
#     'SJT617',
#     'SJT508',
#     'SJT513',
#     'SJT521',
#     'SJT315',
#     'SJT112',
#     'SJT113',
#     'SJT401',
#     'SJT404',
#     'SJT405',
#     'SJT323',
#     'SJT505',
#     'SJT402',
#     'SJT423',
#     'SJT302',
#     'SJT322',
#     'SJT501',
#     'SJT601',
#     'SJT421',
#     'SJT303',
#     'SJT308',
#     'SJT311A',
#     'SJT305',
#     'SJT409',
#     'SJT424',
#     'SJT514',
#     'SJT602',
#     'SJT201',
#     'SJT205',
#     'SJT207',
#     'SJT207A',
#     'SJT208',
#     'SJT211',
#     'SJT211A',
#     'SJT221',
#     'SJT222',
#     'SJT807'],
#    ['TT630', 'TT434A', 'TT530A', 'TT531A', 'TT631', 'TT619', 'TT504', 'TT523'],
#    ['SMVG10',
#     'SMV116',
#     'SMV217',
#     'SMV219',
#     'SMV128',
#     'SMV209',
#     'SMV234',
#     'SMV109',
#     'SMV101',
#     'SMV220'],
#    ['MGB105', 'MGB201', 'MGB110', 'MGB305', 'MGB 303', 'MGB304'],
#    ['MB214',
#     'MB218',
#     'MB224',
#     'MB225',
#     'MB226',
#     'MB309',
#     'MB305A',
#     'MB219',
#     'MB227',
#     'MB312',
#     'MB309A'],
#    ['CBMR101', 'CBMR402', 'CBMR403'],
#    ['CDMM301', 'CDMM105', 'CDMM303'],
#    ['GDN128', 'GDN129'],
#    ['PLB519', 'PLB509', 'PLB504', 'PLB522', 'PLB622'],
#    []],
#   [['SJT109',
#     'SJT405',
#     'SJT424',
#     'SJT207',
#     'SJT207A',
#     'SJT112',
#     'SJT126',
#     'SJT201',
#     'SJT205',
#     'SJT127',
#     'SJT807',
#     'SJT315'],
#    ['TT630',
#     'TT434',
#     'TT621',
#     'TT619',
#     'TT413',
#     'TT424',
#     'TT434A',
#     'TT423',
#     'TT414',
#     'TT301',
#     'TT302',
#     'TT303',
#     'TT531A',
#     'TT631',
#     'TT504',
#     'TT524',
#     'TT206'],
#    ['SMV109',
#     'SMV111',
#     'SMV209',
#     'SMV217',
#     'SMV219',
#     'SMV220',
#     'SMV218',
#     'SMV234',
#     'SMV101',
#     'SMV102',
#     'SMVG11',
#     'SMV112',
#     'SMV116'],
#    ['MGB110'],
#    ['MB214',
#     'MB218',
#     'MB225',
#     'MB226',
#     'MB305A',
#     'MB224',
#     'MB311',
#     'MB309A',
#     'MB227',
#     'MB219'],
#    [],
#    ['CDMM303', 'CDMM105'],
#    [],
#    ['PLB509', 'PLB519'],
#    []],
#   [['SJT322',
#     'SJT315',
#     'SJT208',
#     'SJT211A',
#     'SJT211',
#     'SJT215',
#     'SJT221',
#     'SJT222',
#     'SJT401',
#     'SJT402',
#     'SJT403',
#     'SJT404',
#     'SJT405',
#     'SJT308',
#     'SJT324',
#     'SJT311',
#     'SJT311A',
#     'SJT323',
#     'SJT224',
#     'SJT127',
#     'SJT505',
#     'SJT514',
#     'SJT508',
#     'SJT521',
#     'SJT513',
#     'SJT522',
#     'SJT409',
#     'SJT415',
#     'SJT421',
#     'SJT202',
#     'SJT423',
#     'SJT207A',
#     'SJT807',
#     'SJT501',
#     'SJT424',
#     'SJT207',
#     'SJT109',
#     'SJT112',
#     'SJT114',
#     'SJT126',
#     'SJT201',
#     'SJT205',
#     'SJT118'],
#    ['TT207',
#     'TT208',
#     'TT630',
#     'TT631',
#     'TT531A',
#     'TT424',
#     'TT423',
#     'TT434',
#     'TT303',
#     'TT504',
#     'TT434A',
#     'TT206',
#     'TT301',
#     'TT302'],
#    ['SMV109',
#     'SMV116',
#     'SMV128',
#     'SMV217',
#     'SMV220',
#     'SMV234',
#     'SMV218',
#     'SMV219',
#     'SMV102',
#     'SMVG10'],
#    ['MGB304', 'MGB305', 'MGB106', 'MGB201', 'MGB207'],
#    ['MB214',
#     'MB218',
#     'MB219',
#     'MB224',
#     'MB225',
#     'MB226',
#     'MB227',
#     'MB312',
#     'MB309'],
#    ['CBMR101', 'CBMR301', 'CBMR402', 'CBMR403'],
#    ['CDMM105'],
#    ['GDN129', 'GDN128'],
#    ['PLB522', 'PLB509'],
#    []],
#   [['SJT201',
#     'SJT202',
#     'SJT505',
#     'SJT508',
#     'SJT513',
#     'SJT204',
#     'SJT207',
#     'SJT203',
#     'SJT205',
#     'SJT207A',
#     'SJT401',
#     'SJT402',
#     'SJT403',
#     'SJT404',
#     'SJT405',
#     'SJT323',
#     'SJT409',
#     'SJT415',
#     'SJT421',
#     'SJT514',
#     'SJT521',
#     'SJT422',
#     'SJT522',
#     'SJT423',
#     'SJT424',
#     'SJT324',
#     'SJT501',
#     'SJT322',
#     'SJT223',
#     'SJT308',
#     'SJT315',
#     'SJT504',
#     'SJT311',
#     'SJT311A',
#     'SJT502',
#     'SJT503',
#     'SJT224',
#     'SJT601',
#     'SJT222',
#     'SJT109',
#     'SJT112',
#     'SJT114',
#     'SJT113',
#     'SJT115',
#     'SJT118',
#     'SJT124',
#     'SJT125',
#     'SJT126',
#     'SJT127',
#     'SJT208',
#     'SJT211',
#     'SJT211A',
#     'SJT215',
#     'SJT221'],
#    ['TT531A',
#     'TT423',
#     'TT424',
#     'TT621',
#     'TT630',
#     'TT725',
#     'TT631',
#     'TT434A',
#     'TT434',
#     'TT530',
#     'TT504',
#     'TT523',
#     'TT524',
#     'TT303',
#     'TT619'],
#    ['SMV101',
#     'SMV102',
#     'SMV104',
#     'SMV109',
#     'SMV112',
#     'SMV116',
#     'SMV218',
#     'SMV214',
#     'SMV128',
#     'SMV219',
#     'SMV220',
#     'SMVG10'],
#    [],
#    ['MB110',
#     'MB111',
#     'MB124',
#     'MB211',
#     'MB212',
#     'MB213',
#     'MB214',
#     'MB311',
#     'MB312',
#     'MB219',
#     'MB224',
#     'MB225',
#     'MB226',
#     'MB227',
#     'MB218',
#     'MB309'],
#    ['CBMR101', 'CBMR301', 'CBMR403', 'CBMR402'],
#    ['CDMM105', 'CDMM303'],
#    ['GDN107'],
#    ['PLB509'],
#    []],
#   [['SJT421',
#     'SJT505',
#     'SJT508',
#     'SJT513',
#     'SJT514',
#     'SJT521',
#     'SJT522',
#     'SJT401',
#     'SJT402',
#     'SJT404',
#     'SJT403',
#     'SJT112',
#     'SJT405',
#     'SJT617',
#     'SJT224',
#     'SJT504',
#     'SJT423',
#     'SJT315',
#     'SJT422',
#     'SJT415',
#     'SJT202',
#     'SJT807',
#     'SJT203',
#     'SJT222',
#     'SJT308',
#     'SJT409',
#     'SJT501',
#     'SJT311',
#     'SJT303',
#     'SJT324',
#     'SJT322',
#     'SJT424',
#     'SJT113',
#     'SJT207',
#     'SJT221',
#     'SJT323',
#     'SJT311A',
#     'SJT109',
#     'SJT114',
#     'SJT115',
#     'SJT204',
#     'SJT118',
#     'SJT124',
#     'SJT127',
#     'SJT207A',
#     'SJT205',
#     'SJT125',
#     'SJT126',
#     'SJT211A',
#     'SJT208',
#     'SJT201',
#     'SJT305',
#     'SJT211',
#     'SJT215'],
#    ['TT112',
#     'TT523',
#     'TT434',
#     'TT434A',
#     'TT424',
#     'TT208',
#     'TT301',
#     'TT302',
#     'TT531A',
#     'TT207',
#     'TT423',
#     'TT630',
#     'TT331',
#     'TT504'],
#    ['SMV217',
#     'SMV220',
#     'SMV112',
#     'SMV218',
#     'SMV219',
#     'SMV128',
#     'SMV109',
#     'SMV234'],
#    [],
#    ['MB214',
#     'MB218',
#     'MB224',
#     'MB225',
#     'MB312',
#     'MB219',
#     'MB305A',
#     'MB309',
#     'MB311',
#     'MB226',
#     'MB227'],
#    ['CBMR101', 'CBMR301'],
#    ['CDMM301', 'CDMM105', 'CDMM302', 'CDMM303'],
#    [],
#    ['PLB519', 'PLB522', 'PLB523'],
#    []],
#   [['SJT415',
#     'SJT505',
#     'SJT508',
#     'SJT513',
#     'SJT514',
#     'SJT521',
#     'SJT401',
#     'SJT402',
#     'SJT403',
#     'SJT404',
#     'SJT112',
#     'SJT113',
#     'SJT223',
#     'SJT315',
#     'SJT323',
#     'SJT305',
#     'SJT501',
#     'SJT522',
#     'SJT421',
#     'SJT807',
#     'SJT322',
#     'SJT405',
#     'SJT423',
#     'SJT409',
#     'SJT424',
#     'SJT503',
#     'SJT601',
#     'SJT222',
#     'SJT205',
#     'SJT211A',
#     'SJT109',
#     'SJT114',
#     'SJT115',
#     'SJT118',
#     'SJT124',
#     'SJT125',
#     'SJT207',
#     'SJT126',
#     'SJT202',
#     'SJT204',
#     'SJT207A',
#     'SJT308'],
#    ['TT523',
#     'TT630',
#     'TT631',
#     'TT112',
#     'TT434A',
#     'TT434',
#     'TT504',
#     'TT531A',
#     'TT331'],
#    ['SMV116',
#     'SMV219',
#     'SMV218',
#     'SMV217',
#     'SMV209',
#     'SMV234',
#     'SMV220',
#     'SMV112',
#     'SMV101',
#     'SMV128',
#     'SMV109'],
#    ['MGB109', 'MGB202', 'MGB207', 'MGB106', 'MGB303'],
#    ['MB219', 'MB224', 'MB226', 'MB214', 'MB309', 'MB225', 'MB227'],
#    ['CBMR101', 'CBMR301', 'CBMR402'],
#    ['CDMM105', 'CDMM302', 'CDMM301'],
#    ['GDN107'],
#    ['PLB622', 'PLB509', 'PLB504', 'PLB519', 'PLB522'],
#    []],
#   [['SJT415',
#     'SJT401',
#     'SJT501',
#     'SJT324',
#     'SJT112',
#     'SJT114',
#     'SJT109',
#     'SJT115',
#     'SJT118',
#     'SJT124',
#     'SJT207A'],
#    ['TT630',
#     'TT434',
#     'TT619',
#     'TT434A',
#     'TT424',
#     'TT206',
#     'TT301',
#     'TT302',
#     'TT303',
#     'TT621',
#     'TT504'],
#    ['SMV109',
#     'SMV217',
#     'SMV111',
#     'SMV219',
#     'SMV218',
#     'SMV128',
#     'SMV102',
#     'SMV101',
#     'SMV116',
#     'SMVG11'],
#    [],
#    ['MB214',
#     'MB225',
#     'MB226',
#     'MB227',
#     'MB305A',
#     'MB309',
#     'MB312',
#     'MB311',
#     'MB309A',
#     'MB218',
#     'MB219',
#     'MB224'],
#    [],
#    ['CDMM301', 'CDMM105'],
#    [],
#    [],
#    []]]]

# %%
import json

jsonString = json.dumps(buildingwise)
jsonString
# Out:
# '[[[["SJT415", "SJT617", "SJT508", "SJT513", "SJT521", "SJT315", "SJT112", "SJT113", "SJT401", "SJT404", "SJT405", "SJT505", "SJT324", "SJT402", "SJT403", "SJT422", "SJT423", "SJT302", "SJT322", "SJT501", "SJT601", "SJT323", "SJT421", "SJT522", "SJT303", "SJT308", "SJT311A", "SJT305", "SJT409", "SJT424", "SJT514", "SJT602", "SJT201", "SJT205", "SJT207", "SJT207A", "SJT208", "SJT211", "SJT211A", "SJT215", "SJT221", "SJT222", "SJT224", "SJT807", "SJT304", "SJT127", "SJT311"], ["TT630", "TT434A", "TT424", "TT423", "TT434", "TT335", "TT531A", "TT631", "TT619", "TT504", "TT523", "TT524"], ["SMVG10", "SMV116", "SMV217", "SMV218", "SMV219", "SMV128", "SMV209", "SMV234", "SMV109", "SMV101", "SMV102", "SMV220", "SMV320"], ["MGB105", "MGB201", "MGB110", "MGB305", "MGB 303", "MGB304"], ["MB214", "MB218", "MB224", "MB225", "MB226", "MB305A", "MB219", "MB227", "MB312", "MB311", "MB309A"], ["CBMR101", "CBMR402", "CBMR403"], ["CDMM105", "CDMM302", "CDMM303"], ["GDN128", "GDN129"], ["PLB519", "PLB509", "PLB504", "PLB522", "PLB622"], []], [["SJT109", "SJT204", "SJT617", "SJT311A", "SJT404", "SJT501", "SJT521", "SJT208", "SJT211", "SJT211A", "SJT215", "SJT221", "SJT222", "SJT224", "SJT402", "SJT308", "SJT323", "SJT403", "SJT401", "SJT409", "SJT422", "SJT423", "SJT504", "SJT505", "SJT508", "SJT513", "SJT807", "SJT522", "SJT415", "SJT421", "SJT405", "SJT424", "SJT203", "SJT207", "SJT207A", "SJT112", "SJT113", "SJT114", "SJT126", "SJT201", "SJT205", "SJT127", "SJT322", "SJT315", "SJT324", "SJT311"], ["TT630", "TT434", "TT413", "TT424", "TT434A", "TT414", "TT415", "TT423", "TT301", "TT302", "TT303", "TT531A", "TT631", "TT334", "TT523", "TT504", "TT524", "TT206"], ["SMV109", "SMV116", "SMV111", "SMV209", "SMV217", "SMV219", "SMV220", "SMV218", "SMV234", "SMV214", "SMV128", "SMV102", "SMV101", "SMVG11", "SMVG10"], ["MGB201", "MGB106", "MGB 303", "MGB110", "MGB202"], ["MB214", "MB218", "MB225", "MB226", "MB224", "MB305A", "MB227", "MB309A", "MB309", "MB311", "MB219", "MB312"], ["CBMR101", "CBMR301", "CBMR402", "CBMR403"], ["CDMM301", "CDMM303", "CDMM302", "CDMM105", "CDMM304"], ["GDN129", "GDN128"], ["PLB509", "PLB622", "PLB519"], []], [["SJT322", "SJT315", "SJT208", "SJT211A", "SJT211", "SJT215", "SJT221", "SJT222", "SJT401", "SJT402", "SJT403", "SJT404", "SJT405", "SJT308", "SJT324", "SJT311", "SJT311A", "SJT323", "SJT224", "SJT127", "SJT505", "SJT514", "SJT508", "SJT521", "SJT513", "SJT522", "SJT409", "SJT415", "SJT421", "SJT423", "SJT601", "SJT202", "SJT207A", "SJT422", "SJT807", "SJT501", "SJT424", "SJT207", "SJT109", "SJT112", "SJT114", "SJT126", "SJT201", "SJT205", "SJT118"], ["TT207", "TT208", "TT630", "TT631", "TT531A", "TT424", "TT423", "TT434", "TT303", "TT413", "TT415", "TT414", "TT504", "TT434A", "TT301", "TT302", "TT524", "TT206"], ["SMV109", "SMV116", "SMV128", "SMV217", "SMV220", "SMV234", "SMV209", "SMV218", "SMV219", "SMV101", "SMV102", "SMV313", "SMVG10"], ["MGB304", "MGB305", "MGB105", "MGB202", "MGB106", "MGB201", "MGB207", "MGB 303"], ["MB214", "MB218", "MB219", "MB224", "MB225", "MB226", "MB227", "MB305A", "MB312", "MB309A", "MB309", "MB311"], ["CBMR101", "CBMR301", "CBMR402", "CBMR403"], ["CDMM105", "CDMM301"], ["GDN129", "GDN128"], ["PLB522", "PLB523", "PLB509"], []], [["SJT617", "SJT514", "SJT405", "SJT423", "SJT513", "SJT522", "SJT501", "SJT601", "SJT521", "SJT323", "SJT404", "SJT508", "SJT322", "SJT401", "SJT409", "SJT109", "SJT113", "SJT114", "SJT126", "SJT127", "SJT807", "SJT201", "SJT205", "SJT207", "SJT207A", "SJT208", "SJT211", "SJT211A", "SJT215", "SJT221", "SJT222", "SJT224", "SJT308", "SJT403", "SJT505", "SJT415", "SJT324", "SJT602"], ["TT423", "TT414", "TT304", "TT630", "TT631", "TT504", "TT523", "TT524"], ["SMV116", "SMV220", "SMV219", "SMV111", "SMV109", "SMV128", "SMVG11", "SMV234", "SMV217"], ["MGB 303", "MGB106", "MGB201", "MGB304", "MGB305", "MGB202", "MGB105"], ["MB218", "MB219", "MB225", "MB226", "MB227", "MB305A", "MB309"], ["CBMR403", "CBMR101", "CBMR402", "CBMR301"], ["CDMM105", "CDMM302", "CDMM303"], [" ...

# %%
buildingwise[0]
# Out:
# [[['SJT415',
#    'SJT617',
#    'SJT508',
#    'SJT513',
#    'SJT521',
#    'SJT315',
#    'SJT112',
#    'SJT113',
#    'SJT401',
#    'SJT404',
#    'SJT405',
#    'SJT505',
#    'SJT324',
#    'SJT402',
#    'SJT403',
#    'SJT422',
#    'SJT423',
#    'SJT302',
#    'SJT322',
#    'SJT501',
#    'SJT601',
#    'SJT323',
#    'SJT421',
#    'SJT522',
#    'SJT303',
#    'SJT308',
#    'SJT311A',
#    'SJT305',
#    'SJT409',
#    'SJT424',
#    'SJT514',
#    'SJT602',
#    'SJT201',
#    'SJT205',
#    'SJT207',
#    'SJT207A',
#    'SJT208',
#    'SJT211',
#    'SJT211A',
#    'SJT215',
#    'SJT221',
#    'SJT222',
#    'SJT224',
#    'SJT807',
#    'SJT304',
#    'SJT127',
#    'SJT311'],
#   ['TT630',
#    'TT434A',
#    'TT424',
#    'TT423',
#    'TT434',
#    'TT335',
#    'TT531A',
#    'TT631',
#    'TT619',
#    'TT504',
#    'TT523',
#    'TT524'],
#   ['SMVG10',
#    'SMV116',
#    'SMV217',
#    'SMV218',
#    'SMV219',
#    'SMV128',
#    'SMV209',
#    'SMV234',
#    'SMV109',
#    'SMV101',
#    'SMV102',
#    'SMV220',
#    'SMV320'],
#   ['MGB105', 'MGB201', 'MGB110', 'MGB305', 'MGB 303', 'MGB304'],
#   ['MB214',
#    'MB218',
#    'MB224',
#    'MB225',
#    'MB226',
#    'MB305A',
#    'MB219',
#    'MB227',
#    'MB312',
#    'MB311',
#    'MB309A'],
#   ['CBMR101', 'CBMR402', 'CBMR403'],
#   ['CDMM105', 'CDMM302', 'CDMM303'],
#   ['GDN128', 'GDN129'],
#   ['PLB519', 'PLB509', 'PLB504', 'PLB522', 'PLB622'],
#   []],
#  [['SJT109',
#    'SJT204',
#    'SJT617',
#    'SJT311A',
#    'SJT404',
#    'SJT501',
#    'SJT521',
#    'SJT208',
#    'SJT211',
#    'SJT211A',
#    'SJT215',
#    'SJT221',
#    'SJT222',
#    'SJT224',
#    'SJT402',
#    'SJT308',
#    'SJT323',
#    'SJT403',
#    'SJT401',
#    'SJT409',
#    'SJT422',
#    'SJT423',
#    'SJT504',
#    'SJT505',
#    'SJT508',
#    'SJT513',
#    'SJT807',
#    'SJT522',
#    'SJT415',
#    'SJT421',
#    'SJT405',
#    'SJT424',
#    'SJT203',
#    'SJT207',
#    'SJT207A',
#    'SJT112',
#    'SJT113',
#    'SJT114',
#    'SJT126',
#    'SJT201',
#    'SJT205',
#    'SJT127',
#    'SJT322',
#    'SJT315',
#    'SJT324',
#    'SJT311'],
#   ['TT630',
#    'TT434',
#    'TT413',
#    'TT424',
#    'TT434A',
#    'TT414',
#    'TT415',
#    'TT423',
#    'TT301',
#    'TT302',
#    'TT303',
#    'TT531A',
#    'TT631',
#    'TT334',
#    'TT523',
#    'TT504',
#    'TT524',
#    'TT206'],
#   ['SMV109',
#    'SMV116',
#    'SMV111',
#    'SMV209',
#    'SMV217',
#    'SMV219',
#    'SMV220',
#    'SMV218',
#    'SMV234',
#    'SMV214',
#    'SMV128',
#    'SMV102',
#    'SMV101',
#    'SMVG11',
#    'SMVG10'],
#   ['MGB201', 'MGB106', 'MGB 303', 'MGB110', 'MGB202'],
#   ['MB214',
#    'MB218',
#    'MB225',
#    'MB226',
#    'MB224',
#    'MB305A',
#    'MB227',
#    'MB309A',
#    'MB309',
#    'MB311',
#    'MB219',
#    'MB312'],
#   ['CBMR101', 'CBMR301', 'CBMR402', 'CBMR403'],
#   ['CDMM301', 'CDMM303', 'CDMM302', 'CDMM105', 'CDMM304'],
#   ['GDN129', 'GDN128'],
#   ['PLB509', 'PLB622', 'PLB519'],
#   []],
#  [['SJT322',
#    'SJT315',
#    'SJT208',
#    'SJT211A',
#    'SJT211',
#    'SJT215',
#    'SJT221',
#    'SJT222',
#    'SJT401',
#    'SJT402',
#    'SJT403',
#    'SJT404',
#    'SJT405',
#    'SJT308',
#    'SJT324',
#    'SJT311',
#    'SJT311A',
#    'SJT323',
#    'SJT224',
#    'SJT127',
#    'SJT505',
#    'SJT514',
#    'SJT508',
#    'SJT521',
#    'SJT513',
#    'SJT522',
#    'SJT409',
#    'SJT415',
#    'SJT421',
#    'SJT423',
#    'SJT601',
#    'SJT202',
#    'SJT207A',
#    'SJT422',
#    'SJT807',
#    'SJT501',
#    'SJT424',
#    'SJT207',
#    'SJT109',
#    'SJT112',
#    'SJT114',
#    'SJT126',
#    'SJT201',
#    'SJT205',
#    'SJT118'],
#   ['TT207',
#    'TT208',
#    'TT630',
#    'TT631',
#    'TT531A',
#    'TT424',
#    'TT423',
#    'TT434',
#    'TT303',
#    'TT413',
#    'TT415',
#    'TT414',
#    'TT504',
#    'TT434A',
#    'TT301',
#    'TT302',
#    'TT524',
#    'TT206'],
#   ['SMV109',
#    'SMV116',
#    'SMV128',
#    'SMV217',
#    'SMV220',
#    'SMV234',
#    'SMV209',
#    'SMV218',
#    'SMV219',
#    'SMV101',
#    'SMV102',
#    'SMV313',
#    'SMVG10'],
#   ['MGB304',
#    'MGB305',
#    'MGB105',
#    'MGB202',
#    'MGB106',
#    'MGB201',
#    'MGB207',
#    'MGB 303'],
#   ['MB214',
#    'MB218',
#    'MB219',
#    'MB224',
#    'MB225',
#    'MB226',
#    'MB227',
#    'MB305A',
#    'MB312',
#    'MB309A',
#    'MB309',
#    'MB311'],
#   ['CBMR101', 'CBMR301', 'CBMR402', 'CBMR403'],
#   ['CDMM105', 'CDMM301'],
#   ['GDN129', 'GDN128'],
#   ['PLB522', 'PLB523', 'PLB509'],
#   []],
#  [['SJT617',
#    'SJT514',
#    'SJT405',
#    'SJT423',
#    'SJT513',
#    'SJT522',
#    'SJT501',
#    'SJT601',
#    'SJT521',
#    'SJT323',
#    'SJT404',
#    'SJT508',
#    'SJT322',
#    'SJT401',
#    'SJT409',
#    'SJT109',
#    'SJT113',
#    'SJT114',
#    'SJT126',
#    'SJT127',
#    'SJT807',
#    'SJT201',
#    'SJT205',
#    'SJT207',
#    'SJT207A',
#    'SJT208',
#    'SJT211',
#    'SJT211A',
#    'SJT215',
#    'SJT221',
#    'SJT222',
#    'SJT224',
#    'SJT308',
#    'SJT403',
#    'SJT505',
#    'SJT415',
#    'SJT324',
#    'SJT602'],
#   ['TT423', 'TT414', 'TT304', 'TT630', 'TT631', 'TT504', 'TT523', 'TT524'],
#   ['SMV116',
#    'SMV220',
#    'SMV219',
#    'SMV111',
#    'SMV109',
#    'SMV128',
#    'SMVG11',
#    'SMV234',
#    'SMV217'],
#   ['MGB 303', 'MGB106', 'MGB201', 'MGB304', 'MGB305', 'MGB202', 'MGB105'],
#   ['MB218', 'MB219', 'MB225', 'MB226', 'MB227', 'MB305A', 'MB309'],
#   ['CBMR403', 'CBMR101', 'CBMR402', 'CBMR301'],
#   ['CDMM105', 'CDMM302', 'CDMM303'],
#   ['GDN128', 'GDN129'],
#   [],
#   []],
#  [['SJT109',
#    'SJT112',
#    'SJT113',
#    'SJT114',
#    'SJT522',
#    'SJT401',
#    'SJT402',
#    'SJT505',
#    'SJT308',
#    'SJT508',
#    'SJT311',
#    'SJT315',
#    'SJT423',
#    'SJT405',
#    'SJT501',
#    'SJT513',
#    'SJT514',
#    'SJT504',
#    'SJT323',
#    'SJT403',
#    'SJT324',
#    'SJT404',
#    'SJT521',
#    'SJT424',
#    'SJT601',
#    'SJT415',
#    'SJT422',
#    'SJT409',
#    'SJT127',
#    'SJT201',
#    'SJT205',
#    'SJT207A',
#    'SJT208',
#    'SJT211',
#    'SJT211A',
#    'SJT126',
#    'SJT215',
#    'SJT807',
#    'SJT602'],
#   ['TT413',
#    'TT524',
#    'TT415',
#    'TT423',
#    'TT424',
#    'TT434',
#    'TT304',
#    'TT531A',
#    'TT301',
#    'TT208',
#    'TT303',
#    'TT530A',
#    'TT523',
#    'TT206'],
#   ['SMV128',
#    'SMV112',
#    'SMV220',
#    'SMV116',
#    'SMV217',
#    'SMV218',
#    'SMV102',
#    'SMV101',
#    'SMVG11',
#    'SMV219',
#    'SMV209'],
#   ['MGB304', 'MGB303', 'MGB 303', 'MGB110', 'MGB209', 'MGB207', 'MGB208'],
#   ['MB214',
#    'MB219',
#    'MB218',
#    'MB311',
#    'MB224',
#    'MB226',
#    'MB309A',
#    'MB210',
#    'MB312'],
#   ['CBMR301', 'CBMR101'],
#   ['CDMM304'],
#   ['GDN128'],
#   [],
#   []],
#  [['SJT415',
#    'SJT505',
#    'SJT508',
#    'SJT513',
#    'SJT514',
#    'SJT521',
#    'SJT401',
#    'SJT402',
#    'SJT403',
#    'SJT404',
#    'SJT112',
#    'SJT113',
#    'SJT617',
#    'SJT303',
#    'SJT224',
#    'SJT315',
#    'SJT323',
#    'SJT305',
#    'SJT501',
#    'SJT522',
#    'SJT302',
#    'SJT311A',
#    'SJT421',
#    'SJT807',
#    'SJT504',
#    'SJT322',
#    'SJT405',
#    'SJT423',
#    'SJT409',
#    'SJT424',
#    'SJT503',
#    'SJT601',
#    'SJT222',
#    'SJT205',
#    'SJT211A',
#    'SJT109',
#    'SJT114',
#    'SJT115',
#    'SJT118',
#    'SJT124',
#    'SJT125',
#    'SJT207',
#    'SJT126',
#    'SJT127',
#    'SJT201',
#    'SJT202',
#    'SJT203',
#    'SJT204',
#    'SJT207A',
#    'SJT308',
#    'SJT304',
#    'SJT208',
#    'SJT211',
#    'SJT221',
#    'SJT215',
#    'SJT324',
#    'SJT422',
#    'SJT311'],
#   ['TT523',
#    'TT630',
#    'TT631',
#    'TT112',
#    'TT423',
#    'TT424',
#    'TT434A',
#    'TT434',
#    'TT504',
#    'TT531A',
#    'TT524',
#    'TT619',
#    'TT331'],
#   ['SMV116',
#    'SMV219',
#    'SMV218',
#    'SMV217',
#    'SMV209',
#    'SMV234',
#    'SMV220',
#    'SMV112',
#    'SMV101',
#    'SMV128',
#    'SMV102',
#    'SMV109',
#    'SMVG10'],
#   ['MGB109', 'MGB202', 'MGB110', 'MGB207', 'MGB106', 'MGB303'],
#   ['MB219', 'MB224', 'MB214', 'MB309', 'MB225', 'MB227'],
#   ['CBMR101', 'CBMR301', 'CBMR403', 'CBMR402'],
#   ['CDMM105', 'CDMM302', 'CDMM301'],
#   ['GDN107'],
#   ['PLB622', 'PLB509', 'PLB504', 'PLB519', 'PLB522'],
#   []],
#  [['SJT415',
#    'SJT522',
#    'SJT423',
#    'SJT223',
#    'SJT305',
#    'SJT401',
#    'SJT311A',
#    'SJT405',
#    'SJT501',
#    'SJT208',
#    'SJT211',
#    'SJT211A',
#    'SJT125',
#    'SJT126',
#    'SJT222',
#    'SJT308',
#    'SJT403',
#    'SJT402',
#    'SJT409',
#    'SJT323',
#    'SJT404',
#    'SJT201',
#    'SJT421',
#    'SJT221',
#    'SJT202',
#    'SJT504',
#    'SJT503',
#    'SJT505',
#    'SJT422',
#    'SJT508',
#    'SJT315',
#    'SJT322',
#    'SJT424',
#    'SJT324',
#    'SJT112',
#    'SJT113',
#    'SJT114',
#    'SJT109',
#    'SJT115',
#    'SJT118',
#    'SJT124',
#    'SJT207A'],
#   ['TT630',
#    'TT434',
#    'TT434A',
#    'TT414',
#    'TT415',
#    'TT424',
#    'TT301',
#    'TT302',
#    'TT303',
#    'TT621',
#    'TT504',
#    'TT207',
#    'TT208',
#    'TT331',
#    'TT631',
#    'TT413',
#    'TT423',
#    'TT524'],
#   ['SMV109',
#    'SMV217',
#    'SMV111',
#    'SMV219',
#    'SMV218',
#    'SMV128',
#    'SMV214',
#    'SMV116',
#    'SMV102',
#    'SMVG11'],
#   ['MGB105', 'MGB106'],
#   ['MB214',
#    'MB225',
#    'MB226',
#    'MB227',
#    'MB218',
#    'MB305A',
#    'MB309',
#    'MB312',
#    'MB311',
#    'MB309A',
#    'MB224',
#    'MB219'],
#   ['CBMR101'],
#   ['CDMM304', 'CDMM301', 'CDMM105', 'CDMM303'],
#   ['GDN107', 'GDN129', 'GDN128'],
#   ['PLB523'],
#   []],
#  [['SJT322',
#    'SJT315',
#    'SJT208',
#    'SJT215',
#    'SJT211A',
#    'SJT211',
#    'SJT221',
#    'SJT222',
#    'SJT401',
#    'SJT402',
#    'SJT403',
#    'SJT404',
#    'SJT405',
#    'SJT308',
#    'SJT311',
#    'SJT324',
#    'SJT311A',
#    'SJT323',
#    'SJT224',
#    'SJT127',
#    'SJT505',
#    'SJT514',
#    'SJT508',
#    'SJT521',
#    'SJT513',
#    'SJT522',
#    'SJT409',
#    'SJT415',
#    'SJT807',
#    'SJT423',
#    'SJT504',
#    'SJT115',
#    'SJT125',
#    'SJT303',
#    'SJT202',
#    'SJT203',
#    'SJT501',
#    'SJT305',
#    'SJT421',
#    'SJT422',
#    'SJT503',
#    'SJT124',
#    'SJT118',
#    'SJT109',
#    'SJT112',
#    'SJT113',
#    'SJT114',
#    'SJT617'],
#   ['TT207',
#    'TT208',
#    'TT630',
#    'TT631',
#    'TT531A',
#    'TT424',
#    'TT423',
#    'TT434',
#    'TT303',
#    'TT414',
#    'TT112',
#    'TT413',
#    'TT434A',
#    'TT206',
#    'TT301',
#    'TT302',
#    'TT415'],
#   ['SMV109',
#    'SMV116',
#    'SMV128',
#    'SMV112',
#    'SMV220',
#    'SMV219',
#    'SMV218',
#    'SMV217',
#    'SMV102',
#    'SMV101',
#    'SMV234'],
#   [],
#   ['MB214',
#    'MB218',
#    'MB219',
#    'MB224',
#    'MB225',
#    'MB226',
#    'MB227',
#    'MB305A',
#    'MB309',
#    'MB312',
#    'MB311',
#    'MB309A'],
#   ['CBMR101', 'CBMR301', 'CBMR403', 'CBMR402'],
#   ['CDMM105', 'CDMM301', 'CDMM303', 'CDMM302'],
#   ['GDN107', 'GDN129', 'GDN128'],
#   ['PLB519', 'PLB522'],
#   []],
#  [['SJT415',
#    'SJT401',
#    'SJT807',
#    'SJT305',
#    'SJT403',
#    'SJT404',
#    'SJT421',
#    'SJT423',
#    'SJT508',
#    'SJT513',
#    'SJT409',
#    'SJT424',
#    'SJT504',
#    'SJT311A',
#    'SJT501',
#    'SJT505',
#    'SJT521',
#    'SJT405',
#    'SJT208',
#    'SJT113',
#    'SJT114',
#    'SJT115',
#    'SJT118',
#    'SJT124',
#    'SJT125',
#    'SJT127',
#    'SJT112',
#    'SJT202',
#    'SJT203',
#    'SJT204',
#    'SJT205',
#    'SJT207',
#    'SJT207A',
#    'SJT211',
#    'SJT222',
#    'SJT602',
#    'SJT323',
#    'SJT303'],
#   ['TT424',
#    'TT434',
#    'TT434A',
#    'TT523',
#    'TT304',
#    'TT531A',
#    'TT630',
#    'TT631',
#    'TT504'],
#   ['SMV112', 'SMV116', 'SMV111', 'SMV218', 'SMV217', 'SMV128', 'SMV102'],
#   ['MGB 303'],
#   ['MB305A',
#    'MB214',
#    'MB309',
#    'MB218',
#    'MB219',
#    'MB224',
#    'MB225',
#    'MB226',
#    'MB312',
#    'MB227',
#    'MB311',
#    'MB309A'],
#   ['CBMR101', 'CBMR301', 'CBMR402', 'CBMR403'],
#   ['CDMM105', 'CDMM302', 'CDMM303'],
#   [],
#   ['PLB504'],
#   []],
#  [['SJT109',
#    'SJT112',
#    'SJT113',
#    'SJT324',
#    'SJT305',
#    'SJT403',
#    'SJT311',
#    'SJT401',
#    'SJT423',
#    'SJT402',
#    'SJT323',
#    'SJT405',
#    'SJT424',
#    'SJT501',
#    'SJT502',
#    'SJT508',
#    'SJT311A',
#    'SJT404',
#    'SJT315',
#    'SJT505',
#    'SJT215',
#    'SJT224',
#    'SJT221',
#    'SJT422',
#    'SJT514',
#    'SJT222',
#    'SJT415',
#    'SJT409',
#    'SJT308',
#    'SJT504',
#    'SJT322',
#    'SJT513',
#    'SJT211A',
#    'SJT114',
#    'SJT115',
#    'SJT118',
#    'SJT125',
#    'SJT127',
#    'SJT201',
#    'SJT202',
#    'SJT126',
#    'SJT203',
#    'SJT207',
#    'SJT207A'],
#   ['TT434A',
#    'TT415',
#    'TT413',
#    'TT414',
#    'TT423',
#    'TT424',
#    'TT302',
#    'TT301',
#    'TT303',
#    'TT530',
#    'TT206',
#    'TT631'],
#   ['SMV116', 'SMV214', 'SMV128', 'SMV109', 'SMV102', 'SMV101', 'SMVG11'],
#   ['MGB105'],
#   ['MB214', 'MB219', 'MB225', 'MB218', 'MB312'],
#   ['CBMR101'],
#   ['CDMM304'],
#   [],
#   [],
#   []]]

# %%
print('[')
for i in range(len(buildingwise[0])):
    print('[')
    for j in range(len(buildingwise[0][i])):
        print(buildingwise[0][i][j])
    print('],')
print(']')
# Out:
# [
# ['SJT415', 'SJT617', 'SJT508', 'SJT513', 'SJT521', 'SJT315', 'SJT112', 'SJT113', 'SJT401', 'SJT404', 'SJT405', 'SJT505', 'SJT324', 'SJT402', 'SJT403', 'SJT422', 'SJT423', 'SJT302', 'SJT322', 'SJT501', 'SJT601', 'SJT323', 'SJT421', 'SJT522', 'SJT303', 'SJT308', 'SJT311A', 'SJT305', 'SJT409', 'SJT424', 'SJT514', 'SJT602', 'SJT201', 'SJT205', 'SJT207', 'SJT207A', 'SJT208', 'SJT211', 'SJT211A', 'SJT215', 'SJT221', 'SJT222', 'SJT224', 'SJT807', 'SJT304', 'SJT127', 'SJT311']
# ['TT630', 'TT434A', 'TT424', 'TT423', 'TT434', 'TT335', 'TT531A', 'TT631', 'TT619', 'TT504', 'TT523', 'TT524']
# ['SMVG10', 'SMV116', 'SMV217', 'SMV218', 'SMV219', 'SMV128', 'SMV209', 'SMV234', 'SMV109', 'SMV101', 'SMV102', 'SMV220', 'SMV320']
# ['MGB105', 'MGB201', 'MGB110', 'MGB305', 'MGB 303', 'MGB304']
# ['MB214', 'MB218', 'MB224', 'MB225', 'MB226', 'MB305A', 'MB219', 'MB227', 'MB312', 'MB311', 'MB309A']
# ['CBMR101', 'CBMR402', 'CBMR403']
# ['CDMM105', 'CDMM302', 'CDMM303']
# ['GDN128', 'GDN129']
# ['PLB519', 'PLB509', 'PLB504', 'PLB522', 'PLB622']
# []
# [
# [
# ['SJT109', 'SJT204', 'SJT617', 'SJT311A', 'SJT404', 'SJT501', 'SJT521', 'SJT208', 'SJT211', 'SJT211A', 'SJT215', 'SJT221', 'SJT222', 'SJT224', 'SJT402', 'SJT308', 'SJT323', 'SJT403', 'SJT401', 'SJT409', 'SJT422', 'SJT423', 'SJT504', 'SJT505', 'SJT508', 'SJT513', 'SJT807', 'SJT522', 'SJT415', 'SJT421', 'SJT405', 'SJT424', 'SJT203', 'SJT207', 'SJT207A', 'SJT112', 'SJT113', 'SJT114', 'SJT126', 'SJT201', 'SJT205', 'SJT127', 'SJT322', 'SJT315', 'SJT324', 'SJT311']
# ['TT630', 'TT434', 'TT413', 'TT424', 'TT434A', 'TT414', 'TT415', 'TT423', 'TT301', 'TT302', 'TT303', 'TT531A', 'TT631', 'TT334', 'TT523', 'TT504', 'TT524', 'TT206']
# ['SMV109', 'SMV116', 'SMV111', 'SMV209', 'SMV217', 'SMV219', 'SMV220', 'SMV218', 'SMV234', 'SMV214', 'SMV128', 'SMV102', 'SMV101', 'SMVG11', 'SMVG10']
# ['MGB201', 'MGB106', 'MGB 303', 'MGB110', 'MGB202']
# ['MB214', 'MB218', 'MB225', 'MB226', 'MB224', 'MB305A', 'MB227', 'MB309A', 'MB309', 'MB311', 'MB219', 'MB312']
# ['CBMR101', 'CBMR301', 'CBMR402', 'CBMR403']
# ['CDMM301', 'CDMM303', 'CDMM302', 'CDMM105', 'CDMM304']
# ['GDN129', 'GDN128']
# ['PLB509', 'PLB622', 'PLB519']
# []
# [
# [
# ['SJT322', 'SJT315', 'SJT208', 'SJT211A', 'SJT211', 'SJT215', 'SJT221', 'SJT222', 'SJT401', 'SJT402', 'SJT403', 'SJT404', 'SJT405', 'SJT308', 'SJT324', 'SJT311', 'SJT311A', 'SJT323', 'SJT224', 'SJT127', 'SJT505', 'SJT514', 'SJT508', 'SJT521', 'SJT513', 'SJT522', 'SJT409', 'SJT415', 'SJT421', 'SJT423', 'SJT601', 'SJT202', 'SJT207A', 'SJT422', 'SJT807', 'SJT501', 'SJT424', 'SJT207', 'SJT109', 'SJT112', 'SJT114', 'SJT126', 'SJT201', 'SJT205', 'SJT118']
# ['TT207', 'TT208', 'TT630', 'TT631', 'TT531A', 'TT424', 'TT423', 'TT434', 'TT303', 'TT413', 'TT415', 'TT414', 'TT504', 'TT434A', 'TT301', 'TT302', 'TT524', 'TT206']
# ['SMV109', 'SMV116', 'SMV128', 'SMV217', 'SMV220', 'SMV234', 'SMV209', 'SMV218', 'SMV219', 'SMV101', 'SMV102', 'SMV313', 'SMVG10']
# ['MGB304', 'MGB305', 'MGB105', 'MGB202', 'MGB106', 'MGB201', 'MGB207', 'MGB 303']
# ['MB214', 'MB218', 'MB219', 'MB224', 'MB225', 'MB226', 'MB227', 'MB305A', 'MB312', 'MB309A', 'MB309', 'MB311']
# ['CBMR101', 'CBMR301', 'CBMR402', 'CBMR403']
# ['CDMM105', 'CDMM301']
# ['GDN129', 'GDN128']
# ['PLB522', 'PLB523', 'PLB509']
# []
# [
# [
# ['SJT617', 'SJT514', 'SJT405', 'SJT423', 'SJT513', 'SJT522', 'SJT501', 'SJT601', 'SJT521', 'SJT323', 'SJT404', 'SJT508', 'SJT322', 'SJT401', 'SJT409', 'SJT109', 'SJT113', 'SJT114', 'SJT126', 'SJT127', 'SJT807', 'SJT201', 'SJT205', 'SJT207', 'SJT207A', 'SJT208', 'SJT211', 'SJT211A', 'SJT215', 'SJT221', 'SJT222', 'SJT224', 'SJT308', 'SJT403', 'SJT505', 'SJT415', 'SJT324', 'SJT602']
# ['TT423', 'TT414', 'TT304', 'TT630', 'TT631', 'TT504', 'TT523', 'TT524']
# ['SMV116', 'SMV220', 'SMV219', 'SMV111', 'SMV109', 'SMV128', 'SMVG11', 'SMV234', 'SMV217']
# ['MGB 303', 'MGB106', 'MGB201', 'MGB304', 'MGB305', 'MGB202', 'MGB105']
# ['MB218', 'MB219', 'MB225', 'MB226', 'MB227', 'MB305A', 'MB309']
# ['CBMR403', 'CBMR101', 'CBMR402', 'CBMR301']
# ['CDMM105', 'CDMM302', 'CDMM303']
# ['GDN128', 'GDN129']
# []
# []
# [
# [
# ['SJT109', 'SJT112', 'SJT113', 'SJT114', 'SJT522', 'SJT401', 'SJT402', 'SJT505', 'SJT308', 'SJT508', 'SJT311', 'SJT315', 'SJT423', 'SJT405', 'SJT501', 'SJT513', 'SJT514', 'SJT504', 'SJT323', 'SJT403', 'SJT324', 'SJT404', 'SJT521', 'SJT424', 'SJT601', 'SJT415', 'SJT422', 'SJT409', 'SJT127', 'SJT201', 'SJT205', 'SJT207A', 'SJT208', 'SJT211', 'SJT211A', 'SJT126', 'SJT215', 'SJT807', 'SJT602']
# ['TT413', 'TT524', 'TT415', 'TT423', 'TT424', 'TT434', 'TT304', 'TT531A', 'TT301', 'TT208', 'TT303', 'TT530A', 'TT523', 'TT206']
# ['SMV128', 'SMV112', 'SMV220', 'SMV116', 'SMV217', 'SMV218', 'SMV102', 'SMV101', 'SMVG11', 'SMV219', 'SMV209']
# ['MGB304', 'MGB303', 'MGB 303', 'MGB110', 'MGB209', 'MGB207', 'MGB208']
# ['MB214', 'MB219', 'MB218', 'MB311', 'MB224', 'MB226', 'MB309A', 'MB210', 'MB312']
# ['CBMR301', 'CBMR101']
# ['CDMM304']
# ['GDN128']
# []
# []
# [
# [
# ['SJT415', 'SJT505', 'SJT508', 'SJT513', 'SJT514', 'SJT521', 'SJT401', 'SJT402', 'SJT403', 'SJT404', 'SJT112', 'SJT113', 'SJT617', 'SJT303', 'SJT224', 'SJT315', 'SJT323', 'SJT305', 'SJT501', 'SJT522', 'SJT302', 'SJT311A', 'SJT421', 'SJT807', 'SJT504', 'SJT322', 'SJT405', 'SJT423', 'SJT409', 'SJT424', 'SJT503', 'SJT601', 'SJT222', 'SJT205', 'SJT211A', 'SJT109', 'SJT114', 'SJT115', 'SJT118', 'SJT124', 'SJT125', 'SJT207', 'SJT126', 'SJT127', 'SJT201', 'SJT202', 'SJT203', 'SJT204', 'SJT207A', 'SJT308', 'SJT304', 'SJT208', 'SJT211', 'SJT221', 'SJT215', 'SJT324', 'SJT422', 'SJT311']
# ['TT523', 'TT630', 'TT631', 'TT112', 'TT423', 'TT424', 'TT434A', 'TT434', 'TT504', 'TT531A', 'TT524', 'TT619', 'TT331']
# ['SMV116', 'SMV219', 'SMV218', 'SMV217', 'SMV209', 'SMV234', 'SMV220', 'SMV112', 'SMV101', 'SMV128', 'SMV102', 'SMV109', 'SMVG10']
# ['MGB109', 'MGB202', 'MGB110', 'MGB207', 'MGB106', 'MGB303']
# ['MB219', 'MB224', 'MB214', 'MB309', 'MB225', 'MB227']
# ['CBMR101', 'CBMR301', 'CBMR403', 'CBMR402']
# ['CDMM105', 'CDMM302', 'CDMM301']
# ['GDN107']
# ['PLB622', 'PLB509', 'PLB504', 'PLB519', 'PLB522']
# []
# [
# [
# ['SJT415', 'SJT522', 'SJT423', 'SJT223', 'SJT305', 'SJT401', 'SJT311A', 'SJT405', 'SJT501', 'SJT208', 'SJT211', 'SJT211A', 'SJT125', 'SJT126', 'SJT222', 'SJT308', 'SJT403', 'SJT402', 'SJT409', 'SJT323', 'SJT404', 'SJT201', 'SJT421', 'SJT221', 'SJT202', 'SJT504', 'SJT503', 'SJT505', 'SJT422', 'SJT508', 'SJT315', 'SJT322', 'SJT424', 'SJT324', 'SJT112', 'SJT113', 'SJT114', 'SJT109', 'SJT115', 'SJT118', 'SJT124', 'SJT207A']
# ['TT630', 'TT434', 'TT434A', 'TT414', 'TT415', 'TT424', 'TT301', 'TT302', 'TT303', 'TT621', 'TT504', 'TT207', 'TT208', 'TT331', 'TT631', 'TT413', 'TT423', 'TT524']
# ['SMV109', 'SMV217', 'SMV111', 'SMV219', 'SMV218', 'SMV128', 'SMV214', 'SMV116', 'SMV102', 'SMVG11']
# ['MGB105', 'MGB106']
# ['MB214', 'MB225', 'MB226', 'MB227', 'MB218', 'MB305A', 'MB309', 'MB312', 'MB311', 'MB309A', 'MB224', 'MB219']
# ['CBMR101']
# ['CDMM304', 'CDMM301', 'CDMM105', 'CDMM303']
# ['GDN107', 'GDN129', 'GDN128']
# ['PLB523']
# []
# [
# [
# ['SJT322', 'SJT315', 'SJT208', 'SJT215', 'SJT211A', 'SJT211', 'SJT221', 'SJT222', 'SJT401', 'SJT402', 'SJT403', 'SJT404', 'SJT405', 'SJT308', 'SJT311', 'SJT324', 'SJT311A', 'SJT323', 'SJT224', 'SJT127', 'SJT505', 'SJT514', 'SJT508', 'SJT521', 'SJT513', 'SJT522', 'SJT409', 'SJT415', 'SJT807', 'SJT423', 'SJT504', 'SJT115', 'SJT125', 'SJT303', 'SJT202', 'SJT203', 'SJT501', 'SJT305', 'SJT421', 'SJT422', 'SJT503', 'SJT124', 'SJT118', 'SJT109', 'SJT112', 'SJT113', 'SJT114', 'SJT617']
# ['TT207', 'TT208', 'TT630', 'TT631', 'TT531A', 'TT424', 'TT423', 'TT434', 'TT303', 'TT414', 'TT112', 'TT413', 'TT434A', 'TT206', 'TT301', 'TT302', 'TT415']
# ['SMV109', 'SMV116', 'SMV128', 'SMV112', 'SMV220', 'SMV219', 'SMV218', 'SMV217', 'SMV102', 'SMV101', 'SMV234']
# []
# ['MB214', 'MB218', 'MB219', 'MB224', 'MB225', 'MB226', 'MB227', 'MB305A', 'MB309', 'MB312', 'MB311', 'MB309A']
# ['CBMR101', 'CBMR301', 'CBMR403', 'CBMR402']
# ['CDMM105', 'CDMM301', 'CDMM303', 'CDMM302']
# ['GDN107', 'GDN129', 'GDN128']
# ['PLB519', 'PLB522']
# []
# [
# [
# ['SJT415', 'SJT401', 'SJT807', 'SJT305', 'SJT403', 'SJT404', 'SJT421', 'SJT423', 'SJT508', 'SJT513', 'SJT409', 'SJT424', 'SJT504', 'SJT311A', 'SJT501', 'SJT505', 'SJT521', 'SJT405', 'SJT208', 'SJT113', 'SJT114', 'SJT115', 'SJT118', 'SJT124', 'SJT125', 'SJT127', 'SJT112', 'SJT202', 'SJT203', 'SJT204', 'SJT205', 'SJT207', 'SJT207A', 'SJT211', 'SJT222', 'SJT602', 'SJT323', 'SJT303']
# ['TT424', 'TT434', 'TT434A', 'TT523', 'TT304', 'TT531A', 'TT630', 'TT631', 'TT504']
# ['SMV112', 'SMV116', 'SMV111', 'SMV218', 'SMV217', 'SMV128', 'SMV102']
# ['MGB 303']
# ['MB305A', 'MB214', 'MB309', 'MB218', 'MB219', 'MB224', 'MB225', 'MB226', 'MB312', 'MB227', 'MB311', 'MB309A']
# ['CBMR101', 'CBMR301', 'CBMR402', 'CBMR403']
# ['CDMM105', 'CDMM302', 'CDMM303']
# []
# ['PLB504']
# []
# [
# [
# ['SJT109', 'SJT112', 'SJT113', 'SJT324', 'SJT305', 'SJT403', 'SJT311', 'SJT401', 'SJT423', 'SJT402', 'SJT323', 'SJT405', 'SJT424', 'SJT501', 'SJT502', 'SJT508', 'SJT311A', 'SJT404', 'SJT315', 'SJT505', 'SJT215', 'SJT224', 'SJT221', 'SJT422', 'SJT514', 'SJT222', 'SJT415', 'SJT409', 'SJT308', 'SJT504', 'SJT322', 'SJT513', 'SJT211A', 'SJT114', 'SJT115', 'SJT118', 'SJT125', 'SJT127', 'SJT201', 'SJT202', 'SJT126', 'SJT203', 'SJT207', 'SJT207A']
# ['TT434A', 'TT415', 'TT413', 'TT414', 'TT423', 'TT424', 'TT302', 'TT301', 'TT303', 'TT530', 'TT206', 'TT631']
# ['SMV116', 'SMV214', 'SMV128', 'SMV109', 'SMV102', 'SMV101', 'SMVG11']
# ['MGB105']
# ['MB214', 'MB219', 'MB225', 'MB218', 'MB312']
# ['CBMR101']
# ['CDMM304']
# []
# []
# []
# [
